# %% [markdown]
# # Crawl JC Odds

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import re
import time
from tqdm import tqdm_notebook as tqdm
from datetime import datetime, timedelta
import json

driver = webdriver.Chrome()
start_url = "http://bet.hkjc.com/football/default.aspx?url=/football/schedule/schedule.aspx&lang=en"
driver.get(start_url)
driver.switch_to_frame(driver.find_element_by_tag_name("iframe"))

from_date = "01"
from_month = "08"
from_year = "2017"

to_date = "31"
to_month = "05"
to_year = "2018"

with open('./{}-{}/team_instances_table.json'.format(from_year, to_year),'r') as fp:
    team_table = json.load(fp)

# %%
def reloadIframe(webdriver):
    webdriver.switch_to_default_content()
    webdriver.switch_to_frame(webdriver.find_element_by_tag_name("iframe"))

# %%
results_dividends_button = driver.find_element_by_xpath("//*[@id=\"betToolsTxt_2\"]")
results_dividends_button.click()
match_results_button = driver.find_element_by_xpath("//*[@id=\"betToolsMenu_2\"]/table/tbody/tr/td/table/tbody/tr[1]/td[2]/a")
match_results_button.click()
time.sleep(2)

jc_match_table = {}
ttl_cnt = 1

for team_id, team_info in team_table.items():
    jc_team = team_info['jc_name']
    while True:
        try:
            reloadIframe(driver)
            time.sleep(1)
            
            # Select desired start date
            from_date_list = Select(driver.find_element_by_xpath("//*[@id=\"ctl00_cm_srch_DDL_Fday\"]"))
            from_month_list = Select(driver.find_element_by_xpath("//*[@id=\"ctl00_cm_srch_DDL_Fmonth\"]"))
            from_year_list = Select(driver.find_element_by_xpath("//*[@id=\"ctl00_cm_srch_DDL_Fyear\"]"))

            change_from_date = from_date_list.select_by_value(from_date)
            change_from_month = from_month_list.select_by_value(from_month)
            change_from_year = from_year_list.select_by_value(from_year)
            
            # Select desired end date
            to_date_list = Select(driver.find_element_by_xpath("//*[@id=\"ctl00_cm_srch_DDL_Tday\"]"))
            to_month_list = Select(driver.find_element_by_xpath("//*[@id=\"ctl00_cm_srch_DDL_Tmonth\"]"))
            to_year_list = Select(driver.find_element_by_xpath("//*[@id=\"ctl00_cm_srch_DDL_Tyear\"]"))

            change_to_date = to_date_list.select_by_value(to_date)
            change_to_month = to_month_list.select_by_value(to_month)
            change_to_year = to_year_list.select_by_value(to_year)
            
            # Select desired JC team name
            select_team = Select(driver.find_element_by_xpath("//*[@id=\"ctl00_cm_srch_DDL_TeamList\"]"))
            select_team.select_by_visible_text(jc_team)
            
            # Click "search"
            driver.find_element_by_xpath("//*[@id=\"btn_search\"]").click()
            time.sleep(1)
            
            # Map each match to Whoscored match table and record the JC odds report link
            reloadIframe(driver)
            time.sleep(1)
            
            page_a_tag = driver.find_elements_by_xpath("//*[@id=\"footballmaincontent\"]/table/tbody/tr[4]/td/div/div[2]/a")
            page_cnt = 1
            while True:
                all_matches = driver.find_elements_by_xpath("//*[@id=\"ctl00_cm_tdMatches\"]/table/tbody/tr")
                series_a_matches = []
                
                for match in all_matches:
                    matchLeague = match.find_element_by_class_name("matchLeague").find_element_by_tag_name('img').get_attribute("title")
                    if matchLeague == "Italian Division 1":
                        series_a_matches.append(match)
                print(">>> {} Crawling team: {}, page: {}, no of matches: {}".format(ttl_cnt,jc_team, page_cnt, len(series_a_matches)))
                
                for match in series_a_matches:
                    matchTeam = match.find_element_by_class_name("matchTeam").text
                    home_team = matchTeam.split(" vs ")[0]
                    away_team = matchTeam.split(" vs ")[1]
                    
                    matchDate = match.find_element_by_class_name("matchDate").text
                    #jc_match_date = datetime.strptime(matchDate, "%d/%m/%Y")
                    
                    matchOdds = match.find_element_by_class_name("matchOdds").find_element_by_tag_name("a").get_attribute("href")
                    
                    jc_match_id = "{},{},{}".format(home_team,away_team,matchDate)
                    
                    if jc_match_id not in jc_match_table:
                        jc_match_table[jc_match_id] = {}
                        jc_match_table[jc_match_id]["odds_link"] = matchOdds
                    
                    
                if page_a_tag[-1].text != "Next":
                    break
                
                page_a_tag[-1].click()
                time.sleep(1)
                page_cnt += 1
                reloadIframe(driver)
                time.sleep(1)
                while True:
                    try:
                        page_a_tag = driver.find_elements_by_xpath("//*[@id=\"footballmaincontent\"]/table/tbody/tr[4]/td/div/div[2]/a")
                        break
                    except Exception as e:
                        print("Finding next page button...")
                        print(e)
                        time.sleep(1)
            ttl_cnt += 1          
            break
            
        except Exception as e:
            print(e)
            time.sleep(1)
print(">>> finished.")
# Out:
# >>>1 Crawling team: SPAL, page: 1, no of matches: 19
# >>>1 Crawling team: SPAL, page: 2, no of matches: 10
# >>>2 Crawling team: Sassuolo, page: 1, no of matches: 18
# >>>2 Crawling team: Sassuolo, page: 2, no of matches: 11
# >>>3 Crawling team: Cagliari, page: 1, no of matches: 20
# >>>3 Crawling team: Cagliari, page: 2, no of matches: 9
# >>>4 Crawling team: Sampdoria, page: 1, no of matches: 18
# >>>4 Crawling team: Sampdoria, page: 2, no of matches: 12
# >>>5 Crawling team: Genoa, page: 1, no of matches: 18
# >>>5 Crawling team: Genoa, page: 2, no of matches: 12
# >>>6 Crawling team: Benevento, page: 1, no of matches: 20
# >>>6 Crawling team: Benevento, page: 2, no of matches: 9
# >>>7 Crawling team: Roma, page: 1, no of matches: 16
# >>>7 Crawling team: Roma, page: 2, no of matches: 14
# >>>8 Crawling team: Fiorentina, page: 1, no of matches: 18
# >>>8 Crawling team: Fiorentina, page: 2, no of matches: 11
# >>>9 Crawling team: Crotone, page: 1, no of matches: 19
# >>>9 Crawling team: Crotone, page: 2, no of matches: 10
# >>>10 Crawling team: Lazio, page: 1, no of matches: 13
# >>>10 Crawling team: Lazio, page: 2, no of matches: 14
# >>>10 Crawling team: Lazio, page: 3, no of matches: 3
# >>>11 Crawling team: AC Torino, page: 1, no of matches: 17
# >>>11 Crawling team: AC Torino, page: 2, no of matches: 12
# >>>12 Crawling team: Chievo, page: 1, no of matches: 19
# >>>12 Crawling team: Chievo, page: 2, no of matches: 10
# >>>13 Crawling team: Napoli, page: 1, no of matches: 15
# >>>13 Crawling team: Napoli, page: 2, no of matches: 14
# >>>13 Crawling team: Napoli, page: 3, no of matches: 0
# >>>14 Crawling team: Bologna, page: 1, no of matches: 20
# >>>14 Crawling team: Bologna, page: 2, no of matches: 9
# >>>15 Crawling team: AC Milan, page: 1, no of matches: 13
# >>>15 Crawling team: AC Milan, page: 2, no of matches: 13
# >>>15 Crawling team: AC Milan, page: 3, no of matches: 3
# >>>16 Crawling team: Udinese, page: 1, no of matches: 18
# >>>16 Crawling team: Udinese, page: 2, no of matches: 12
# >>>17 Crawling team: Verona, page: 1, no of matches: 18
# >>>17 Crawling team: Verona, page: 2, no of matches: 11
# >>>18 Crawling team: Inter Milan, page: 1, no of matches: 18
# >>>18 Crawling team: Inter Milan, page: 2, no of matches: 11
# >>>19 Crawling team: Atalanta, page: 1, no of matches: 14
# >>>19 Crawling team: Atalanta, page: 2, no of matches: 14
# >>>19 Crawling team: Atalanta, page: 3, no of matches: 3
# >>>20 Crawling team: Juventus, page: 1, no of matches: 14
# >>>20 Crawling team: Juventus, page: 2, no of matches: 14
# >>>20 Crawling team: Juventus, page: 3, no of matches: 2
# >>> finished.

# %%
subdriver = webdriver.Chrome()

ttl_cnt = 1
print("Total number of match: {}.".format(len(jc_match_table)))
for jc_match_id, jc_match_details in jc_match_table.items():
    print(">>>{} Crawling {}...".format(ttl_cnt, jc_match_id))
    odds_link = jc_match_details['odds_link']
    subdriver.get(odds_link)
    time.sleep(2)
    
    tblResults = subdriver.find_elements_by_class_name("tblResults")

    # Filter tblResults
    for tblResult in tblResults:
        try:
            pool_type = tblResult.get_attribute("poolkey")
            if (pool_type == "HAD"):
                home_full_odds = tblResult.find_element_by_xpath("tbody/tr[3]/td[1]").text
                draw_full_odds = tblResult.find_element_by_xpath("tbody/tr[3]/td[2]").text
                away_full_odds = tblResult.find_element_by_xpath("tbody/tr[3]/td[3]").text
                jc_full_odds = ",".join([home_full_odds, draw_full_odds, away_full_odds])
            elif (pool_type == "FHA"):
                home_half_odds = tblResult.find_element_by_xpath("tbody/tr[3]/td[1]").text
                draw_half_odds = tblResult.find_element_by_xpath("tbody/tr[3]/td[2]").text
                away_half_odds = tblResult.find_element_by_xpath("tbody/tr[3]/td[3]").text
                jc_half_odds = ",".join([home_half_odds, draw_half_odds, away_half_odds])
        except Exception as e:
            print(e)
            
    jc_match_table[jc_match_id]["jc_full_odds"] = jc_full_odds
    jc_match_table[jc_match_id]["jc_half_odds"] = jc_half_odds
    
    ttl_cnt += 1
print(">>> finished.")
driver.close()
subdriver.close()
# Out:
# Total number of match: 294.
# >>>1 Crawling Chievo,Juventus,28/01/2018...
# >>>2 Crawling Chievo,Lazio,28/08/2017...
# >>>3 Crawling Genoa,Cagliari,04/03/2018...
# >>>4 Crawling Cagliari,Crotone,10/09/2017...
# >>>5 Crawling Sassuolo,Juventus,17/09/2017...
# >>>6 Crawling Juventus,Benevento,05/11/2017...
# >>>7 Crawling AC Milan,Crotone,06/01/2018...
# >>>8 Crawling AC Milan,Cagliari,28/08/2017...
# >>>9 Crawling Crotone,Chievo,17/12/2017...
# >>>10 Crawling Lazio,Verona,20/02/2018...
# >>>11 Crawling Udinese,Roma,17/02/2018...
# >>>12 Crawling Benevento,Inter Milan,01/10/2017...
# >>>13 Crawling Napoli,Fiorentina,10/12/2017...
# >>>14 Crawling Napoli,Verona,06/01/2018...
# >>>15 Crawling Crotone,Roma,18/03/2018...
# >>>16 Crawling Napoli,Genoa,19/03/2018...
# >>>17 Crawling Chievo,Verona,22/10/2017...
# >>>18 Crawling Crotone,Verona,28/08/2017...
# >>>19 Crawling AC Milan,SPAL,21/09/2017...
# >>>20 Crawling Napoli,Lazio,11/02/2018...
# >>>21 Crawling Roma,Sampdoria,29/01/2018...
# >>>22 Crawling Fiorentina,Verona,28/01/2018...
# >>>23 Crawling SPAL,Genoa,29/10/2017...
# >>>24 Crawling Juventus,Atalanta,15/03/2018...
# >>>25 Crawling Udinese,Napoli,26/11/2017...
# >>>26 Crawling SPAL,Verona,10/12/2017...
# >>>27 Crawling Atalanta,Chievo,04/02/2018...
# >>>28 Crawling Roma,Lazio,19/11/2017...
# >>>29 Crawling Atalanta,Sassuolo,10/09/2017...
# >>>30 Crawling Sampdoria,AC Torino,04/02/2018...
# >>>31 Crawling Sampdoria,Udinese,25/02/2018...
# >>>32 Crawling SPAL,Cagliari,17/09/2017...
# >>>33 Crawling Atalanta,Verona,26/10/2017...
# >>>34 Crawling Lazio,Udinese,05/11/2017...
# >>>35 Crawling Bologna,Inter Milan,20/09/2017...
# >>>36 Crawling Udinese,Chievo,21/08/2017...
# >>>37 Crawling Sampdoria,Lazio,04/12/2017...
# >>>38 Crawling Bologna,Fiorentina,04/02/2018...
# >>>39 Crawling Sampdoria,Atalanta,15/10/2017...
# >>>40 Crawling Genoa,Roma,26/11/2017...
# >>>41 Crawling Bologna,AC Torino,21/08/2017...
# >>>42 Crawling Crotone,Udinese,05/12/2017...
# >>>43 Crawling Benevento,Lazio,29/10/2017...
# >>>44 Crawling Inter Milan,AC Milan,16/10/2017...
# >>>45 Crawling Napoli,Benevento,17/09/2017...
# >>>46 Crawling Benevento,Crotone,18/02/2018...
# >>>47 Crawling Verona,Bologna,21/11/2017...
# >>>48 Crawling Cagliari,Sassuolo,21/09/2017...
# >>>49 Crawling Inter Milan,Lazio,31/12/2017...
# >>>50 Crawling Lazio,Udinese,25/01/2018...
# >>>51 Crawling Fiorentina,Roma,05/11/2017...
# >>>52 Crawling Juventus,Cagliari,20/08/2017...
# >>>53 Crawling Sampdoria,Crotone,22/10/2017...
# >>>54 Crawling Sampdoria,Verona,11/02/2018...
# >>>55 Crawling SPAL,Udinese,28/08/2017...
# >>>56 Crawling Napoli,Atalanta,28/08/2017...
# >>>57 Crawling Cagliari,Chievo,24/09/2017...
# >>>58 Crawling Fiorentina,Bologna,17/09/2017...
# >>>59 Crawling SPAL,Juventus,18/03/2018...
# >>>60 Crawling Sassuolo,Cagliari,11/02/2018...
# >>>61 Crawling AC Torino,Verona,01/10/2017...
# >>>62 Crawling Roma,Atalanta,07/01/2018...
# >>>63 Crawling Atalanta,Bologna,22/10/2017...
# >>>64 Crawling AC Milan,Roma,02/10/2017...
# >>>65 Crawling Cagliari,SPAL,04/02/2018...
# >>>66 Crawling Atalanta,Napoli,21/01/2018...
# >>>67 Crawling Genoa,Sampdoria,05/11/2017...
# >>>68 Crawling Inter Milan,Roma,22/01/2018...
# >>>69 Crawling Verona,Sampdoria,21/09/2017...
# >>>70 Crawling Cagliari,Fiorentina,23/12/2017...
# >>>71 Crawling AC Torino,Benevento,28/01/2018...
# >>>72 Crawling Roma,Inter Milan,27/08/2017...
# >>>73 Crawling Cagliari,Juventus,07/01/2018...
# >>>74 Crawling Udinese,AC Milan,04/02/2018...
# >>>75 Crawling Benevento,SPAL,18/12/2017...
# >>>76 Crawling Juventus,Genoa,23/01/2018...
# >>>77 Crawling Napoli,SPAL,18/02/2018...
# >>>78 Crawling Udinese,Verona,23/12/2017...
# >>>79 Crawling Juventus,Atalanta,26/02/2018...
# >>>80 Crawling SPAL,Inter Milan,28/01/2018...
# >>>81 Crawling AC Milan,Lazio,29/01/2018...
# >>>82 Crawling Sampdoria,SPAL,30/12/2017...
# >>>83 Crawling Crotone,Cagliari,28/01/2018...
# >>>84 Crawling Inter Milan,Genoa,24/09/2017...
# >>>85 Crawling Juventus,Inter Milan,10/12/2017...
# >>>86 Crawling Fiorentina,Genoa,17/12/2017...
# >>>87 Crawling Udinese,Juventus,23/10/2017...
# >>>88 Crawling Crotone,AC Milan,21/08/2017...
# >>>89 Crawling Atalanta,Juventus,02/10/2017...
# >>>90 Crawling AC Torino,Sassuolo,28/08/2017...
# >>>91 Crawling SPAL,AC Milan,10/02/2018...
# >>>92 Crawling Lazio,Fiorentina,27/11/2017...
# >>>93 Crawling Lazio,SPAL,21/08/2017...
# >>>94 Crawling Sampdoria,Inter Milan,18/03/2018...
# >>>95 Crawling Inter Milan,Benevento,25/02/2018...
# >>>96 Crawling Atalanta,Fiorentina,19/02/2018...
# >>>97 Crawling Sassuolo,Atalanta,28/01/2018...
# >>>98 Crawling Crotone,Genoa,19/11/2017...
# >>>99 Crawling AC Torino,Udinese,11/02/2018...
# >>>100 Crawling Napoli,Cagliari,01/10/2017...
# >>>101 Crawling Benevento,Chievo,30/12/2017...
# >>>102 Crawling AC Milan,Inter Milan,05/03/2018...
# >>>103 Crawling Verona,Crotone,21/01/2018...
# >>>104 Crawling Bologna,Atalanta,11/03/2018...
# >>>105 Crawling Fiorentina,Juventus,10/02/2018...
# >>>106 Crawling AC Milan,AC Torino,26/11/2017...
# >>>107 Crawling Genoa,Udinese,28/01/2018...
# >>>108 Crawling Udinese,Sassuolo,18/03/2018...
# >>>109 Crawling Atalanta,Sampdoria,04/03/2018...
# >>>110 Crawling Juventus,Chievo,10/09/2017...
# >>>111 Crawling Chievo,Fiorentina,01/10/2017...
# >>>112 Crawling Udinese,Cagliari,19/11/2017...
# >>>113 Crawling SPAL,Sassuolo,22/10/2017...
# >>>114 Crawling Fiorentina,Chievo,25/02/2018...
# >>>115 Crawling Napoli,Inter Milan,22/10/2017...
# >>>116 Crawling Verona,Genoa,05/12/2017...
# >>>117 Crawling Genoa,Lazio,18/09/2017...
# >>>118 Crawling Benevento,Bologna,27/08/2017...
# >>>119 Crawling Verona,AC Torino,25/02/2018...
# >>>120 Crawling Bologna,Lazio,26/10/2017...
# >>>121 Crawling Bologna,Genoa,25/02/2018...
# >>>122 Crawling Verona,Chievo,11/03/2018...
# >>>123 Crawling Genoa,Atalanta,12/12/2017...
# >>>124 Crawling Lazio,Bologna,19/03/2018...
# >>>125 Crawling Verona,AC Milan,17/12/2017...
# >>>126 Crawling Inter Milan,Napoli,12/03/2018...
# >>>127 Crawling AC Milan,Juventus,29/10/2017...
# >>>128 Crawling Genoa,Inter Milan,18/02/2018...
# >>>129 Crawling Juventus,Lazio,15/10/2017...
# >>>130 Crawling Verona,Juventus,31/12/2017...
# >>>131 Crawling Sampdoria,AC Milan,24/09/2017...
# >>>132 Crawling Inter Milan,Fiorentina,21/08/2017...
# >>>133 Crawling Juventus,SPAL,26/10/2017...
# >>>134 Crawling SPAL,Lazio,06/01/2018...
# >>>135 Crawling Genoa,Atalanta,13/12/2017...
# >>>136 Crawling Chievo,AC Milan,26/10/2017...
# >>>137 Crawling Benevento,Verona,04/03/2018...
# >>>138 Crawling Atalanta,Benevento,28/11/2017...
# >>>139 Crawling AC Milan,Sampdoria,19/02/2018...
# >>>140 Crawling Sassuolo,Crotone,11/12/2017...
# >>>141 Crawling Inter Milan,Bologna,11/02/2018...
# >>>142 Crawling Benevento,Fiorentina,22/10/2017...
# >>>143 Crawling Udinese,AC Torino,21/09/2017...
# >>>144 Crawling Roma,SPAL,02/12/2017...
# >>>145 Crawling Chievo,Roma,10/12/2017...
# >>>146 Crawling Crotone,Inter Milan,16/09/2017...
# >>>147 Crawling Crotone,Napoli,30/12/2017...
# >>>148 Crawling Roma,Napoli,15/10/2017...
# >>>149 Crawling Fiorentina,Sampdoria,28/08/2017...
# >>>150 Crawling Fiorentina,AC Milan,30/12/2017...
# >>>151 Crawling Benevento,AC Torino,11/09/2017...
# >>>152 Crawling Bologna,SPAL,15/10/2017...
# >>>153 Crawling AC Milan,Udinese,17/09/2017...
# >>>154 Crawling AC Torino,Chievo,19/11/2017...
# >>>155 Crawling Sampdoria,Benevento,21/08/2017...
# >>>156 Crawling Atalanta,Cagliari,30/12/2017...
# >>>157 Crawling Chievo,Sassuolo,04/03/2018...
# >>>158 Crawling Fiorentina,Inter Milan,06/01/2018...
# >>>159 Crawling Napoli,Roma,04/03/2018...
# >>>160 Crawling Juventus,Sassuolo,04/02/2018...
# >>>161 Crawling Napoli,Juventus,02/12/2017...
# >>>162 Crawling Verona,Inter Milan,31/10/2017...
# >>>163 Crawling Inter Milan,Crotone,04/02/2018...
# >>>164 Crawling SPAL,Crotone,01/10/2017...
# >>>165 Crawling Udinese,Atalanta,29/10/2017...
# >>>166 Crawling Verona,Lazio,24/09/2017...
# >>>167 Crawling Fiorentina,Udinese,15/10/2017...
# >>>168 Crawling Sassuolo,Lazio,25/02/2018...
# >>>169 Crawling SPAL,Fiorentina,19/11/2017...
# >>>170 Crawling Fiorentina,Atalanta,25/09/2017...
# >>>171 Crawling Sassuolo,SPAL,11/03/2018...
# >>>172 Crawling Bologna,Cagliari,03/12/2017...
# >>>173 Crawling Crotone,Fiorentina,29/10/2017...
# >>>174 Crawling AC Torino,Crotone,04/03/2018...
# >>>175 Crawling Sampdoria,Juventus,19/11/2017...
# >>>176 Crawling Bologna,Crotone,05/11/2017...
# >>>177 Crawling Inter Milan,Atalanta,20/11/2017...
# >>>178 Crawling Juventus,Fiorentina,21/09/2017...
# >>>179 Crawling Chievo,Napoli,05/11/2017...
# >>>180 Crawling Lazio,Sassuolo,01/10/2017...
# >>>181 Crawling Sampdoria,Sassuolo,17/12/2017...
# >>>182 Crawling Sassuolo,Bologna,25/09/2017...
# >>>183 Crawling AC Milan,Atalanta,24/12/2017...
# >>>184 Crawling Atalanta,Crotone,21/09/2017...
# >>>185 Crawling Inter Milan,AC Torino,05/11/2017...
# >>>186 Crawling Bologna,Sampdoria,25/11/2017...
# >>>187 Crawling Lazio,Chievo,21/01/2018...
# >>>188 Crawling Udinese,SPAL,21/01/2018...
# >>>189 Crawling Bologna,Sassuolo,18/02/2018...
# >>>190 Crawling Roma,AC Milan,26/02/2018...
# >>>191 Crawling Benevento,Sassuolo,19/11/2017...
# >>>192 Crawling Udinese,Sampdoria,01/10/2017...
# >>>193 Crawling Chievo,Cagliari,18/02/2018...
# >>>194 Crawling Napoli,Sampdoria,23/12/2017...
# >>>195 Crawling AC Milan,Genoa,22/10/2017...
# >>>196 Crawling Sassuolo,Chievo,15/10/2017...
# >>>197 Crawling Lazio,Crotone,23/12/2017...
# >>>198 Crawling Verona,Benevento,17/10/2017...
# >>>199 Crawling Genoa,Benevento,23/12/2017...
# >>>200 Crawling Juventus,Udinese,11/03/2018...
# >>>201 Crawling Verona,Roma,04/02/2018...
# >>>202 Crawling Inter Milan,Chievo,03/12/2017...
# >>>203 Crawling Lazio,AC Milan,10/09/2017...
# >>>204 Crawling Lazio,Genoa,06/02/2018...
# >>>205 Crawling Verona,Fiorentina,10/09/2017...
# >>>206 Crawling Roma,AC Torino,10/03/2018...
# >>>207 Crawling Chievo,Atalanta,18/09/2017...
# >>>208 Crawling Inter Milan,Sampdoria,25/10/2017...
# >>>209 Crawling AC Milan,Bologna,11/12/2017...
# >>>210 Crawling Benevento,Napoli,05/02/2018...
# >>>211 Crawling AC Milan,Chievo,18/03/2018...
# >>>212 Crawling Sassuolo,AC Torino,21/01/2018...
# >>>213 Crawling Sassuolo,Udinese,26/10/2017...
# >>>214 Crawling Inter Milan,Udinese,16/12/2017...
# >>>215 Crawling Sassuolo,Verona,26/11/2017...
# >>>216 Crawling Cagliari,Genoa,15/10/2017...
# >>>217 Crawling Genoa,Sassuolo,06/01/2018...
# >>>218 Crawling Bologna,Napoli,11/09/2017...
# >>>219 Crawling Genoa,Bologna,01/10/2017...
# >>>220 Crawling Verona,Napoli,20/08/2017...
# >>>221 Crawling AC Torino,Bologna,06/01/2018...
# >>>222 Crawling Napoli,Bologna,28/01/2018...
# >>>223 Crawling Fiorentina,Sassuolo,03/12/2017...
# >>>224 Crawling Benevento,AC Milan,03/12/2017...
# >>>225 Crawling Atalanta,Lazio,18/12/2017...
# >>>226 Crawling Napoli,AC Milan,19/11/2017...
# >>>227 Crawling Roma,Crotone,26/10/2017...
# >>>228 Crawling Fiorentina,Benevento,11/03/2018...
# >>>229 Crawling Bologna,Udinese,30/12/2017...
# >>>230 Crawling Cagliari,Napoli,27/02/2018...
# >>>231 Crawling Chievo,Genoa,11/02/2018...
# >>>232 Crawling Roma,Cagliari,17/12/2017...
# >>>233 Crawling Inter Milan,SPAL,10/09/2017...
# >>>234 Crawling Napoli,Sassuolo,29/10/2017...
# >>>235 Crawling Cagliari,Benevento,26/10/2017...
# >>>236 Crawling Genoa,Chievo,21/09/2017...
# >>>237 Crawling Crotone,AC Torino,15/10/2017...
# >>>238 Crawling AC Torino,Atalanta,03/12/2017...
# >>>239 Crawling Bologna,Juventus,17/12/2017...
# >>>240 Crawling Bologna,Benevento,21/01/2018...
# >>>241 Crawling Chievo,SPAL,26/11/2017...
# >>>242 Crawling Cagliari,AC Milan,22/01/2018...
# >>>243 Crawling Roma,Bologna,29/10/2017...
# >>>244 Crawling Sassuolo,AC Milan,06/11/2017...
# >>>245 Crawling Chievo,Bologna,23/12/2017...
# >>>246 Crawling Sassuolo,Inter Milan,23/12/2017...
# >>>247 Crawling AC Torino,Fiorentina,18/03/2018...
# >>>248 Crawling Benevento,Roma,21/09/2017...
# >>>249 Crawling AC Torino,Cagliari,30/10/2017...
# >>>250 Crawling Roma,Sassuolo,30/12/2017...
# >>>251 Crawling Benevento,Cagliari,18/03/2018...
# >>>252 Crawling Atalanta,Roma,21/08/2017...
# >>>253 Crawling Cagliari,Sampdoria,10/12/2017...
# >>>254 Crawling SPAL,Bologna,03/03/2018...
# >>>255 Crawling Sampdoria,Roma,10/09/2017...
# >>>256 Crawling Cagliari,Inter Milan,26/11/2017...
# >>>257 Crawling Crotone,Sampdoria,11/03/2018...
# >>>258 Crawling Lazio,AC Torino,12/12/2017...
# >>>259 Crawling Udinese,Fiorentina,04/03/2018...
# >>>260 Crawling Cagliari,Lazio,11/03/2018...
# >>>261 Crawling Sampdoria,Fiorentina,21/01/2018...
# >>>262 Crawling Benevento,Sampdoria,06/01/2018...
# >>>263 Crawling Lazio,Cagliari,23/10/2017...
# >>>264 Crawling Genoa,Juventus,27/08/2017...
# >>>265 Crawling Genoa,Napoli,26/10/2017...
# >>>266 Crawling Juventus,Roma,24/12/2017...
# >>>267 Crawling Chievo,Udinese,06/01/2018...
# >>>268 Crawling Sampdoria,Chievo,29/10/2017...
# >>>269 Crawling Roma,Udinese,23/09/2017...
# >>>270 Crawling AC Torino,Sampdoria,17/09/2017...
# >>>271 Crawling Verona,Atalanta,18/03/2018...
# >>>272 Crawling AC Torino,Roma,22/10/2017...
# >>>273 Crawling Lazio,Napoli,21/09/2017...
# >>>274 Crawling Udinese,Genoa,10/09/2017...
# >>>275 Crawling AC Torino,Napoli,17/12/2017...
# >>>276 Crawling Crotone,SPAL,25/02/2018...
# >>>277 Crawling SPAL,Napoli,24/09/2017...
# >>>278 Crawling Fiorentina,AC Torino,26/10/2017...
# >>>279 Crawling Genoa,AC Milan,12/03/2018...
# >>>280 Crawling Crotone,Atalanta,11/02/2018...
# >>>281 Crawling AC Torino,Genoa,30/12/2017...
# >>>282 Crawling Cagliari,Verona,05/11/2017...
# >>>283 Crawling Juventus,AC Torino,24/09/2017...
# >>>284 Crawling Atalanta,SPAL,06/11/2017...
# >>>285 Crawling Lazio,Juventus,04/03/2018...
# >>>286 Crawling Roma,Verona,17/09/2017...
# >>>287 Crawling AC Torino,Juventus,18/02/2018...
# >>>288 Crawling Udinese,Benevento,10/12/2017...
# >>>289 Crawling Sassuolo,Genoa,21/08/2017...
# >>>290 Crawling Roma,Benevento,12/02/2018...
# >>>291 Crawling Crotone,Benevento,24/09/2017...
# >>>292 Crawling Juventus,Crotone,27/11/2017...
# >>>293 Crawling SPAL,AC Torino,23/12/2017...
# >>>294 Crawling Sampdoria,Roma,25/01/2018...
# >>> finished.

# %%
with open('./{}-{}/jc_match_odds_table.json'.format(from_year, to_year),'w') as fp:
    json.dump(jc_match_table, fp, indent=4)

# %% [markdown]
# # Add jc_name to current existed Whoscored team table

# %%
import json

from_year = "2017"
to_year = "2018"

with open('./{}-{}/team_instances_table.json','r') as fp:
    team_table = json.load(fp)

# %%
# Add jc_name to current team table
for team_id, team_info in team_table.items():
    if team_info["team_name"] == 'Torino':
        team_info["jc_name"] = 'AC Torino'
    elif team_info["team_name"] == 'Inter':
        team_info["jc_name"] = 'Inter Milan'
    elif team_inf0["team_name"] == "SPAL 2013":
        team_info["jc_name"] == "SPAL"
    else:
        team_info["jc_name"] = team_info["team_name"]
        
with open('./2017-2018/team_instances_table.json','w') as fp:
    json.dump(team_table, fp, indent=4)

# %% [markdown]
# # Merge jc_match_table to team_instances_table

# %%
import re
import time
from tqdm import tqdm_notebook as tqdm
from datetime import datetime, timedelta
import json

from_year = "2017"
to_year = "2018"

with open('./{}-{}/match_instances_table.json'.format(from_year, to_year),'r') as fp:
    match_table = json.load(fp)
with open('./{}-{}/team_instances_table.json'.format(from_year, to_year),'r') as fp:
    team_table = json.load(fp)
with open('./{}-{}/jc_match_odds_table.json'.format(from_year, to_year),'r') as fp:
    jc_match_table = json.load(fp)

# %%
jc_match_tuple_used = []
for ws_match_id, ws_match_details in match_table.items():
    ws_home_team = team_table[str(ws_match_details['home_team_id'])]['jc_name']
    ws_away_team = team_table[str(ws_match_details['away_team_id'])]['jc_name']
    ws_date = datetime.strptime(ws_match_details['match_datetime'], "%a, %d-%b-%y, %H:%M")
    ws_date = ws_date + timedelta(hours=8)
    offsetted_ws_date = datetime(year=ws_date.year,month=ws_date.month,day=ws_date.day)
    ws_match_tuple = (ws_home_team, ws_away_team, offsetted_ws_date)
    
    match_table[ws_match_id]["jc_odds_link"] = None
    match_table[ws_match_id]["jc_full_odds"] = None
    match_table[ws_match_id]["jc_half_odds"] = None
    for jc_match_id, jc_match_details in jc_match_table.items():
        jc_home_team = jc_match_id.split(",")[0]
        jc_away_team = jc_match_id.split(",")[1]
        jc_date = datetime.strptime(jc_match_id.split(",")[2], "%d/%m/%Y")
        jc_match_tuple = (jc_home_team, jc_away_team, jc_date)
        
        if ws_match_tuple == jc_match_tuple:
            match_table[ws_match_id]["jc_odds_link"] = jc_match_details["odds_link"]
            match_table[ws_match_id]["jc_full_odds"] = jc_match_details["jc_full_odds"]
            match_table[ws_match_id]["jc_half_odds"] = jc_match_details["jc_half_odds"]
            jc_match_tuple_used.append(jc_match_tuple)
            break
            
print(">>> finished.")
# Out:
# >>> finished.

# %%
with open('match_instances_table.json','w') as fp:
    json.dump(match_table, fp, indent=4)

# %%
[1,5,3][::2]
# Out:
# [1, 3]

# %% [markdown]
# # Calculate JC winning cases

# %%
import json
import copy
import matplotlib.pyplot as plt
import numpy as np

from_year = "2017"
to_year = "2018"

with open('./{}-{}/match_instances_table.json'.format(from_year, to_year),'r') as fp:
    match_table = json.load(fp)
    
def calculateJCWinningAcc(match_odds_table, png_path,start=10, step=10, draw_as_event=False):
    no_match = len(match_odds_table)
    match_table = 
    
    for match_id, match_details in match_table.items():
        try:
            home_half_time_result = int(match_details["half_time_result"].split(" : ")[0])
            away_half_time_result = int(match_details["half_time_result"].split(" : ")[1])
            home_full_time_result = int(match_details["result"].split(" : ")[0])
            away_full_time_result = int(match_details["result"].split(" : ")[1])
            
            if (draw_as_event):
                jc_half_odds = match_details["jc_half_odds"].split(",")
                jc_full_odds = match_details["jc_full_odds"].split(",")
            else:
                jc_half_odds = match_details["jc_half_odds"].split(",")[::2]
                jc_full_odds = match_details["jc_full_odds"].split(",")[::2]
                
            jc_half_predicted = jc_half_odds.index(min(jc_half_odds))
            jc_full_predicted = jc_full_odds.index(min(jc_full_odds))

            if (draw_as_event):            
                if (home_half_time_result < away_half_time_result and jc_half_predicted == 2):
                    match_table[match_id]['jc_half_win'] = True
                elif (home_half_time_result > away_half_time_result and jc_half_predicted == 0):
                    match_table[match_id]['jc_half_win'] = True
                elif (home_half_time_result == away_half_time_result and jc_half_predicted == 1):
                    match_table[match_id]['jc_half_win'] = True
                else:
                    match_table[match_id]['jc_half_win'] = False

                if (home_full_time_result < away_full_time_result and jc_full_predicted == 2):
                    match_table[match_id]['jc_full_win'] = True
                elif (home_full_time_result > away_full_time_result and jc_full_predicted == 0):
                    match_table[match_id]['jc_full_win'] = True
                elif (home_full_time_result == away_full_time_result and jc_full_predicted == 1):
                    match_table[match_id]['jc_full_win'] = True
                else:
                    match_table[match_id]['jc_full_win'] = False                
            else:
                if (home_half_time_result < away_half_time_result and jc_half_predicted == 1):
                    match_table[match_id]['jc_half_win'] = True
                elif (home_half_time_result > away_half_time_result and jc_half_predicted == 0):
                    match_table[match_id]['jc_half_win'] = True
                elif (home_half_time_result == away_half_time_result):
                    match_table[match_id]['jc_half_win'] = True
                else:
                    match_table[match_id]['jc_half_win'] = False

                if (home_full_time_result < away_full_time_result and jc_full_predicted == 1):
                    match_table[match_id]['jc_full_win'] = True
                elif (home_full_time_result > away_full_time_result and jc_full_predicted == 0):
                    match_table[match_id]['jc_full_win'] = True
                elif (home_full_time_result == away_full_time_result):
                    match_table[match_id]['jc_full_win'] = True
                else:
                    match_table[match_id]['jc_full_win'] = False

        except:
            no_match -= 1
            match_table[match_id]['jc_half_win'] = None
            match_table[match_id]['jc_full_win'] = None
            print("No odds found for {}.".format(match_id))

    # Calculate average accuracy
    jc_half_correct_predicted = 0
    jc_full_correct_predicted = 0

    for _, match_details in match_table.items():
        if (match_details['jc_half_win']):
            jc_half_correct_predicted += 1
        if (match_details['jc_full_win']):
            jc_full_correct_predicted += 1

    jc_half_acc = jc_half_correct_predicted/no_match
    jc_full_acc = jc_full_correct_predicted/no_match
            
    if (draw_as_event):
        print(">>> {}-{} JC half acc (include draw): {}".format(from_year, to_year, jc_half_acc))
        print(">>> {}-{} JC full acc (include draw): {}".format(from_year, to_year, jc_full_acc))
    else:
        print(">>> {}-{} JC half acc (binary): {}".format(from_year, to_year, jc_half_acc))
        print(">>> {}-{} JC full acc (binary): {}".format(from_year, to_year, jc_full_acc))       
    
    plotAccFig(match_table, start=start, step=step, png_path=png_path)
    
    return match_table, jc_half_acc, jc_full_acc

def plotAccFig(match_odds_table, png_path, start=10, step=10, compared_odds_table=None):
    match_date_half_full = []
    
    for _, match_details in match_odds_table.items():
        match_date = datetime.strptime(match_details['match_datetime'], "%a, %d-%b-%y, %H:%M")
        jc_half_win = match_details['jc_half_win']
        jc_full_win = match_details['jc_full_win']
        match_date_half_full.append((match_date, jc_half_win, jc_full_win))

    match_date_half_full = sorted(match_date_half_full, key= lambda x:x[0])
    match_acc = []
    half_cnt = 0
    full_cnt = 0
    cumulative_half_correct = 0
    cumulative_full_correct = 0
        
    for date, half, full in match_date_half_full:
        half_cnt += 1
        full_cnt += 1
        if (half):
            cumulative_half_correct += 1
        if (full):
            cumulative_full_correct += 1
        match_acc.append((date, cumulative_half_correct/half_cnt, cumulative_full_correct/full_cnt))
        
    if (compared_odds_table):
        compared_match_date_half_full = []
        
        for _, match_details in compared_odds_table.items():
            match_date = datetime.strptime(match_details['match_datetime'], "%a, %d-%b-%y, %H:%M")
            jc_half_win = match_details['jc_half_win']
            jc_full_win = match_details['jc_full_win']
            compared_match_date_half_full.append((match_date, jc_half_win, jc_full_win))

        compared_match_date_half_full = sorted(compared_match_date_half_full, key= lambda x:x[0])
        compared_match_acc = []
        half_cnt = 0
        full_cnt = 0
        cumulative_half_correct = 0
        cumulative_full_correct = 0        

        for date, half, full in match_date_half_full:
            half_cnt += 1
            full_cnt += 1
            if (half):
                cumulative_half_correct += 1
            if (full):
                cumulative_full_correct += 1
            compared_match_acc.append((date, cumulative_half_correct/half_cnt, cumulative_full_correct/full_cnt))
        
    match_dates = [date for date,_,_ in match_acc][start::step]
    
    if (compared_odds_table):
        match_half_acc = [half for _,half,_ in match_acc][start::step]
        compared_half_acc = [half for _,half,_ in compared_match_acc][start::step]
        half_acc = np.array(match_half_acc) - np.array(compared_half_acc)
        
        match_full_acc = [full for _,_,full in match_acc][start::step]
        compared_full_acc = [full for _,_,full in compared_match_acc][start::step]
        full_acc = np.array(match_full_acc) - np.array(compared_full_acc)
    else:
        half_acc = [half for _,half,_ in match_acc][start::step]
        full_acc = [full for _,_,full in match_acc][start::step]
        
    # plot
    plt.title("{}-{} Jockey Club Half and Full Accuracy".format(min(match_dates).year, max(match_dates).year))
    plt.plot(match_dates,half_acc,color='red',label='half acc')
    plt.plot(match_dates,full_acc,color='blue',label='full acc')
    plt.legend()
    # beautify the x-labels
    plt.gcf().autofmt_xdate()
    plt.savefig('./{}-{}/'.format(min(match_dates).year, max(match_dates).year) + png_path)
    plt.show()

# %%
draw_event
# Out:
# True

# %%
binary_event
# Out:
# {'1225138': {'away_team_id': 84,
#   'half_time_result': '0 : 1',
#   'home_team_id': 300,
#   'jc_full_odds': '2.70,3.25,2.25',
#   'jc_full_win': True,
#   'jc_half_odds': '3.25,2.12,2.85',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117316',
#   'match_datetime': 'Sun, 20-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225138/Live/Italy-Serie-A-2017-2018-Atalanta-Roma',
#   'result': '0 : 1'},
#  '1225139': {'away_team_id': 72,
#   'half_time_result': '1 : 1',
#   'home_team_id': 71,
#   'jc_full_odds': '2.80,3.10,2.25',
#   'jc_full_win': True,
#   'jc_half_odds': '3.40,2.05,2.90',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117333',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225139/Live/Italy-Serie-A-2017-2018-Bologna-Torino',
#   'result': '1 : 1'},
#  '1225140': {'away_team_id': 80,
#   'half_time_result': '0 : 3',
#   'home_team_id': 779,
#   'jc_full_odds': '6.10,3.95,1.42',
#   'jc_full_win': True,
#   'jc_half_odds': '5.80,2.28,1.93',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117334',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225140/Live/Italy-Serie-A-2017-2018-Crotone-AC-Milan',
#   'result': '0 : 3'},
#  '1225141': {'away_team_id': 276,
#   'half_time_result': '0 : 2',
#   'home_team_id': 76,
#   'jc_full_odds': '7.00,4.35,1.33',
#   'jc_full_win': True,
#   'jc_half_odds': '6.40,2.40,1.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117434',
#   'match_datetime': 'Sat, 19-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225141/Live/Italy-Serie-A-2017-2018-Verona-Napoli',
#   'result': '1 : 3'},
#  '1225142': {'away_team_id': 73,
#   'half_time_result': '2 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '1.44,3.90,5.80',
#   'jc_full_win': True,
#   'jc_half_odds': '1.93,2.28,5.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117332',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225142/Live/Italy-Serie-A-2017-2018-Inter-Fiorentina',
#   'result': '3 : 0'},
#  '1225143': {'away_team_id': 78,
#   'half_time_result': '2 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.07,7.50,22.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.39,2.95,14.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117413',
#   'match_datetime': 'Sat, 19-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225143/Live/Italy-Serie-A-2017-2018-Juventus-Cagliari',
#   'result': '3 : 0'},
#  '1225144': {'away_team_id': 1502,
#   'half_time_result': '0 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '1.19,5.30,10.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.60,2.60,8.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117335',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225144/Live/Italy-Serie-A-2017-2018-Lazio-SPAL-2013',
#   'result': '0 : 0'},
#  '1225145': {'away_team_id': 1503,
#   'half_time_result': '1 : 1',
#   'home_team_id': 271,
#   'jc_full_odds': '1.50,3.65,5.50',
#   'jc_full_win': True,
#   'jc_half_odds': '2.05,2.20,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117336',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225145/Live/Italy-Serie-A-2017-2018-Sampdoria-Benevento',
#   'result': '2 : 1'},
#  '1225146': {'away_team_id': 278,
#   'half_time_result': '0 : 0',
#   'home_team_id': 2889,
#   'jc_full_odds': '1.83,3.30,3.65',
#   'jc_full_win': True,
#   'jc_half_odds': '2.40,2.10,4.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117337',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225146/Live/Italy-Serie-A-2017-2018-Sassuolo-Genoa',
#   'result': '0 : 0'},
#  '1225147': {'away_team_id': 267,
#   'half_time_result': '1 : 1',
#   'home_team_id': 86,
#   'jc_full_odds': '1.83,3.15,3.85',
#   'jc_full_win': False,
#   'jc_half_odds': '2.45,2.02,4.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117338',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225147/Live/Italy-Serie-A-2017-2018-Udinese-Chievo',
#   'result': '1 : 2'},
#  '1225148': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1503,
#   'jc_full_odds': '2.52,3.05,2.52',
#   'jc_full_win': False,
#   'jc_half_odds': '3.15,2.02,3.15',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117649',
#   'match_datetime': 'Sat, 26-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225148/Live/Italy-Serie-A-2017-2018-Benevento-Bologna',
#   'result': '0 : 1'},
#  '1225149': {'away_team_id': 77,
#   'half_time_result': '1 : 1',
#   'home_team_id': 267,
#   'jc_full_odds': '3.60,3.25,1.86',
#   'jc_full_win': True,
#   'jc_half_odds': '4.10,2.10,2.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117748',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225149/Live/Italy-Serie-A-2017-2018-Chievo-Lazio',
#   'result': '1 : 2'},
#  '1225150': {'away_team_id': 76,
#   'half_time_result': '0 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '2.45,2.90,2.70',
#   'jc_full_win': True,
#   'jc_half_odds': '3.10,1.92,3.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117749',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225150/Live/Italy-Serie-A-2017-2018-Crotone-Verona',
#   'result': '0 : 0'},
#  '1225151': {'away_team_id': 271,
#   'half_time_result': '0 : 2',
#   'home_team_id': 73,
#   'jc_full_odds': '1.57,3.75,4.55',
#   'jc_full_win': False,
#   'jc_half_odds': '2.08,2.30,4.70',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117750',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225151/Live/Italy-Serie-A-2017-2018-Fiorentina-Sampdoria',
#   'result': '1 : 2'},
#  '1225152': {'away_team_id': 87,
#   'half_time_result': '2 : 2',
#   'home_team_id': 278,
#   'jc_full_odds': '7.75,4.15,1.33',
#   'jc_full_win': True,
#   'jc_half_odds': '7.00,2.30,1.82',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117648',
#   'match_datetime': 'Sat, 26-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225152/Live/Italy-Serie-A-2017-2018-Genoa-Juventus',
#   'result': '2 : 4'},
#  '1225153': {'away_team_id': 78,
#   'half_time_result': '1 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '1.22,5.25,9.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.65,2.65,7.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117747',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225153/Live/Italy-Serie-A-2017-2018-AC-Milan-Cagliari',
#   'result': '2 : 1'},
#  '1225154': {'away_team_id': 300,
#   'half_time_result': '0 : 1',
#   'home_team_id': 276,
#   'jc_full_odds': '1.30,4.50,7.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.70,2.58,6.50',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117751',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225154/Live/Italy-Serie-A-2017-2018-Napoli-Atalanta',
#   'result': '3 : 1'},
#  '1225155': {'away_team_id': 75,
#   'half_time_result': '1 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '2.05,3.35,2.95',
#   'jc_full_win': False,
#   'jc_half_odds': '2.70,2.20,3.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117673',
#   'match_datetime': 'Sat, 26-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225155/Live/Italy-Serie-A-2017-2018-Roma-Inter',
#   'result': '1 : 3'},
#  '1225156': {'away_team_id': 86,
#   'half_time_result': '1 : 0',
#   'home_team_id': 1502,
#   'jc_full_odds': '2.38,3.05,2.68',
#   'jc_full_win': True,
#   'jc_half_odds': '3.10,1.95,3.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117752',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225156/Live/Italy-Serie-A-2017-2018-SPAL-2013-Udinese',
#   'result': '3 : 2'},
#  '1225157': {'away_team_id': 2889,
#   'half_time_result': '1 : 0',
#   'home_team_id': 72,
#   'jc_full_odds': '1.55,3.80,4.65',
#   'jc_full_win': True,
#   'jc_half_odds': '2.07,2.32,4.65',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117733',
#   'match_datetime': 'Sun, 27-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225157/Live/Italy-Serie-A-2017-2018-Torino-Sassuolo',
#   'result': '3 : 0'},
#  '1225158': {'away_team_id': 2889,
#   'half_time_result': '1 : 1',
#   'home_team_id': 300,
#   'jc_full_odds': '1.50,3.80,5.20',
#   'jc_full_win': True,
#   'jc_half_odds': '2.00,2.25,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118173',
#   'match_datetime': 'Sun, 10-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225158/Live/Italy-Serie-A-2017-2018-Atalanta-Sassuolo',
#   'result': '2 : 1'},
#  '1225159': {'away_team_id': 72,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1503,
#   'jc_full_odds': '3.40,3.55,1.83',
#   'jc_full_win': True,
#   'jc_half_odds': '3.75,2.30,2.35',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118194',
#   'match_datetime': 'Sun, 10-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225159/Live/Italy-Serie-A-2017-2018-Benevento-Torino',
#   'result': '0 : 1'},
#  '1225160': {'away_team_id': 276,
#   'half_time_result': '0 : 0',
#   'home_team_id': 71,
#   'jc_full_odds': '7.80,4.65,1.28',
#   'jc_full_win': True,
#   'jc_half_odds': '6.80,2.50,1.72',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118212',
#   'match_datetime': 'Sun, 10-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225160/Live/Italy-Serie-A-2017-2018-Bologna-Napoli',
#   'result': '0 : 3'},
#  '1225161': {'away_team_id': 779,
#   'half_time_result': '1 : 0',
#   'home_team_id': 78,
#   'jc_full_odds': '1.57,3.50,5.00',
#   'jc_full_win': True,
#   'jc_half_odds': '2.12,2.17,5.10',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118174',
#   'match_datetime': 'Sun, 10-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225161/Live/Italy-Serie-A-2017-2018-Cagliari-Crotone',
#   'result': '1 : 0'},
#  '1225162': {'away_team_id': 73,
#   'half_time_result': '0 : 3',
#   'home_team_id': 76,
#   'jc_full_odds': '3.55,3.30,1.85',
#   'jc_full_win': True,
#   'jc_half_odds': '4.15,2.08,2.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118176',
#   'match_datetime': 'Sun, 10-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225162/Live/Italy-Serie-A-2017-2018-Verona-Fiorentina',
#   'result': '0 : 5'},
#  '1225163': {'away_team_id': 1502,
#   'half_time_result': '1 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '1.13,6.30,12.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.48,2.88,9.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118161',
#   'match_datetime': 'Sun, 10-Sep-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225163/Live/Italy-Serie-A-2017-2018-Inter-SPAL-2013',
#   'result': '2 : 0'},
#  '1225164': {'away_team_id': 267,
#   'half_time_result': '1 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.17,5.70,11.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.58,2.65,8.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118104',
#   'match_datetime': 'Sat, 09-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225164/Live/Italy-Serie-A-2017-2018-Juventus-Chievo',
#   'result': '3 : 0'},
#  '1225165': {'away_team_id': 80,
#   'half_time_result': '2 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '2.12,3.30,2.87',
#   'jc_full_win': True,
#   'jc_half_odds': '2.75,2.13,3.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118172',
#   'match_datetime': 'Sun, 10-Sep-17, 15:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225165/Live/Italy-Serie-A-2017-2018-Lazio-AC-Milan',
#   'result': '4 : 1'},
#  '1225166': {'away_team_id': 84,
#   'half_time_result': '1 : 0',
#   'home_team_id': 271,
#   'jc_full_odds': '3.60,3.55,1.78',
#   'jc_full_win': True,
#   'jc_half_odds': '3.90,2.28,2.30',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=122888',
#   'match_datetime': 'Wed, 24-Jan-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225166/Live/Italy-Serie-A-2017-2018-Sampdoria-Roma',
#   'result': '1 : 1'},
#  '1225167': {'away_team_id': 278,
#   'half_time_result': '1 : 0',
#   'home_team_id': 86,
#   'jc_full_odds': '2.22,3.10,2.85',
#   'jc_full_win': True,
#   'jc_half_odds': '2.85,2.00,3.60',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118175',
#   'match_datetime': 'Sun, 10-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225167/Live/Italy-Serie-A-2017-2018-Udinese-Genoa',
#   'result': '1 : 0'},
#  '1225168': {'away_team_id': 300,
#   'half_time_result': '0 : 0',
#   'home_team_id': 267,
#   'jc_full_odds': '2.72,3.00,2.37',
#   'jc_full_win': True,
#   'jc_half_odds': '3.55,1.95,3.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118517',
#   'match_datetime': 'Sun, 17-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225168/Live/Italy-Serie-A-2017-2018-Chievo-Atalanta',
#   'result': '1 : 1'},
#  '1225169': {'away_team_id': 75,
#   'half_time_result': '0 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '7.75,4.45,1.30',
#   'jc_full_win': True,
#   'jc_half_odds': '6.25,2.42,1.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118389',
#   'match_datetime': 'Sat, 16-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225169/Live/Italy-Serie-A-2017-2018-Crotone-Inter',
#   'result': '0 : 2'},
#  '1225170': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '1.43,3.95,5.80',
#   'jc_full_win': True,
#   'jc_half_odds': '1.93,2.30,5.75',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118432',
#   'match_datetime': 'Sat, 16-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225170/Live/Italy-Serie-A-2017-2018-Fiorentina-Bologna',
#   'result': '2 : 1'},
#  '1225171': {'away_team_id': 77,
#   'half_time_result': '0 : 1',
#   'home_team_id': 278,
#   'jc_full_odds': '3.55,3.40,1.83',
#   'jc_full_win': True,
#   'jc_half_odds': '3.90,2.15,2.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118533',
#   'match_datetime': 'Sun, 17-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225171/Live/Italy-Serie-A-2017-2018-Genoa-Lazio',
#   'result': '2 : 3'},
#  '1225172': {'away_team_id': 86,
#   'half_time_result': '2 : 1',
#   'home_team_id': 80,
#   'jc_full_odds': '1.30,4.45,7.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.74,2.45,6.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118497',
#   'match_datetime': 'Sun, 17-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225172/Live/Italy-Serie-A-2017-2018-AC-Milan-Udinese',
#   'result': '2 : 1'},
#  '1225173': {'away_team_id': 1503,
#   'half_time_result': '4 : 0',
#   'home_team_id': 276,
#   'jc_full_odds': '1.06,8.70,18.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.35,3.35,11.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118499',
#   'match_datetime': 'Sun, 17-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225173/Live/Italy-Serie-A-2017-2018-Napoli-Benevento',
#   'result': '6 : 0'},
#  '1225174': {'away_team_id': 76,
#   'half_time_result': '2 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.13,6.50,12.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.48,2.95,9.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118454',
#   'match_datetime': 'Sat, 16-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225174/Live/Italy-Serie-A-2017-2018-Roma-Verona',
#   'result': '3 : 0'},
#  '1225175': {'away_team_id': 87,
#   'half_time_result': '0 : 1',
#   'home_team_id': 2889,
#   'jc_full_odds': '6.70,4.20,1.36',
#   'jc_full_win': True,
#   'jc_half_odds': '6.80,2.32,1.82',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118487',
#   'match_datetime': 'Sun, 17-Sep-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225175/Live/Italy-Serie-A-2017-2018-Sassuolo-Juventus',
#   'result': '1 : 3'},
#  '1225176': {'away_team_id': 78,
#   'half_time_result': '0 : 1',
#   'home_team_id': 1502,
#   'jc_full_odds': '2.20,3.15,2.85',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,2.05,3.40',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118500',
#   'match_datetime': 'Sun, 17-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225176/Live/Italy-Serie-A-2017-2018-SPAL-2013-Cagliari',
#   'result': '0 : 2'},
#  '1225177': {'away_team_id': 271,
#   'half_time_result': '2 : 2',
#   'home_team_id': 72,
#   'jc_full_odds': '1.59,3.85,4.30',
#   'jc_full_win': True,
#   'jc_half_odds': '2.05,2.40,4.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118498',
#   'match_datetime': 'Sun, 17-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225177/Live/Italy-Serie-A-2017-2018-Torino-Sampdoria',
#   'result': '2 : 2'},
#  '1225178': {'away_team_id': 779,
#   'half_time_result': '3 : 0',
#   'home_team_id': 300,
#   'jc_full_odds': '1.28,4.40,8.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.76,2.35,7.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118645',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225178/Live/Italy-Serie-A-2017-2018-Atalanta-Crotone',
#   'result': '5 : 1'},
#  '1225179': {'away_team_id': 84,
#   'half_time_result': '0 : 2',
#   'home_team_id': 1503,
#   'jc_full_odds': '9.00,5.15,1.22',
#   'jc_full_win': True,
#   'jc_half_odds': '8.00,2.65,1.60',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118623',
#   'match_datetime': 'Wed, 20-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225179/Live/Italy-Serie-A-2017-2018-Benevento-Roma',
#   'result': '0 : 4'},
#  '1225180': {'away_team_id': 75,
#   'half_time_result': '1 : 0',
#   'home_team_id': 71,
#   'jc_full_odds': '5.00,3.80,1.52',
#   'jc_full_win': True,
#   'jc_half_odds': '5.00,2.28,2.05',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118574',
#   'match_datetime': 'Tue, 19-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225180/Live/Italy-Serie-A-2017-2018-Bologna-Inter',
#   'result': '1 : 1'},
#  '1225181': {'away_team_id': 2889,
#   'half_time_result': '0 : 0',
#   'home_team_id': 78,
#   'jc_full_odds': '2.03,3.35,3.00',
#   'jc_full_win': False,
#   'jc_half_odds': '2.70,2.15,3.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118646',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225181/Live/Italy-Serie-A-2017-2018-Cagliari-Sassuolo',
#   'result': '0 : 1'},
#  '1225182': {'away_team_id': 267,
#   'half_time_result': '0 : 0',
#   'home_team_id': 278,
#   'jc_full_odds': '2.03,3.10,3.25',
#   'jc_full_win': True,
#   'jc_half_odds': '2.75,2.00,3.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118647',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225182/Live/Italy-Serie-A-2017-2018-Genoa-Chievo',
#   'result': '1 : 1'},
#  '1225183': {'away_team_id': 271,
#   'half_time_result': '0 : 0',
#   'home_team_id': 76,
#   'jc_full_odds': '3.10,3.35,2.00',
#   'jc_full_win': True,
#   'jc_half_odds': '3.60,2.15,2.60',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118649',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225183/Live/Italy-Serie-A-2017-2018-Verona-Sampdoria',
#   'result': '0 : 0'},
#  '1225184': {'away_team_id': 73,
#   'half_time_result': '0 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.28,4.60,8.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.73,2.45,7.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118642',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225184/Live/Italy-Serie-A-2017-2018-Juventus-Fiorentina',
#   'result': '1 : 0'},
#  '1225185': {'away_team_id': 276,
#   'half_time_result': '1 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '3.10,3.50,1.95',
#   'jc_full_win': True,
#   'jc_half_odds': '3.35,2.30,2.55',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118643',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225185/Live/Italy-Serie-A-2017-2018-Lazio-Napoli',
#   'result': '1 : 4'},
#  '1225186': {'away_team_id': 1502,
#   'half_time_result': '1 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '1.19,5.50,10.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.58,2.70,8.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118644',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225186/Live/Italy-Serie-A-2017-2018-AC-Milan-SPAL-2013',
#   'result': '2 : 0'},
#  '1225187': {'away_team_id': 72,
#   'half_time_result': '0 : 2',
#   'home_team_id': 86,
#   'jc_full_odds': '2.90,3.30,2.10',
#   'jc_full_win': True,
#   'jc_half_odds': '3.35,2.15,2.75',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118648',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225187/Live/Italy-Serie-A-2017-2018-Udinese-Torino',
#   'result': '2 : 3'},
#  '1225188': {'away_team_id': 267,
#   'half_time_result': '0 : 0',
#   'home_team_id': 78,
#   'jc_full_odds': '2.20,3.05,2.92',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,1.96,3.65',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118845',
#   'match_datetime': 'Sun, 24-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225188/Live/Italy-Serie-A-2017-2018-Cagliari-Chievo',
#   'result': '0 : 2'},
#  '1225189': {'away_team_id': 1503,
#   'half_time_result': '1 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '1.88,3.15,3.65',
#   'jc_full_win': True,
#   'jc_half_odds': '2.50,2.03,4.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118846',
#   'match_datetime': 'Sun, 24-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225189/Live/Italy-Serie-A-2017-2018-Crotone-Benevento',
#   'result': '2 : 0'},
#  '1225190': {'away_team_id': 300,
#   'half_time_result': '1 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '2.10,3.30,2.90',
#   'jc_full_win': True,
#   'jc_half_odds': '2.80,2.15,3.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118879',
#   'match_datetime': 'Sun, 24-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225190/Live/Italy-Serie-A-2017-2018-Fiorentina-Atalanta',
#   'result': '1 : 1'},
#  '1225191': {'away_team_id': 77,
#   'half_time_result': '0 : 2',
#   'home_team_id': 76,
#   'jc_full_odds': '5.70,4.05,1.43',
#   'jc_full_win': True,
#   'jc_half_odds': '5.45,2.35,1.92',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118844',
#   'match_datetime': 'Sun, 24-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225191/Live/Italy-Serie-A-2017-2018-Verona-Lazio',
#   'result': '0 : 3'},
#  '1225192': {'away_team_id': 278,
#   'half_time_result': '0 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '1.24,5.00,8.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.67,2.55,7.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118843',
#   'match_datetime': 'Sun, 24-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225192/Live/Italy-Serie-A-2017-2018-Inter-Genoa',
#   'result': '1 : 0'},
#  '1225193': {'away_team_id': 72,
#   'half_time_result': '2 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.30,4.50,7.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.76,2.50,6.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118802',
#   'match_datetime': 'Sat, 23-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225193/Live/Italy-Serie-A-2017-2018-Juventus-Torino',
#   'result': '4 : 0'},
#  '1225194': {'away_team_id': 86,
#   'half_time_result': '3 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.17,5.70,11.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.53,2.78,8.75',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118739',
#   'match_datetime': 'Sat, 23-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225194/Live/Italy-Serie-A-2017-2018-Roma-Udinese',
#   'result': '3 : 1'},
#  '1225195': {'away_team_id': 80,
#   'half_time_result': '0 : 0',
#   'home_team_id': 271,
#   'jc_full_odds': '3.50,3.45,1.83',
#   'jc_full_win': False,
#   'jc_half_odds': '4.00,2.25,2.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118832',
#   'match_datetime': 'Sun, 24-Sep-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225195/Live/Italy-Serie-A-2017-2018-Sampdoria-AC-Milan',
#   'result': '2 : 0'},
#  '1225196': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 2889,
#   'jc_full_odds': '1.85,3.25,3.65',
#   'jc_full_win': False,
#   'jc_half_odds': '2.45,2.10,4.10',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118862',
#   'match_datetime': 'Sun, 24-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225196/Live/Italy-Serie-A-2017-2018-Sassuolo-Bologna',
#   'result': '0 : 1'},
#  '1225197': {'away_team_id': 276,
#   'half_time_result': '1 : 1',
#   'home_team_id': 1502,
#   'jc_full_odds': '11.00,5.90,1.16',
#   'jc_full_win': True,
#   'jc_half_odds': '8.50,2.85,1.52',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118780',
#   'match_datetime': 'Sat, 23-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225197/Live/Italy-Serie-A-2017-2018-SPAL-2013-Napoli',
#   'result': '2 : 3'},
#  '1225198': {'away_team_id': 87,
#   'half_time_result': '1 : 2',
#   'home_team_id': 300,
#   'jc_full_odds': '4.45,3.35,1.67',
#   'jc_full_win': True,
#   'jc_half_odds': '4.70,2.08,2.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119218',
#   'match_datetime': 'Sun, 01-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225198/Live/Italy-Serie-A-2017-2018-Atalanta-Juventus',
#   'result': '2 : 2'},
#  '1225199': {'away_team_id': 75,
#   'half_time_result': '1 : 2',
#   'home_team_id': 1503,
#   'jc_full_odds': '8.70,5.00,1.24',
#   'jc_full_win': True,
#   'jc_half_odds': '6.80,2.60,1.68',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119178',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225199/Live/Italy-Serie-A-2017-2018-Benevento-Inter',
#   'result': '1 : 2'},
#  '1225200': {'away_team_id': 73,
#   'half_time_result': '1 : 1',
#   'home_team_id': 267,
#   'jc_full_odds': '2.75,3.10,2.30',
#   'jc_full_win': False,
#   'jc_half_odds': '3.45,2.00,2.95',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119181',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225200/Live/Italy-Serie-A-2017-2018-Chievo-Fiorentina',
#   'result': '2 : 1'},
#  '1225201': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 278,
#   'jc_full_odds': '2.05,3.00,3.30',
#   'jc_full_win': False,
#   'jc_half_odds': '2.85,1.90,4.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119129',
#   'match_datetime': 'Sat, 30-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225201/Live/Italy-Serie-A-2017-2018-Genoa-Bologna',
#   'result': '0 : 1'},
#  '1225202': {'away_team_id': 2889,
#   'half_time_result': '1 : 1',
#   'home_team_id': 77,
#   'jc_full_odds': '1.40,4.25,5.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.86,2.45,5.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119179',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225202/Live/Italy-Serie-A-2017-2018-Lazio-Sassuolo',
#   'result': '6 : 1'},
#  '1225203': {'away_team_id': 84,
#   'half_time_result': '0 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '2.35,3.40,2.48',
#   'jc_full_win': False,
#   'jc_half_odds': '3.00,2.12,3.10',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119199',
#   'match_datetime': 'Sun, 01-Oct-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225203/Live/Italy-Serie-A-2017-2018-AC-Milan-Roma',
#   'result': '0 : 2'},
#  '1225204': {'away_team_id': 78,
#   'half_time_result': '2 : 0',
#   'home_team_id': 276,
#   'jc_full_odds': '1.06,8.80,18.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.37,3.30,10.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119166',
#   'match_datetime': 'Sun, 01-Oct-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225204/Live/Italy-Serie-A-2017-2018-Napoli-Cagliari',
#   'result': '3 : 0'},
#  '1225205': {'away_team_id': 779,
#   'half_time_result': '1 : 0',
#   'home_team_id': 1502,
#   'jc_full_odds': '1.82,3.10,4.00',
#   'jc_full_win': True,
#   'jc_half_odds': '2.50,2.00,4.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119182',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225205/Live/Italy-Serie-A-2017-2018-SPAL-2013-Crotone',
#   'result': '1 : 1'},
#  '1225206': {'away_team_id': 76,
#   'half_time_result': '2 : 0',
#   'home_team_id': 72,
#   'jc_full_odds': '1.27,4.85,7.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.72,2.55,6.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119180',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225206/Live/Italy-Serie-A-2017-2018-Torino-Verona',
#   'result': '2 : 2'},
#  '1225207': {'away_team_id': 271,
#   'half_time_result': '1 : 0',
#   'home_team_id': 86,
#   'jc_full_odds': '2.45,3.25,2.45',
#   'jc_full_win': True,
#   'jc_half_odds': '3.15,2.03,3.15',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119107',
#   'match_datetime': 'Sat, 30-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225207/Live/Italy-Serie-A-2017-2018-Udinese-Sampdoria',
#   'result': '4 : 0'},
#  '1225208': {'away_team_id': 1502,
#   'half_time_result': '1 : 0',
#   'home_team_id': 71,
#   'jc_full_odds': '1.79,3.15,4.05',
#   'jc_full_win': True,
#   'jc_half_odds': '2.45,2.03,4.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119620',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225208/Live/Italy-Serie-A-2017-2018-Bologna-SPAL-2013',
#   'result': '2 : 1'},
#  '1225209': {'away_team_id': 278,
#   'half_time_result': '0 : 2',
#   'home_team_id': 78,
#   'jc_full_odds': '2.25,3.10,2.80',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,2.00,3.50',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119621',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225209/Live/Italy-Serie-A-2017-2018-Cagliari-Genoa',
#   'result': '2 : 3'},
#  '1225210': {'away_team_id': 72,
#   'half_time_result': '1 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '3.20,3.20,2.00',
#   'jc_full_win': True,
#   'jc_half_odds': '3.85,2.10,2.55',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119622',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225210/Live/Italy-Serie-A-2017-2018-Crotone-Torino',
#   'result': '2 : 2'},
#  '1225211': {'away_team_id': 86,
#   'half_time_result': '1 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '1.48,3.90,5.25',
#   'jc_full_win': True,
#   'jc_half_odds': '1.96,2.35,5.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119605',
#   'match_datetime': 'Sun, 15-Oct-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225211/Live/Italy-Serie-A-2017-2018-Fiorentina-Udinese',
#   'result': '2 : 1'},
#  '1225212': {'away_team_id': 1503,
#   'half_time_result': '0 : 0',
#   'home_team_id': 76,
#   'jc_full_odds': '1.77,3.35,3.85',
#   'jc_full_win': True,
#   'jc_half_odds': '2.30,2.12,4.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119680',
#   'match_datetime': 'Mon, 16-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225212/Live/Italy-Serie-A-2017-2018-Verona-Benevento',
#   'result': '1 : 0'},
#  '1225213': {'away_team_id': 80,
#   'half_time_result': '1 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '2.00,3.35,3.10',
#   'jc_full_win': True,
#   'jc_half_odds': '2.65,2.15,3.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119648',
#   'match_datetime': 'Sun, 15-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225213/Live/Italy-Serie-A-2017-2018-Inter-AC-Milan',
#   'result': '3 : 2'},
#  '1225214': {'away_team_id': 77,
#   'half_time_result': '1 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.46,3.85,5.60',
#   'jc_full_win': False,
#   'jc_half_odds': '2.00,2.28,5.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119556',
#   'match_datetime': 'Sat, 14-Oct-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225214/Live/Italy-Serie-A-2017-2018-Juventus-Lazio',
#   'result': '1 : 2'},
#  '1225215': {'away_team_id': 276,
#   'half_time_result': '0 : 1',
#   'home_team_id': 84,
#   'jc_full_odds': '2.82,3.55,2.05',
#   'jc_full_win': True,
#   'jc_half_odds': '3.40,2.20,2.65',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119578',
#   'match_datetime': 'Sat, 14-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225215/Live/Italy-Serie-A-2017-2018-Roma-Napoli',
#   'result': '0 : 1'},
#  '1225216': {'away_team_id': 300,
#   'half_time_result': '0 : 1',
#   'home_team_id': 271,
#   'jc_full_odds': '3.10,3.20,2.05',
#   'jc_full_win': False,
#   'jc_half_odds': '3.70,2.10,2.62',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119619',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225216/Live/Italy-Serie-A-2017-2018-Sampdoria-Atalanta',
#   'result': '3 : 1'},
#  '1225217': {'away_team_id': 267,
#   'half_time_result': '0 : 0',
#   'home_team_id': 2889,
#   'jc_full_odds': '2.12,3.05,3.10',
#   'jc_full_win': True,
#   'jc_half_odds': '2.85,1.95,3.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119623',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225217/Live/Italy-Serie-A-2017-2018-Sassuolo-Chievo',
#   'result': '0 : 0'},
#  '1225218': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 300,
#   'jc_full_odds': '1.52,3.60,5.30',
#   'jc_full_win': True,
#   'jc_half_odds': '2.10,2.15,5.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119918',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225218/Live/Italy-Serie-A-2017-2018-Atalanta-Bologna',
#   'result': '1 : 0'},
#  '1225219': {'away_team_id': 73,
#   'half_time_result': '0 : 1',
#   'home_team_id': 1503,
#   'jc_full_odds': '5.60,4.10,1.43',
#   'jc_full_win': True,
#   'jc_half_odds': '5.35,2.40,1.90',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119919',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225219/Live/Italy-Serie-A-2017-2018-Benevento-Fiorentina',
#   'result': '0 : 3'},
#  '1225220': {'away_team_id': 76,
#   'half_time_result': '2 : 1',
#   'home_team_id': 267,
#   'jc_full_odds': '1.88,3.15,3.65',
#   'jc_full_win': True,
#   'jc_half_odds': '2.50,2.00,4.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119905',
#   'match_datetime': 'Sun, 22-Oct-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225220/Live/Italy-Serie-A-2017-2018-Chievo-Verona',
#   'result': '3 : 2'},
#  '1225221': {'away_team_id': 78,
#   'half_time_result': '2 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '1.16,5.80,11.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.53,2.82,8.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119951',
#   'match_datetime': 'Sun, 22-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225221/Live/Italy-Serie-A-2017-2018-Lazio-Cagliari',
#   'result': '3 : 0'},
#  '1225222': {'away_team_id': 278,
#   'half_time_result': '0 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '1.44,3.95,5.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.97,2.30,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119917',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225222/Live/Italy-Serie-A-2017-2018-AC-Milan-Genoa',
#   'result': '0 : 0'},
#  '1225223': {'away_team_id': 75,
#   'half_time_result': '0 : 0',
#   'home_team_id': 276,
#   'jc_full_odds': '1.40,4.25,5.80',
#   'jc_full_win': True,
#   'jc_half_odds': '1.85,2.48,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119882',
#   'match_datetime': 'Sat, 21-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225223/Live/Italy-Serie-A-2017-2018-Napoli-Inter',
#   'result': '0 : 0'},
#  '1225224': {'away_team_id': 779,
#   'half_time_result': '3 : 0',
#   'home_team_id': 271,
#   'jc_full_odds': '1.42,3.95,6.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.90,2.30,5.95',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119860',
#   'match_datetime': 'Sat, 21-Oct-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225224/Live/Italy-Serie-A-2017-2018-Sampdoria-Crotone',
#   'result': '5 : 0'},
#  '1225225': {'away_team_id': 2889,
#   'half_time_result': '0 : 1',
#   'home_team_id': 1502,
#   'jc_full_odds': '2.55,3.10,2.45',
#   'jc_full_win': True,
#   'jc_half_odds': '3.25,1.98,3.15',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119920',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225225/Live/Italy-Serie-A-2017-2018-SPAL-2013-Sassuolo',
#   'result': '0 : 1'},
#  '1225226': {'away_team_id': 84,
#   'half_time_result': '0 : 0',
#   'home_team_id': 72,
#   'jc_full_odds': '3.35,3.70,1.81',
#   'jc_full_win': True,
#   'jc_half_odds': '3.60,2.40,2.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119916',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225226/Live/Italy-Serie-A-2017-2018-Torino-Roma',
#   'result': '0 : 1'},
#  '1225227': {'away_team_id': 87,
#   'half_time_result': '1 : 2',
#   'home_team_id': 86,
#   'jc_full_odds': '8.50,4.45,1.28',
#   'jc_full_win': True,
#   'jc_half_odds': '8.00,2.35,1.73',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119935',
#   'match_datetime': 'Sun, 22-Oct-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225227/Live/Italy-Serie-A-2017-2018-Udinese-Juventus',
#   'result': '2 : 6'},
#  '1225228': {'away_team_id': 76,
#   'half_time_result': '0 : 0',
#   'home_team_id': 300,
#   'jc_full_odds': '1.22,5.00,9.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.63,2.55,8.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120038',
#   'match_datetime': 'Wed, 25-Oct-17, 17:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225228/Live/Italy-Serie-A-2017-2018-Atalanta-Verona',
#   'result': '3 : 0'},
#  '1225229': {'away_team_id': 77,
#   'half_time_result': '0 : 2',
#   'home_team_id': 71,
#   'jc_full_odds': '4.50,3.60,1.60',
#   'jc_full_win': True,
#   'jc_half_odds': '4.60,2.25,2.15',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120055',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225229/Live/Italy-Serie-A-2017-2018-Bologna-Lazio',
#   'result': '1 : 2'},
#  '1225230': {'away_team_id': 1503,
#   'half_time_result': '1 : 0',
#   'home_team_id': 78,
#   'jc_full_odds': '1.50,3.80,5.20',
#   'jc_full_win': True,
#   'jc_half_odds': '2.05,2.25,5.10',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120056',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225230/Live/Italy-Serie-A-2017-2018-Cagliari-Benevento',
#   'result': '2 : 1'},
#  '1225231': {'away_team_id': 80,
#   'half_time_result': '0 : 2',
#   'home_team_id': 267,
#   'jc_full_odds': '3.10,3.15,2.08',
#   'jc_full_win': True,
#   'jc_half_odds': '3.70,2.00,2.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120053',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225231/Live/Italy-Serie-A-2017-2018-Chievo-AC-Milan',
#   'result': '1 : 4'},
#  '1225232': {'away_team_id': 72,
#   'half_time_result': '1 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '1.62,3.80,4.10',
#   'jc_full_win': True,
#   'jc_half_odds': '2.10,2.38,4.35',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120057',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225232/Live/Italy-Serie-A-2017-2018-Fiorentina-Torino',
#   'result': '3 : 0'},
#  '1225233': {'away_team_id': 276,
#   'half_time_result': '1 : 2',
#   'home_team_id': 278,
#   'jc_full_odds': '7.80,4.70,1.28',
#   'jc_full_win': True,
#   'jc_half_odds': '6.25,2.48,1.77',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120058',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225233/Live/Italy-Serie-A-2017-2018-Genoa-Napoli',
#   'result': '2 : 3'},
#  '1225234': {'away_team_id': 271,
#   'half_time_result': '2 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '1.32,4.55,6.80',
#   'jc_full_win': True,
#   'jc_half_odds': '1.78,2.50,6.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120007',
#   'match_datetime': 'Tue, 24-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225234/Live/Italy-Serie-A-2017-2018-Inter-Sampdoria',
#   'result': '3 : 2'},
#  '1225235': {'away_team_id': 1502,
#   'half_time_result': '2 : 1',
#   'home_team_id': 87,
#   'jc_full_odds': '1.06,8.00,23.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.39,3.00,13.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120054',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225235/Live/Italy-Serie-A-2017-2018-Juventus-SPAL-2013',
#   'result': '4 : 1'},
#  '1225236': {'away_team_id': 779,
#   'half_time_result': '1 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.08,7.50,18.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.42,3.05,10.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120059',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225236/Live/Italy-Serie-A-2017-2018-Roma-Crotone',
#   'result': '1 : 0'},
#  '1225237': {'away_team_id': 86,
#   'half_time_result': '0 : 1',
#   'home_team_id': 2889,
#   'jc_full_odds': '1.85,3.35,3.55',
#   'jc_full_win': False,
#   'jc_half_odds': '2.45,2.15,3.90',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120060',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225237/Live/Italy-Serie-A-2017-2018-Sassuolo-Udinese',
#   'result': '0 : 1'},
#  '1225238': {'away_team_id': 77,
#   'half_time_result': '0 : 3',
#   'home_team_id': 1503,
#   'jc_full_odds': '9.25,5.50,1.20',
#   'jc_full_win': True,
#   'jc_half_odds': '7.50,2.80,1.57',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120256',
#   'match_datetime': 'Sun, 29-Oct-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225238/Live/Italy-Serie-A-2017-2018-Benevento-Lazio',
#   'result': '1 : 5'},
#  '1225239': {'away_team_id': 73,
#   'half_time_result': '2 : 1',
#   'home_team_id': 779,
#   'jc_full_odds': '5.15,3.75,1.51',
#   'jc_full_win': False,
#   'jc_half_odds': '5.10,2.25,2.05',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120270',
#   'match_datetime': 'Sun, 29-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225239/Live/Italy-Serie-A-2017-2018-Crotone-Fiorentina',
#   'result': '2 : 1'},
#  '1225240': {'away_team_id': 75,
#   'half_time_result': '0 : 1',
# ...
#   'result': '1 : 1'},
#  '1225387': {'away_team_id': 77,
#   'half_time_result': '0 : 2',
#   'home_team_id': 2889,
#   'jc_full_odds': '3.90,3.55,1.71',
#   'jc_full_win': True,
#   'jc_half_odds': '4.20,2.25,2.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123968',
#   'match_datetime': 'Sun, 25-Feb-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225387/Live/Italy-Serie-A-2017-2018-Sassuolo-Lazio',
#   'result': '0 : 3'},
#  '1225388': {'away_team_id': 76,
#   'half_time_result': '0 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '1.12,6.60,12.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.47,3.05,8.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123742',
#   'match_datetime': 'Mon, 19-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225388/Live/Italy-Serie-A-2017-2018-Lazio-Verona',
#   'result': '2 : 0'},
#  '1225389': {'away_team_id': 80,
#   'half_time_result': '0 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.80,3.40,3.65',
#   'jc_full_win': False,
#   'jc_half_odds': '2.45,2.22,3.70',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123989',
#   'match_datetime': 'Sun, 25-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225389/Live/Italy-Serie-A-2017-2018-Roma-AC-Milan',
#   'result': '0 : 2'},
#  '1225390': {'away_team_id': 75,
#   'half_time_result': '1 : 0',
#   'home_team_id': 278,
#   'jc_full_odds': '2.90,3.00,2.25',
#   'jc_full_win': False,
#   'jc_half_odds': '3.70,1.90,3.00',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123674',
#   'match_datetime': 'Sat, 17-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225390/Live/Italy-Serie-A-2017-2018-Genoa-Inter',
#   'result': '2 : 0'},
#  '1225391': {'away_team_id': 276,
#   'half_time_result': '0 : 2',
#   'home_team_id': 78,
#   'jc_full_odds': '8.50,4.75,1.26',
#   'jc_full_win': True,
#   'jc_half_odds': '7.50,2.52,1.68',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124004',
#   'match_datetime': 'Mon, 26-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225391/Live/Italy-Serie-A-2017-2018-Cagliari-Napoli',
#   'result': '0 : 5'},
#  '1225392': {'away_team_id': 87,
#   'half_time_result': '0 : 1',
#   'home_team_id': 72,
#   'jc_full_odds': '4.80,3.35,1.62',
#   'jc_full_win': True,
#   'jc_half_odds': '5.05,2.10,2.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123690',
#   'match_datetime': 'Sun, 18-Feb-18, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225392/Live/Italy-Serie-A-2017-2018-Torino-Juventus',
#   'result': '0 : 1'},
#  '1225393': {'away_team_id': 1502,
#   'half_time_result': '0 : 1',
#   'home_team_id': 779,
#   'jc_full_odds': '2.15,2.95,3.15',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,1.88,4.00',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123957',
#   'match_datetime': 'Sun, 25-Feb-18, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225393/Live/Italy-Serie-A-2017-2018-Crotone-SPAL-2013',
#   'result': '2 : 3'},
#  '1225394': {'away_team_id': 84,
#   'half_time_result': '0 : 0',
#   'home_team_id': 86,
#   'jc_full_odds': '4.10,3.55,1.67',
#   'jc_full_win': True,
#   'jc_half_odds': '4.40,2.25,2.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123626',
#   'match_datetime': 'Sat, 17-Feb-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225394/Live/Italy-Serie-A-2017-2018-Udinese-Roma',
#   'result': '0 : 2'},
#  '1225395': {'away_team_id': 72,
#   'half_time_result': '1 : 0',
#   'home_team_id': 76,
#   'jc_full_odds': '5.20,3.80,1.50',
#   'jc_full_win': False,
#   'jc_half_odds': '5.15,2.30,2.00',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123971',
#   'match_datetime': 'Sun, 25-Feb-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225395/Live/Italy-Serie-A-2017-2018-Verona-Torino',
#   'result': '2 : 1'},
#  '1225396': {'away_team_id': 271,
#   'half_time_result': '1 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '1.54,3.75,4.80',
#   'jc_full_win': True,
#   'jc_half_odds': '2.05,2.30,4.90',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123723',
#   'match_datetime': 'Sun, 18-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225396/Live/Italy-Serie-A-2017-2018-AC-Milan-Sampdoria',
#   'result': '1 : 0'},
#  '1225397': {'away_team_id': 86,
#   'half_time_result': '1 : 0',
#   'home_team_id': 271,
#   'jc_full_odds': '1.84,3.30,3.60',
#   'jc_full_win': True,
#   'jc_half_odds': '2.45,2.15,3.95',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123970',
#   'match_datetime': 'Sun, 25-Feb-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225397/Live/Italy-Serie-A-2017-2018-Sampdoria-Udinese',
#   'result': '2 : 1'},
#  '1225400': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1502,
#   'jc_full_odds': '2.27,3.05,2.82',
#   'jc_full_win': True,
#   'jc_half_odds': '2.95,1.93,3.70',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124122',
#   'match_datetime': 'Sat, 03-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225400/Live/Italy-Serie-A-2017-2018-SPAL-2013-Bologna',
#   'result': '1 : 0'},
#  '1225422': {'away_team_id': 87,
#   'half_time_result': '0 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '3.00,3.00,2.20',
#   'jc_full_win': True,
#   'jc_half_odds': '3.80,1.90,2.95',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124162',
#   'match_datetime': 'Sat, 03-Mar-18, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225422/Live/Italy-Serie-A-2017-2018-Lazio-Juventus',
#   'result': '0 : 1'},
#  '1225424': {'away_team_id': 84,
#   'half_time_result': '1 : 2',
#   'home_team_id': 276,
#   'jc_full_odds': '1.50,3.85,5.10',
#   'jc_full_win': False,
#   'jc_half_odds': '2.00,2.30,5.20',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124185',
#   'match_datetime': 'Sat, 03-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225424/Live/Italy-Serie-A-2017-2018-Napoli-Roma',
#   'result': '2 : 4'},
#  '1225430': {'away_team_id': 300,
#   'half_time_result': '0 : 0',
#   'home_team_id': 71,
#   'jc_full_odds': '4.10,3.25,1.75',
#   'jc_full_win': True,
#   'jc_half_odds': '4.70,2.05,2.35',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124522',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225430/Live/Italy-Serie-A-2017-2018-Bologna-Atalanta',
#   'result': '0 : 1'},
#  '1225432': {'away_team_id': 1503,
#   'half_time_result': '1 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '1.30,4.50,7.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.75,2.40,7.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124501',
#   'match_datetime': 'Sun, 11-Mar-18, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225432/Live/Italy-Serie-A-2017-2018-Fiorentina-Benevento',
#   'result': '1 : 0'},
#  '1225434': {'away_team_id': 267,
#   'half_time_result': '0 : 0',
#   'home_team_id': 76,
#   'jc_full_odds': '3.45,3.20,1.93',
#   'jc_full_win': False,
#   'jc_half_odds': '4.00,2.03,2.60',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124469',
#   'match_datetime': 'Sat, 10-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225434/Live/Italy-Serie-A-2017-2018-Verona-Chievo',
#   'result': '1 : 0'},
#  '1225436': {'away_team_id': 77,
#   'half_time_result': '1 : 1',
#   'home_team_id': 78,
#   'jc_full_odds': '5.25,3.90,1.48',
#   'jc_full_win': True,
#   'jc_half_odds': '5.30,2.30,1.98',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124521',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225436/Live/Italy-Serie-A-2017-2018-Cagliari-Lazio',
#   'result': '2 : 2'},
#  '1225438': {'away_team_id': 80,
#   'half_time_result': '0 : 0',
#   'home_team_id': 278,
#   'jc_full_odds': '3.15,2.98,2.12',
#   'jc_full_win': True,
#   'jc_half_odds': '4.00,1.90,2.85',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124535',
#   'match_datetime': 'Sun, 11-Mar-18, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225438/Live/Italy-Serie-A-2017-2018-Genoa-AC-Milan',
#   'result': '0 : 1'},
#  '1225440': {'away_team_id': 276,
#   'half_time_result': '0 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '3.40,3.30,1.90',
#   'jc_full_win': True,
#   'jc_half_odds': '3.85,2.10,2.55',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124548',
#   'match_datetime': 'Sun, 11-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225440/Live/Italy-Serie-A-2017-2018-Inter-Napoli',
#   'result': '0 : 0'},
#  '1225442': {'away_team_id': 271,
#   'half_time_result': '3 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '2.52,3.05,2.52',
#   'jc_full_win': True,
#   'jc_half_odds': '3.25,1.95,3.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124523',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225442/Live/Italy-Serie-A-2017-2018-Crotone-Sampdoria',
#   'result': '4 : 1'},
#  '1225444': {'away_team_id': 1502,
#   'half_time_result': '1 : 1',
#   'home_team_id': 2889,
#   'jc_full_odds': '1.85,3.15,3.75',
#   'jc_full_win': True,
#   'jc_half_odds': '2.50,2.05,4.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124524',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225444/Live/Italy-Serie-A-2017-2018-Sassuolo-SPAL-2013',
#   'result': '1 : 1'},
#  '1225446': {'away_team_id': 72,
#   'half_time_result': '0 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.45,3.95,5.50',
#   'jc_full_win': True,
#   'jc_half_odds': '2.00,2.25,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124378',
#   'match_datetime': 'Fri, 09-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225446/Live/Italy-Serie-A-2017-2018-Roma-Torino',
#   'result': '3 : 0'},
#  '1225448': {'away_team_id': 86,
#   'half_time_result': '1 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.16,5.40,13.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.57,2.55,10.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124520',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225448/Live/Italy-Serie-A-2017-2018-Juventus-Udinese',
#   'result': '2 : 0'},
#  '1225450': {'away_team_id': 300,
#   'half_time_result': '0 : 2',
#   'home_team_id': 76,
#   'jc_full_odds': '7.00,4.25,1.34',
#   'jc_full_win': True,
#   'jc_half_odds': '6.75,2.40,1.77',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124820',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225450/Live/Italy-Serie-A-2017-2018-Verona-Atalanta',
#   'result': '0 : 5'},
#  '1225452': {'away_team_id': 71,
#   'half_time_result': '1 : 1',
#   'home_team_id': 77,
#   'jc_full_odds': '1.25,4.80,8.70',
#   'jc_full_win': True,
#   'jc_half_odds': '1.70,2.48,7.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124846',
#   'match_datetime': 'Sun, 18-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225452/Live/Italy-Serie-A-2017-2018-Lazio-Bologna',
#   'result': '1 : 1'},
#  '1225454': {'away_team_id': 78,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1503,
#   'jc_full_odds': '2.23,3.15,2.80',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,2.05,3.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124819',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225454/Live/Italy-Serie-A-2017-2018-Benevento-Cagliari',
#   'result': '1 : 2'},
#  '1225456': {'away_team_id': 267,
#   'half_time_result': '1 : 2',
#   'home_team_id': 80,
#   'jc_full_odds': '1.28,4.45,8.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.78,2.35,7.20',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124816',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225456/Live/Italy-Serie-A-2017-2018-AC-Milan-Chievo',
#   'result': '3 : 2'},
#  '1225458': {'away_team_id': 73,
#   'half_time_result': '0 : 0',
#   'home_team_id': 72,
#   'jc_full_odds': '2.45,3.15,2.52',
#   'jc_full_win': False,
#   'jc_half_odds': '3.10,2.03,3.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124818',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225458/Live/Italy-Serie-A-2017-2018-Torino-Fiorentina',
#   'result': '1 : 2'},
#  '1225460': {'away_team_id': 278,
#   'half_time_result': '0 : 0',
#   'home_team_id': 276,
#   'jc_full_odds': '1.14,5.80,14.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.54,2.65,10.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124845',
#   'match_datetime': 'Sun, 18-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225460/Live/Italy-Serie-A-2017-2018-Napoli-Genoa',
#   'result': '1 : 0'},
#  '1225462': {'away_team_id': 75,
#   'half_time_result': '0 : 4',
#   'home_team_id': 271,
#   'jc_full_odds': '3.50,3.30,1.88',
#   'jc_full_win': True,
#   'jc_half_odds': '3.90,2.15,2.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124805',
#   'match_datetime': 'Sun, 18-Mar-18, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225462/Live/Italy-Serie-A-2017-2018-Sampdoria-Inter',
#   'result': '0 : 5'},
#  '1225464': {'away_team_id': 87,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1502,
#   'jc_full_odds': '9.75,4.40,1.26',
#   'jc_full_win': True,
#   'jc_half_odds': '9.50,2.25,1.73',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124774',
#   'match_datetime': 'Sat, 17-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225464/Live/Italy-Serie-A-2017-2018-SPAL-2013-Juventus',
#   'result': '0 : 0'},
#  '1225466': {'away_team_id': 84,
#   'half_time_result': '0 : 1',
#   'home_team_id': 779,
#   'jc_full_odds': '5.10,3.90,1.49',
#   'jc_full_win': True,
#   'jc_half_odds': '5.20,2.30,2.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124817',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225466/Live/Italy-Serie-A-2017-2018-Crotone-Roma',
#   'result': '0 : 2'},
#  '1225468': {'away_team_id': 2889,
#   'half_time_result': '1 : 1',
#   'home_team_id': 86,
#   'jc_full_odds': '1.95,3.20,3.35',
#   'jc_full_win': False,
#   'jc_half_odds': '2.60,2.03,4.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124750',
#   'match_datetime': 'Sat, 17-Mar-18, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225468/Live/Italy-Serie-A-2017-2018-Udinese-Sassuolo',
#   'result': '1 : 2'}}

# %%
draw_event,_,_ = calculateJCWinningAcc(match_table, start=10, step=10, png_path='jc_acc_plot_draw.png', draw_as_event=True)
binary_event,_,_ = calculateJCWinningAcc(match_table, start=10, step=10, png_path='jc_acc_plot_binary.png', draw_as_event=False)
plotAccFig(match_odds_table=draw_event, compared_odds_table=binary_event, start=10, step=10, png_path='jc_acc_plot_diff.png')
# Out:
# >>> 2017-2018 JC half acc (include draw): 0.5123674911660777
# >>> 2017-2018 JC full acc (include draw): 0.6007067137809188
# >>> 2017-2018 JC half acc (binary): 0.8763250883392226
# >>> 2017-2018 JC full acc (binary): 0.8091872791519434

# %%
draw_event
# Out:
# {'1225138': {'away_team_id': 84,
#   'half_time_result': '0 : 1',
#   'home_team_id': 300,
#   'jc_full_odds': '2.70,3.25,2.25',
#   'jc_full_win': True,
#   'jc_half_odds': '3.25,2.12,2.85',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117316',
#   'match_datetime': 'Sun, 20-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225138/Live/Italy-Serie-A-2017-2018-Atalanta-Roma',
#   'result': '0 : 1'},
#  '1225139': {'away_team_id': 72,
#   'half_time_result': '1 : 1',
#   'home_team_id': 71,
#   'jc_full_odds': '2.80,3.10,2.25',
#   'jc_full_win': True,
#   'jc_half_odds': '3.40,2.05,2.90',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117333',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225139/Live/Italy-Serie-A-2017-2018-Bologna-Torino',
#   'result': '1 : 1'},
#  '1225140': {'away_team_id': 80,
#   'half_time_result': '0 : 3',
#   'home_team_id': 779,
#   'jc_full_odds': '6.10,3.95,1.42',
#   'jc_full_win': True,
#   'jc_half_odds': '5.80,2.28,1.93',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117334',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225140/Live/Italy-Serie-A-2017-2018-Crotone-AC-Milan',
#   'result': '0 : 3'},
#  '1225141': {'away_team_id': 276,
#   'half_time_result': '0 : 2',
#   'home_team_id': 76,
#   'jc_full_odds': '7.00,4.35,1.33',
#   'jc_full_win': True,
#   'jc_half_odds': '6.40,2.40,1.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117434',
#   'match_datetime': 'Sat, 19-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225141/Live/Italy-Serie-A-2017-2018-Verona-Napoli',
#   'result': '1 : 3'},
#  '1225142': {'away_team_id': 73,
#   'half_time_result': '2 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '1.44,3.90,5.80',
#   'jc_full_win': True,
#   'jc_half_odds': '1.93,2.28,5.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117332',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225142/Live/Italy-Serie-A-2017-2018-Inter-Fiorentina',
#   'result': '3 : 0'},
#  '1225143': {'away_team_id': 78,
#   'half_time_result': '2 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.07,7.50,22.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.39,2.95,14.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117413',
#   'match_datetime': 'Sat, 19-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225143/Live/Italy-Serie-A-2017-2018-Juventus-Cagliari',
#   'result': '3 : 0'},
#  '1225144': {'away_team_id': 1502,
#   'half_time_result': '0 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '1.19,5.30,10.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.60,2.60,8.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117335',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225144/Live/Italy-Serie-A-2017-2018-Lazio-SPAL-2013',
#   'result': '0 : 0'},
#  '1225145': {'away_team_id': 1503,
#   'half_time_result': '1 : 1',
#   'home_team_id': 271,
#   'jc_full_odds': '1.50,3.65,5.50',
#   'jc_full_win': True,
#   'jc_half_odds': '2.05,2.20,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117336',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225145/Live/Italy-Serie-A-2017-2018-Sampdoria-Benevento',
#   'result': '2 : 1'},
#  '1225146': {'away_team_id': 278,
#   'half_time_result': '0 : 0',
#   'home_team_id': 2889,
#   'jc_full_odds': '1.83,3.30,3.65',
#   'jc_full_win': True,
#   'jc_half_odds': '2.40,2.10,4.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117337',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225146/Live/Italy-Serie-A-2017-2018-Sassuolo-Genoa',
#   'result': '0 : 0'},
#  '1225147': {'away_team_id': 267,
#   'half_time_result': '1 : 1',
#   'home_team_id': 86,
#   'jc_full_odds': '1.83,3.15,3.85',
#   'jc_full_win': False,
#   'jc_half_odds': '2.45,2.02,4.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117338',
#   'match_datetime': 'Sun, 20-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225147/Live/Italy-Serie-A-2017-2018-Udinese-Chievo',
#   'result': '1 : 2'},
#  '1225148': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1503,
#   'jc_full_odds': '2.52,3.05,2.52',
#   'jc_full_win': False,
#   'jc_half_odds': '3.15,2.02,3.15',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117649',
#   'match_datetime': 'Sat, 26-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225148/Live/Italy-Serie-A-2017-2018-Benevento-Bologna',
#   'result': '0 : 1'},
#  '1225149': {'away_team_id': 77,
#   'half_time_result': '1 : 1',
#   'home_team_id': 267,
#   'jc_full_odds': '3.60,3.25,1.86',
#   'jc_full_win': True,
#   'jc_half_odds': '4.10,2.10,2.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117748',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225149/Live/Italy-Serie-A-2017-2018-Chievo-Lazio',
#   'result': '1 : 2'},
#  '1225150': {'away_team_id': 76,
#   'half_time_result': '0 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '2.45,2.90,2.70',
#   'jc_full_win': True,
#   'jc_half_odds': '3.10,1.92,3.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117749',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225150/Live/Italy-Serie-A-2017-2018-Crotone-Verona',
#   'result': '0 : 0'},
#  '1225151': {'away_team_id': 271,
#   'half_time_result': '0 : 2',
#   'home_team_id': 73,
#   'jc_full_odds': '1.57,3.75,4.55',
#   'jc_full_win': False,
#   'jc_half_odds': '2.08,2.30,4.70',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117750',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225151/Live/Italy-Serie-A-2017-2018-Fiorentina-Sampdoria',
#   'result': '1 : 2'},
#  '1225152': {'away_team_id': 87,
#   'half_time_result': '2 : 2',
#   'home_team_id': 278,
#   'jc_full_odds': '7.75,4.15,1.33',
#   'jc_full_win': True,
#   'jc_half_odds': '7.00,2.30,1.82',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117648',
#   'match_datetime': 'Sat, 26-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225152/Live/Italy-Serie-A-2017-2018-Genoa-Juventus',
#   'result': '2 : 4'},
#  '1225153': {'away_team_id': 78,
#   'half_time_result': '1 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '1.22,5.25,9.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.65,2.65,7.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117747',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225153/Live/Italy-Serie-A-2017-2018-AC-Milan-Cagliari',
#   'result': '2 : 1'},
#  '1225154': {'away_team_id': 300,
#   'half_time_result': '0 : 1',
#   'home_team_id': 276,
#   'jc_full_odds': '1.30,4.50,7.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.70,2.58,6.50',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117751',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225154/Live/Italy-Serie-A-2017-2018-Napoli-Atalanta',
#   'result': '3 : 1'},
#  '1225155': {'away_team_id': 75,
#   'half_time_result': '1 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '2.05,3.35,2.95',
#   'jc_full_win': False,
#   'jc_half_odds': '2.70,2.20,3.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117673',
#   'match_datetime': 'Sat, 26-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225155/Live/Italy-Serie-A-2017-2018-Roma-Inter',
#   'result': '1 : 3'},
#  '1225156': {'away_team_id': 86,
#   'half_time_result': '1 : 0',
#   'home_team_id': 1502,
#   'jc_full_odds': '2.38,3.05,2.68',
#   'jc_full_win': True,
#   'jc_half_odds': '3.10,1.95,3.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117752',
#   'match_datetime': 'Sun, 27-Aug-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225156/Live/Italy-Serie-A-2017-2018-SPAL-2013-Udinese',
#   'result': '3 : 2'},
#  '1225157': {'away_team_id': 2889,
#   'half_time_result': '1 : 0',
#   'home_team_id': 72,
#   'jc_full_odds': '1.55,3.80,4.65',
#   'jc_full_win': True,
#   'jc_half_odds': '2.07,2.32,4.65',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=117733',
#   'match_datetime': 'Sun, 27-Aug-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225157/Live/Italy-Serie-A-2017-2018-Torino-Sassuolo',
#   'result': '3 : 0'},
#  '1225158': {'away_team_id': 2889,
#   'half_time_result': '1 : 1',
#   'home_team_id': 300,
#   'jc_full_odds': '1.50,3.80,5.20',
#   'jc_full_win': True,
#   'jc_half_odds': '2.00,2.25,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118173',
#   'match_datetime': 'Sun, 10-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225158/Live/Italy-Serie-A-2017-2018-Atalanta-Sassuolo',
#   'result': '2 : 1'},
#  '1225159': {'away_team_id': 72,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1503,
#   'jc_full_odds': '3.40,3.55,1.83',
#   'jc_full_win': True,
#   'jc_half_odds': '3.75,2.30,2.35',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118194',
#   'match_datetime': 'Sun, 10-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225159/Live/Italy-Serie-A-2017-2018-Benevento-Torino',
#   'result': '0 : 1'},
#  '1225160': {'away_team_id': 276,
#   'half_time_result': '0 : 0',
#   'home_team_id': 71,
#   'jc_full_odds': '7.80,4.65,1.28',
#   'jc_full_win': True,
#   'jc_half_odds': '6.80,2.50,1.72',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118212',
#   'match_datetime': 'Sun, 10-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225160/Live/Italy-Serie-A-2017-2018-Bologna-Napoli',
#   'result': '0 : 3'},
#  '1225161': {'away_team_id': 779,
#   'half_time_result': '1 : 0',
#   'home_team_id': 78,
#   'jc_full_odds': '1.57,3.50,5.00',
#   'jc_full_win': True,
#   'jc_half_odds': '2.12,2.17,5.10',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118174',
#   'match_datetime': 'Sun, 10-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225161/Live/Italy-Serie-A-2017-2018-Cagliari-Crotone',
#   'result': '1 : 0'},
#  '1225162': {'away_team_id': 73,
#   'half_time_result': '0 : 3',
#   'home_team_id': 76,
#   'jc_full_odds': '3.55,3.30,1.85',
#   'jc_full_win': True,
#   'jc_half_odds': '4.15,2.08,2.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118176',
#   'match_datetime': 'Sun, 10-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225162/Live/Italy-Serie-A-2017-2018-Verona-Fiorentina',
#   'result': '0 : 5'},
#  '1225163': {'away_team_id': 1502,
#   'half_time_result': '1 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '1.13,6.30,12.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.48,2.88,9.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118161',
#   'match_datetime': 'Sun, 10-Sep-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225163/Live/Italy-Serie-A-2017-2018-Inter-SPAL-2013',
#   'result': '2 : 0'},
#  '1225164': {'away_team_id': 267,
#   'half_time_result': '1 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.17,5.70,11.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.58,2.65,8.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118104',
#   'match_datetime': 'Sat, 09-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225164/Live/Italy-Serie-A-2017-2018-Juventus-Chievo',
#   'result': '3 : 0'},
#  '1225165': {'away_team_id': 80,
#   'half_time_result': '2 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '2.12,3.30,2.87',
#   'jc_full_win': True,
#   'jc_half_odds': '2.75,2.13,3.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118172',
#   'match_datetime': 'Sun, 10-Sep-17, 15:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225165/Live/Italy-Serie-A-2017-2018-Lazio-AC-Milan',
#   'result': '4 : 1'},
#  '1225166': {'away_team_id': 84,
#   'half_time_result': '1 : 0',
#   'home_team_id': 271,
#   'jc_full_odds': '3.60,3.55,1.78',
#   'jc_full_win': True,
#   'jc_half_odds': '3.90,2.28,2.30',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=122888',
#   'match_datetime': 'Wed, 24-Jan-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225166/Live/Italy-Serie-A-2017-2018-Sampdoria-Roma',
#   'result': '1 : 1'},
#  '1225167': {'away_team_id': 278,
#   'half_time_result': '1 : 0',
#   'home_team_id': 86,
#   'jc_full_odds': '2.22,3.10,2.85',
#   'jc_full_win': True,
#   'jc_half_odds': '2.85,2.00,3.60',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118175',
#   'match_datetime': 'Sun, 10-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225167/Live/Italy-Serie-A-2017-2018-Udinese-Genoa',
#   'result': '1 : 0'},
#  '1225168': {'away_team_id': 300,
#   'half_time_result': '0 : 0',
#   'home_team_id': 267,
#   'jc_full_odds': '2.72,3.00,2.37',
#   'jc_full_win': True,
#   'jc_half_odds': '3.55,1.95,3.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118517',
#   'match_datetime': 'Sun, 17-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225168/Live/Italy-Serie-A-2017-2018-Chievo-Atalanta',
#   'result': '1 : 1'},
#  '1225169': {'away_team_id': 75,
#   'half_time_result': '0 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '7.75,4.45,1.30',
#   'jc_full_win': True,
#   'jc_half_odds': '6.25,2.42,1.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118389',
#   'match_datetime': 'Sat, 16-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225169/Live/Italy-Serie-A-2017-2018-Crotone-Inter',
#   'result': '0 : 2'},
#  '1225170': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '1.43,3.95,5.80',
#   'jc_full_win': True,
#   'jc_half_odds': '1.93,2.30,5.75',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118432',
#   'match_datetime': 'Sat, 16-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225170/Live/Italy-Serie-A-2017-2018-Fiorentina-Bologna',
#   'result': '2 : 1'},
#  '1225171': {'away_team_id': 77,
#   'half_time_result': '0 : 1',
#   'home_team_id': 278,
#   'jc_full_odds': '3.55,3.40,1.83',
#   'jc_full_win': True,
#   'jc_half_odds': '3.90,2.15,2.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118533',
#   'match_datetime': 'Sun, 17-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225171/Live/Italy-Serie-A-2017-2018-Genoa-Lazio',
#   'result': '2 : 3'},
#  '1225172': {'away_team_id': 86,
#   'half_time_result': '2 : 1',
#   'home_team_id': 80,
#   'jc_full_odds': '1.30,4.45,7.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.74,2.45,6.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118497',
#   'match_datetime': 'Sun, 17-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225172/Live/Italy-Serie-A-2017-2018-AC-Milan-Udinese',
#   'result': '2 : 1'},
#  '1225173': {'away_team_id': 1503,
#   'half_time_result': '4 : 0',
#   'home_team_id': 276,
#   'jc_full_odds': '1.06,8.70,18.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.35,3.35,11.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118499',
#   'match_datetime': 'Sun, 17-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225173/Live/Italy-Serie-A-2017-2018-Napoli-Benevento',
#   'result': '6 : 0'},
#  '1225174': {'away_team_id': 76,
#   'half_time_result': '2 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.13,6.50,12.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.48,2.95,9.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118454',
#   'match_datetime': 'Sat, 16-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225174/Live/Italy-Serie-A-2017-2018-Roma-Verona',
#   'result': '3 : 0'},
#  '1225175': {'away_team_id': 87,
#   'half_time_result': '0 : 1',
#   'home_team_id': 2889,
#   'jc_full_odds': '6.70,4.20,1.36',
#   'jc_full_win': True,
#   'jc_half_odds': '6.80,2.32,1.82',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118487',
#   'match_datetime': 'Sun, 17-Sep-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225175/Live/Italy-Serie-A-2017-2018-Sassuolo-Juventus',
#   'result': '1 : 3'},
#  '1225176': {'away_team_id': 78,
#   'half_time_result': '0 : 1',
#   'home_team_id': 1502,
#   'jc_full_odds': '2.20,3.15,2.85',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,2.05,3.40',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118500',
#   'match_datetime': 'Sun, 17-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225176/Live/Italy-Serie-A-2017-2018-SPAL-2013-Cagliari',
#   'result': '0 : 2'},
#  '1225177': {'away_team_id': 271,
#   'half_time_result': '2 : 2',
#   'home_team_id': 72,
#   'jc_full_odds': '1.59,3.85,4.30',
#   'jc_full_win': True,
#   'jc_half_odds': '2.05,2.40,4.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118498',
#   'match_datetime': 'Sun, 17-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225177/Live/Italy-Serie-A-2017-2018-Torino-Sampdoria',
#   'result': '2 : 2'},
#  '1225178': {'away_team_id': 779,
#   'half_time_result': '3 : 0',
#   'home_team_id': 300,
#   'jc_full_odds': '1.28,4.40,8.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.76,2.35,7.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118645',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225178/Live/Italy-Serie-A-2017-2018-Atalanta-Crotone',
#   'result': '5 : 1'},
#  '1225179': {'away_team_id': 84,
#   'half_time_result': '0 : 2',
#   'home_team_id': 1503,
#   'jc_full_odds': '9.00,5.15,1.22',
#   'jc_full_win': True,
#   'jc_half_odds': '8.00,2.65,1.60',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118623',
#   'match_datetime': 'Wed, 20-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225179/Live/Italy-Serie-A-2017-2018-Benevento-Roma',
#   'result': '0 : 4'},
#  '1225180': {'away_team_id': 75,
#   'half_time_result': '1 : 0',
#   'home_team_id': 71,
#   'jc_full_odds': '5.00,3.80,1.52',
#   'jc_full_win': True,
#   'jc_half_odds': '5.00,2.28,2.05',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118574',
#   'match_datetime': 'Tue, 19-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225180/Live/Italy-Serie-A-2017-2018-Bologna-Inter',
#   'result': '1 : 1'},
#  '1225181': {'away_team_id': 2889,
#   'half_time_result': '0 : 0',
#   'home_team_id': 78,
#   'jc_full_odds': '2.03,3.35,3.00',
#   'jc_full_win': False,
#   'jc_half_odds': '2.70,2.15,3.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118646',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225181/Live/Italy-Serie-A-2017-2018-Cagliari-Sassuolo',
#   'result': '0 : 1'},
#  '1225182': {'away_team_id': 267,
#   'half_time_result': '0 : 0',
#   'home_team_id': 278,
#   'jc_full_odds': '2.03,3.10,3.25',
#   'jc_full_win': True,
#   'jc_half_odds': '2.75,2.00,3.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118647',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225182/Live/Italy-Serie-A-2017-2018-Genoa-Chievo',
#   'result': '1 : 1'},
#  '1225183': {'away_team_id': 271,
#   'half_time_result': '0 : 0',
#   'home_team_id': 76,
#   'jc_full_odds': '3.10,3.35,2.00',
#   'jc_full_win': True,
#   'jc_half_odds': '3.60,2.15,2.60',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118649',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225183/Live/Italy-Serie-A-2017-2018-Verona-Sampdoria',
#   'result': '0 : 0'},
#  '1225184': {'away_team_id': 73,
#   'half_time_result': '0 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.28,4.60,8.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.73,2.45,7.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118642',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225184/Live/Italy-Serie-A-2017-2018-Juventus-Fiorentina',
#   'result': '1 : 0'},
#  '1225185': {'away_team_id': 276,
#   'half_time_result': '1 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '3.10,3.50,1.95',
#   'jc_full_win': True,
#   'jc_half_odds': '3.35,2.30,2.55',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118643',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225185/Live/Italy-Serie-A-2017-2018-Lazio-Napoli',
#   'result': '1 : 4'},
#  '1225186': {'away_team_id': 1502,
#   'half_time_result': '1 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '1.19,5.50,10.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.58,2.70,8.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118644',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225186/Live/Italy-Serie-A-2017-2018-AC-Milan-SPAL-2013',
#   'result': '2 : 0'},
#  '1225187': {'away_team_id': 72,
#   'half_time_result': '0 : 2',
#   'home_team_id': 86,
#   'jc_full_odds': '2.90,3.30,2.10',
#   'jc_full_win': True,
#   'jc_half_odds': '3.35,2.15,2.75',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118648',
#   'match_datetime': 'Wed, 20-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225187/Live/Italy-Serie-A-2017-2018-Udinese-Torino',
#   'result': '2 : 3'},
#  '1225188': {'away_team_id': 267,
#   'half_time_result': '0 : 0',
#   'home_team_id': 78,
#   'jc_full_odds': '2.20,3.05,2.92',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,1.96,3.65',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118845',
#   'match_datetime': 'Sun, 24-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225188/Live/Italy-Serie-A-2017-2018-Cagliari-Chievo',
#   'result': '0 : 2'},
#  '1225189': {'away_team_id': 1503,
#   'half_time_result': '1 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '1.88,3.15,3.65',
#   'jc_full_win': True,
#   'jc_half_odds': '2.50,2.03,4.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118846',
#   'match_datetime': 'Sun, 24-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225189/Live/Italy-Serie-A-2017-2018-Crotone-Benevento',
#   'result': '2 : 0'},
#  '1225190': {'away_team_id': 300,
#   'half_time_result': '1 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '2.10,3.30,2.90',
#   'jc_full_win': True,
#   'jc_half_odds': '2.80,2.15,3.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118879',
#   'match_datetime': 'Sun, 24-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225190/Live/Italy-Serie-A-2017-2018-Fiorentina-Atalanta',
#   'result': '1 : 1'},
#  '1225191': {'away_team_id': 77,
#   'half_time_result': '0 : 2',
#   'home_team_id': 76,
#   'jc_full_odds': '5.70,4.05,1.43',
#   'jc_full_win': True,
#   'jc_half_odds': '5.45,2.35,1.92',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118844',
#   'match_datetime': 'Sun, 24-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225191/Live/Italy-Serie-A-2017-2018-Verona-Lazio',
#   'result': '0 : 3'},
#  '1225192': {'away_team_id': 278,
#   'half_time_result': '0 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '1.24,5.00,8.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.67,2.55,7.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118843',
#   'match_datetime': 'Sun, 24-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225192/Live/Italy-Serie-A-2017-2018-Inter-Genoa',
#   'result': '1 : 0'},
#  '1225193': {'away_team_id': 72,
#   'half_time_result': '2 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.30,4.50,7.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.76,2.50,6.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118802',
#   'match_datetime': 'Sat, 23-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225193/Live/Italy-Serie-A-2017-2018-Juventus-Torino',
#   'result': '4 : 0'},
#  '1225194': {'away_team_id': 86,
#   'half_time_result': '3 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.17,5.70,11.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.53,2.78,8.75',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118739',
#   'match_datetime': 'Sat, 23-Sep-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225194/Live/Italy-Serie-A-2017-2018-Roma-Udinese',
#   'result': '3 : 1'},
#  '1225195': {'away_team_id': 80,
#   'half_time_result': '0 : 0',
#   'home_team_id': 271,
#   'jc_full_odds': '3.50,3.45,1.83',
#   'jc_full_win': False,
#   'jc_half_odds': '4.00,2.25,2.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118832',
#   'match_datetime': 'Sun, 24-Sep-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225195/Live/Italy-Serie-A-2017-2018-Sampdoria-AC-Milan',
#   'result': '2 : 0'},
#  '1225196': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 2889,
#   'jc_full_odds': '1.85,3.25,3.65',
#   'jc_full_win': False,
#   'jc_half_odds': '2.45,2.10,4.10',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118862',
#   'match_datetime': 'Sun, 24-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225196/Live/Italy-Serie-A-2017-2018-Sassuolo-Bologna',
#   'result': '0 : 1'},
#  '1225197': {'away_team_id': 276,
#   'half_time_result': '1 : 1',
#   'home_team_id': 1502,
#   'jc_full_odds': '11.00,5.90,1.16',
#   'jc_full_win': True,
#   'jc_half_odds': '8.50,2.85,1.52',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=118780',
#   'match_datetime': 'Sat, 23-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225197/Live/Italy-Serie-A-2017-2018-SPAL-2013-Napoli',
#   'result': '2 : 3'},
#  '1225198': {'away_team_id': 87,
#   'half_time_result': '1 : 2',
#   'home_team_id': 300,
#   'jc_full_odds': '4.45,3.35,1.67',
#   'jc_full_win': True,
#   'jc_half_odds': '4.70,2.08,2.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119218',
#   'match_datetime': 'Sun, 01-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225198/Live/Italy-Serie-A-2017-2018-Atalanta-Juventus',
#   'result': '2 : 2'},
#  '1225199': {'away_team_id': 75,
#   'half_time_result': '1 : 2',
#   'home_team_id': 1503,
#   'jc_full_odds': '8.70,5.00,1.24',
#   'jc_full_win': True,
#   'jc_half_odds': '6.80,2.60,1.68',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119178',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225199/Live/Italy-Serie-A-2017-2018-Benevento-Inter',
#   'result': '1 : 2'},
#  '1225200': {'away_team_id': 73,
#   'half_time_result': '1 : 1',
#   'home_team_id': 267,
#   'jc_full_odds': '2.75,3.10,2.30',
#   'jc_full_win': False,
#   'jc_half_odds': '3.45,2.00,2.95',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119181',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225200/Live/Italy-Serie-A-2017-2018-Chievo-Fiorentina',
#   'result': '2 : 1'},
#  '1225201': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 278,
#   'jc_full_odds': '2.05,3.00,3.30',
#   'jc_full_win': False,
#   'jc_half_odds': '2.85,1.90,4.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119129',
#   'match_datetime': 'Sat, 30-Sep-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225201/Live/Italy-Serie-A-2017-2018-Genoa-Bologna',
#   'result': '0 : 1'},
#  '1225202': {'away_team_id': 2889,
#   'half_time_result': '1 : 1',
#   'home_team_id': 77,
#   'jc_full_odds': '1.40,4.25,5.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.86,2.45,5.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119179',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225202/Live/Italy-Serie-A-2017-2018-Lazio-Sassuolo',
#   'result': '6 : 1'},
#  '1225203': {'away_team_id': 84,
#   'half_time_result': '0 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '2.35,3.40,2.48',
#   'jc_full_win': False,
#   'jc_half_odds': '3.00,2.12,3.10',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119199',
#   'match_datetime': 'Sun, 01-Oct-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225203/Live/Italy-Serie-A-2017-2018-AC-Milan-Roma',
#   'result': '0 : 2'},
#  '1225204': {'away_team_id': 78,
#   'half_time_result': '2 : 0',
#   'home_team_id': 276,
#   'jc_full_odds': '1.06,8.80,18.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.37,3.30,10.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119166',
#   'match_datetime': 'Sun, 01-Oct-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225204/Live/Italy-Serie-A-2017-2018-Napoli-Cagliari',
#   'result': '3 : 0'},
#  '1225205': {'away_team_id': 779,
#   'half_time_result': '1 : 0',
#   'home_team_id': 1502,
#   'jc_full_odds': '1.82,3.10,4.00',
#   'jc_full_win': True,
#   'jc_half_odds': '2.50,2.00,4.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119182',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225205/Live/Italy-Serie-A-2017-2018-SPAL-2013-Crotone',
#   'result': '1 : 1'},
#  '1225206': {'away_team_id': 76,
#   'half_time_result': '2 : 0',
#   'home_team_id': 72,
#   'jc_full_odds': '1.27,4.85,7.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.72,2.55,6.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119180',
#   'match_datetime': 'Sun, 01-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225206/Live/Italy-Serie-A-2017-2018-Torino-Verona',
#   'result': '2 : 2'},
#  '1225207': {'away_team_id': 271,
#   'half_time_result': '1 : 0',
#   'home_team_id': 86,
#   'jc_full_odds': '2.45,3.25,2.45',
#   'jc_full_win': True,
#   'jc_half_odds': '3.15,2.03,3.15',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119107',
#   'match_datetime': 'Sat, 30-Sep-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225207/Live/Italy-Serie-A-2017-2018-Udinese-Sampdoria',
#   'result': '4 : 0'},
#  '1225208': {'away_team_id': 1502,
#   'half_time_result': '1 : 0',
#   'home_team_id': 71,
#   'jc_full_odds': '1.79,3.15,4.05',
#   'jc_full_win': True,
#   'jc_half_odds': '2.45,2.03,4.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119620',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225208/Live/Italy-Serie-A-2017-2018-Bologna-SPAL-2013',
#   'result': '2 : 1'},
#  '1225209': {'away_team_id': 278,
#   'half_time_result': '0 : 2',
#   'home_team_id': 78,
#   'jc_full_odds': '2.25,3.10,2.80',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,2.00,3.50',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119621',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225209/Live/Italy-Serie-A-2017-2018-Cagliari-Genoa',
#   'result': '2 : 3'},
#  '1225210': {'away_team_id': 72,
#   'half_time_result': '1 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '3.20,3.20,2.00',
#   'jc_full_win': True,
#   'jc_half_odds': '3.85,2.10,2.55',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119622',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225210/Live/Italy-Serie-A-2017-2018-Crotone-Torino',
#   'result': '2 : 2'},
#  '1225211': {'away_team_id': 86,
#   'half_time_result': '1 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '1.48,3.90,5.25',
#   'jc_full_win': True,
#   'jc_half_odds': '1.96,2.35,5.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119605',
#   'match_datetime': 'Sun, 15-Oct-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225211/Live/Italy-Serie-A-2017-2018-Fiorentina-Udinese',
#   'result': '2 : 1'},
#  '1225212': {'away_team_id': 1503,
#   'half_time_result': '0 : 0',
#   'home_team_id': 76,
#   'jc_full_odds': '1.77,3.35,3.85',
#   'jc_full_win': True,
#   'jc_half_odds': '2.30,2.12,4.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119680',
#   'match_datetime': 'Mon, 16-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225212/Live/Italy-Serie-A-2017-2018-Verona-Benevento',
#   'result': '1 : 0'},
#  '1225213': {'away_team_id': 80,
#   'half_time_result': '1 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '2.00,3.35,3.10',
#   'jc_full_win': True,
#   'jc_half_odds': '2.65,2.15,3.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119648',
#   'match_datetime': 'Sun, 15-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225213/Live/Italy-Serie-A-2017-2018-Inter-AC-Milan',
#   'result': '3 : 2'},
#  '1225214': {'away_team_id': 77,
#   'half_time_result': '1 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.46,3.85,5.60',
#   'jc_full_win': False,
#   'jc_half_odds': '2.00,2.28,5.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119556',
#   'match_datetime': 'Sat, 14-Oct-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225214/Live/Italy-Serie-A-2017-2018-Juventus-Lazio',
#   'result': '1 : 2'},
#  '1225215': {'away_team_id': 276,
#   'half_time_result': '0 : 1',
#   'home_team_id': 84,
#   'jc_full_odds': '2.82,3.55,2.05',
#   'jc_full_win': True,
#   'jc_half_odds': '3.40,2.20,2.65',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119578',
#   'match_datetime': 'Sat, 14-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225215/Live/Italy-Serie-A-2017-2018-Roma-Napoli',
#   'result': '0 : 1'},
#  '1225216': {'away_team_id': 300,
#   'half_time_result': '0 : 1',
#   'home_team_id': 271,
#   'jc_full_odds': '3.10,3.20,2.05',
#   'jc_full_win': False,
#   'jc_half_odds': '3.70,2.10,2.62',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119619',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225216/Live/Italy-Serie-A-2017-2018-Sampdoria-Atalanta',
#   'result': '3 : 1'},
#  '1225217': {'away_team_id': 267,
#   'half_time_result': '0 : 0',
#   'home_team_id': 2889,
#   'jc_full_odds': '2.12,3.05,3.10',
#   'jc_full_win': True,
#   'jc_half_odds': '2.85,1.95,3.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119623',
#   'match_datetime': 'Sun, 15-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225217/Live/Italy-Serie-A-2017-2018-Sassuolo-Chievo',
#   'result': '0 : 0'},
#  '1225218': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 300,
#   'jc_full_odds': '1.52,3.60,5.30',
#   'jc_full_win': True,
#   'jc_half_odds': '2.10,2.15,5.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119918',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225218/Live/Italy-Serie-A-2017-2018-Atalanta-Bologna',
#   'result': '1 : 0'},
#  '1225219': {'away_team_id': 73,
#   'half_time_result': '0 : 1',
#   'home_team_id': 1503,
#   'jc_full_odds': '5.60,4.10,1.43',
#   'jc_full_win': True,
#   'jc_half_odds': '5.35,2.40,1.90',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119919',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225219/Live/Italy-Serie-A-2017-2018-Benevento-Fiorentina',
#   'result': '0 : 3'},
#  '1225220': {'away_team_id': 76,
#   'half_time_result': '2 : 1',
#   'home_team_id': 267,
#   'jc_full_odds': '1.88,3.15,3.65',
#   'jc_full_win': True,
#   'jc_half_odds': '2.50,2.00,4.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119905',
#   'match_datetime': 'Sun, 22-Oct-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225220/Live/Italy-Serie-A-2017-2018-Chievo-Verona',
#   'result': '3 : 2'},
#  '1225221': {'away_team_id': 78,
#   'half_time_result': '2 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '1.16,5.80,11.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.53,2.82,8.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119951',
#   'match_datetime': 'Sun, 22-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225221/Live/Italy-Serie-A-2017-2018-Lazio-Cagliari',
#   'result': '3 : 0'},
#  '1225222': {'away_team_id': 278,
#   'half_time_result': '0 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '1.44,3.95,5.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.97,2.30,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119917',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225222/Live/Italy-Serie-A-2017-2018-AC-Milan-Genoa',
#   'result': '0 : 0'},
#  '1225223': {'away_team_id': 75,
#   'half_time_result': '0 : 0',
#   'home_team_id': 276,
#   'jc_full_odds': '1.40,4.25,5.80',
#   'jc_full_win': True,
#   'jc_half_odds': '1.85,2.48,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119882',
#   'match_datetime': 'Sat, 21-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225223/Live/Italy-Serie-A-2017-2018-Napoli-Inter',
#   'result': '0 : 0'},
#  '1225224': {'away_team_id': 779,
#   'half_time_result': '3 : 0',
#   'home_team_id': 271,
#   'jc_full_odds': '1.42,3.95,6.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.90,2.30,5.95',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119860',
#   'match_datetime': 'Sat, 21-Oct-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225224/Live/Italy-Serie-A-2017-2018-Sampdoria-Crotone',
#   'result': '5 : 0'},
#  '1225225': {'away_team_id': 2889,
#   'half_time_result': '0 : 1',
#   'home_team_id': 1502,
#   'jc_full_odds': '2.55,3.10,2.45',
#   'jc_full_win': True,
#   'jc_half_odds': '3.25,1.98,3.15',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119920',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225225/Live/Italy-Serie-A-2017-2018-SPAL-2013-Sassuolo',
#   'result': '0 : 1'},
#  '1225226': {'away_team_id': 84,
#   'half_time_result': '0 : 0',
#   'home_team_id': 72,
#   'jc_full_odds': '3.35,3.70,1.81',
#   'jc_full_win': True,
#   'jc_half_odds': '3.60,2.40,2.30',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119916',
#   'match_datetime': 'Sun, 22-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225226/Live/Italy-Serie-A-2017-2018-Torino-Roma',
#   'result': '0 : 1'},
#  '1225227': {'away_team_id': 87,
#   'half_time_result': '1 : 2',
#   'home_team_id': 86,
#   'jc_full_odds': '8.50,4.45,1.28',
#   'jc_full_win': True,
#   'jc_half_odds': '8.00,2.35,1.73',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=119935',
#   'match_datetime': 'Sun, 22-Oct-17, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225227/Live/Italy-Serie-A-2017-2018-Udinese-Juventus',
#   'result': '2 : 6'},
#  '1225228': {'away_team_id': 76,
#   'half_time_result': '0 : 0',
#   'home_team_id': 300,
#   'jc_full_odds': '1.22,5.00,9.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.63,2.55,8.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120038',
#   'match_datetime': 'Wed, 25-Oct-17, 17:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225228/Live/Italy-Serie-A-2017-2018-Atalanta-Verona',
#   'result': '3 : 0'},
#  '1225229': {'away_team_id': 77,
#   'half_time_result': '0 : 2',
#   'home_team_id': 71,
#   'jc_full_odds': '4.50,3.60,1.60',
#   'jc_full_win': True,
#   'jc_half_odds': '4.60,2.25,2.15',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120055',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225229/Live/Italy-Serie-A-2017-2018-Bologna-Lazio',
#   'result': '1 : 2'},
#  '1225230': {'away_team_id': 1503,
#   'half_time_result': '1 : 0',
#   'home_team_id': 78,
#   'jc_full_odds': '1.50,3.80,5.20',
#   'jc_full_win': True,
#   'jc_half_odds': '2.05,2.25,5.10',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120056',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225230/Live/Italy-Serie-A-2017-2018-Cagliari-Benevento',
#   'result': '2 : 1'},
#  '1225231': {'away_team_id': 80,
#   'half_time_result': '0 : 2',
#   'home_team_id': 267,
#   'jc_full_odds': '3.10,3.15,2.08',
#   'jc_full_win': True,
#   'jc_half_odds': '3.70,2.00,2.80',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120053',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225231/Live/Italy-Serie-A-2017-2018-Chievo-AC-Milan',
#   'result': '1 : 4'},
#  '1225232': {'away_team_id': 72,
#   'half_time_result': '1 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '1.62,3.80,4.10',
#   'jc_full_win': True,
#   'jc_half_odds': '2.10,2.38,4.35',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120057',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225232/Live/Italy-Serie-A-2017-2018-Fiorentina-Torino',
#   'result': '3 : 0'},
#  '1225233': {'away_team_id': 276,
#   'half_time_result': '1 : 2',
#   'home_team_id': 278,
#   'jc_full_odds': '7.80,4.70,1.28',
#   'jc_full_win': True,
#   'jc_half_odds': '6.25,2.48,1.77',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120058',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225233/Live/Italy-Serie-A-2017-2018-Genoa-Napoli',
#   'result': '2 : 3'},
#  '1225234': {'away_team_id': 271,
#   'half_time_result': '2 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '1.32,4.55,6.80',
#   'jc_full_win': True,
#   'jc_half_odds': '1.78,2.50,6.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120007',
#   'match_datetime': 'Tue, 24-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225234/Live/Italy-Serie-A-2017-2018-Inter-Sampdoria',
#   'result': '3 : 2'},
#  '1225235': {'away_team_id': 1502,
#   'half_time_result': '2 : 1',
#   'home_team_id': 87,
#   'jc_full_odds': '1.06,8.00,23.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.39,3.00,13.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120054',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225235/Live/Italy-Serie-A-2017-2018-Juventus-SPAL-2013',
#   'result': '4 : 1'},
#  '1225236': {'away_team_id': 779,
#   'half_time_result': '1 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.08,7.50,18.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.42,3.05,10.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120059',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225236/Live/Italy-Serie-A-2017-2018-Roma-Crotone',
#   'result': '1 : 0'},
#  '1225237': {'away_team_id': 86,
#   'half_time_result': '0 : 1',
#   'home_team_id': 2889,
#   'jc_full_odds': '1.85,3.35,3.55',
#   'jc_full_win': False,
#   'jc_half_odds': '2.45,2.15,3.90',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120060',
#   'match_datetime': 'Wed, 25-Oct-17, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225237/Live/Italy-Serie-A-2017-2018-Sassuolo-Udinese',
#   'result': '0 : 1'},
#  '1225238': {'away_team_id': 77,
#   'half_time_result': '0 : 3',
#   'home_team_id': 1503,
#   'jc_full_odds': '9.25,5.50,1.20',
#   'jc_full_win': True,
#   'jc_half_odds': '7.50,2.80,1.57',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120256',
#   'match_datetime': 'Sun, 29-Oct-17, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225238/Live/Italy-Serie-A-2017-2018-Benevento-Lazio',
#   'result': '1 : 5'},
#  '1225239': {'away_team_id': 73,
#   'half_time_result': '2 : 1',
#   'home_team_id': 779,
#   'jc_full_odds': '5.15,3.75,1.51',
#   'jc_full_win': False,
#   'jc_half_odds': '5.10,2.25,2.05',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=120270',
#   'match_datetime': 'Sun, 29-Oct-17, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225239/Live/Italy-Serie-A-2017-2018-Crotone-Fiorentina',
#   'result': '2 : 1'},
#  '1225240': {'away_team_id': 75,
#   'half_time_result': '0 : 1',
# ...
#   'result': '1 : 1'},
#  '1225387': {'away_team_id': 77,
#   'half_time_result': '0 : 2',
#   'home_team_id': 2889,
#   'jc_full_odds': '3.90,3.55,1.71',
#   'jc_full_win': True,
#   'jc_half_odds': '4.20,2.25,2.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123968',
#   'match_datetime': 'Sun, 25-Feb-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225387/Live/Italy-Serie-A-2017-2018-Sassuolo-Lazio',
#   'result': '0 : 3'},
#  '1225388': {'away_team_id': 76,
#   'half_time_result': '0 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '1.12,6.60,12.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.47,3.05,8.50',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123742',
#   'match_datetime': 'Mon, 19-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225388/Live/Italy-Serie-A-2017-2018-Lazio-Verona',
#   'result': '2 : 0'},
#  '1225389': {'away_team_id': 80,
#   'half_time_result': '0 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.80,3.40,3.65',
#   'jc_full_win': False,
#   'jc_half_odds': '2.45,2.22,3.70',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123989',
#   'match_datetime': 'Sun, 25-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225389/Live/Italy-Serie-A-2017-2018-Roma-AC-Milan',
#   'result': '0 : 2'},
#  '1225390': {'away_team_id': 75,
#   'half_time_result': '1 : 0',
#   'home_team_id': 278,
#   'jc_full_odds': '2.90,3.00,2.25',
#   'jc_full_win': False,
#   'jc_half_odds': '3.70,1.90,3.00',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123674',
#   'match_datetime': 'Sat, 17-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225390/Live/Italy-Serie-A-2017-2018-Genoa-Inter',
#   'result': '2 : 0'},
#  '1225391': {'away_team_id': 276,
#   'half_time_result': '0 : 2',
#   'home_team_id': 78,
#   'jc_full_odds': '8.50,4.75,1.26',
#   'jc_full_win': True,
#   'jc_half_odds': '7.50,2.52,1.68',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124004',
#   'match_datetime': 'Mon, 26-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225391/Live/Italy-Serie-A-2017-2018-Cagliari-Napoli',
#   'result': '0 : 5'},
#  '1225392': {'away_team_id': 87,
#   'half_time_result': '0 : 1',
#   'home_team_id': 72,
#   'jc_full_odds': '4.80,3.35,1.62',
#   'jc_full_win': True,
#   'jc_half_odds': '5.05,2.10,2.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123690',
#   'match_datetime': 'Sun, 18-Feb-18, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225392/Live/Italy-Serie-A-2017-2018-Torino-Juventus',
#   'result': '0 : 1'},
#  '1225393': {'away_team_id': 1502,
#   'half_time_result': '0 : 1',
#   'home_team_id': 779,
#   'jc_full_odds': '2.15,2.95,3.15',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,1.88,4.00',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123957',
#   'match_datetime': 'Sun, 25-Feb-18, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225393/Live/Italy-Serie-A-2017-2018-Crotone-SPAL-2013',
#   'result': '2 : 3'},
#  '1225394': {'away_team_id': 84,
#   'half_time_result': '0 : 0',
#   'home_team_id': 86,
#   'jc_full_odds': '4.10,3.55,1.67',
#   'jc_full_win': True,
#   'jc_half_odds': '4.40,2.25,2.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123626',
#   'match_datetime': 'Sat, 17-Feb-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225394/Live/Italy-Serie-A-2017-2018-Udinese-Roma',
#   'result': '0 : 2'},
#  '1225395': {'away_team_id': 72,
#   'half_time_result': '1 : 0',
#   'home_team_id': 76,
#   'jc_full_odds': '5.20,3.80,1.50',
#   'jc_full_win': False,
#   'jc_half_odds': '5.15,2.30,2.00',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123971',
#   'match_datetime': 'Sun, 25-Feb-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225395/Live/Italy-Serie-A-2017-2018-Verona-Torino',
#   'result': '2 : 1'},
#  '1225396': {'away_team_id': 271,
#   'half_time_result': '1 : 0',
#   'home_team_id': 80,
#   'jc_full_odds': '1.54,3.75,4.80',
#   'jc_full_win': True,
#   'jc_half_odds': '2.05,2.30,4.90',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123723',
#   'match_datetime': 'Sun, 18-Feb-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225396/Live/Italy-Serie-A-2017-2018-AC-Milan-Sampdoria',
#   'result': '1 : 0'},
#  '1225397': {'away_team_id': 86,
#   'half_time_result': '1 : 0',
#   'home_team_id': 271,
#   'jc_full_odds': '1.84,3.30,3.60',
#   'jc_full_win': True,
#   'jc_half_odds': '2.45,2.15,3.95',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=123970',
#   'match_datetime': 'Sun, 25-Feb-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225397/Live/Italy-Serie-A-2017-2018-Sampdoria-Udinese',
#   'result': '2 : 1'},
#  '1225400': {'away_team_id': 71,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1502,
#   'jc_full_odds': '2.27,3.05,2.82',
#   'jc_full_win': True,
#   'jc_half_odds': '2.95,1.93,3.70',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124122',
#   'match_datetime': 'Sat, 03-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225400/Live/Italy-Serie-A-2017-2018-SPAL-2013-Bologna',
#   'result': '1 : 0'},
#  '1225422': {'away_team_id': 87,
#   'half_time_result': '0 : 0',
#   'home_team_id': 77,
#   'jc_full_odds': '3.00,3.00,2.20',
#   'jc_full_win': True,
#   'jc_half_odds': '3.80,1.90,2.95',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124162',
#   'match_datetime': 'Sat, 03-Mar-18, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225422/Live/Italy-Serie-A-2017-2018-Lazio-Juventus',
#   'result': '0 : 1'},
#  '1225424': {'away_team_id': 84,
#   'half_time_result': '1 : 2',
#   'home_team_id': 276,
#   'jc_full_odds': '1.50,3.85,5.10',
#   'jc_full_win': False,
#   'jc_half_odds': '2.00,2.30,5.20',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124185',
#   'match_datetime': 'Sat, 03-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225424/Live/Italy-Serie-A-2017-2018-Napoli-Roma',
#   'result': '2 : 4'},
#  '1225430': {'away_team_id': 300,
#   'half_time_result': '0 : 0',
#   'home_team_id': 71,
#   'jc_full_odds': '4.10,3.25,1.75',
#   'jc_full_win': True,
#   'jc_half_odds': '4.70,2.05,2.35',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124522',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225430/Live/Italy-Serie-A-2017-2018-Bologna-Atalanta',
#   'result': '0 : 1'},
#  '1225432': {'away_team_id': 1503,
#   'half_time_result': '1 : 0',
#   'home_team_id': 73,
#   'jc_full_odds': '1.30,4.50,7.75',
#   'jc_full_win': True,
#   'jc_half_odds': '1.75,2.40,7.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124501',
#   'match_datetime': 'Sun, 11-Mar-18, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225432/Live/Italy-Serie-A-2017-2018-Fiorentina-Benevento',
#   'result': '1 : 0'},
#  '1225434': {'away_team_id': 267,
#   'half_time_result': '0 : 0',
#   'home_team_id': 76,
#   'jc_full_odds': '3.45,3.20,1.93',
#   'jc_full_win': False,
#   'jc_half_odds': '4.00,2.03,2.60',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124469',
#   'match_datetime': 'Sat, 10-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225434/Live/Italy-Serie-A-2017-2018-Verona-Chievo',
#   'result': '1 : 0'},
#  '1225436': {'away_team_id': 77,
#   'half_time_result': '1 : 1',
#   'home_team_id': 78,
#   'jc_full_odds': '5.25,3.90,1.48',
#   'jc_full_win': True,
#   'jc_half_odds': '5.30,2.30,1.98',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124521',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225436/Live/Italy-Serie-A-2017-2018-Cagliari-Lazio',
#   'result': '2 : 2'},
#  '1225438': {'away_team_id': 80,
#   'half_time_result': '0 : 0',
#   'home_team_id': 278,
#   'jc_full_odds': '3.15,2.98,2.12',
#   'jc_full_win': True,
#   'jc_half_odds': '4.00,1.90,2.85',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124535',
#   'match_datetime': 'Sun, 11-Mar-18, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225438/Live/Italy-Serie-A-2017-2018-Genoa-AC-Milan',
#   'result': '0 : 1'},
#  '1225440': {'away_team_id': 276,
#   'half_time_result': '0 : 0',
#   'home_team_id': 75,
#   'jc_full_odds': '3.40,3.30,1.90',
#   'jc_full_win': True,
#   'jc_half_odds': '3.85,2.10,2.55',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124548',
#   'match_datetime': 'Sun, 11-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225440/Live/Italy-Serie-A-2017-2018-Inter-Napoli',
#   'result': '0 : 0'},
#  '1225442': {'away_team_id': 271,
#   'half_time_result': '3 : 0',
#   'home_team_id': 779,
#   'jc_full_odds': '2.52,3.05,2.52',
#   'jc_full_win': True,
#   'jc_half_odds': '3.25,1.95,3.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124523',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225442/Live/Italy-Serie-A-2017-2018-Crotone-Sampdoria',
#   'result': '4 : 1'},
#  '1225444': {'away_team_id': 1502,
#   'half_time_result': '1 : 1',
#   'home_team_id': 2889,
#   'jc_full_odds': '1.85,3.15,3.75',
#   'jc_full_win': True,
#   'jc_half_odds': '2.50,2.05,4.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124524',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225444/Live/Italy-Serie-A-2017-2018-Sassuolo-SPAL-2013',
#   'result': '1 : 1'},
#  '1225446': {'away_team_id': 72,
#   'half_time_result': '0 : 0',
#   'home_team_id': 84,
#   'jc_full_odds': '1.45,3.95,5.50',
#   'jc_full_win': True,
#   'jc_half_odds': '2.00,2.25,5.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124378',
#   'match_datetime': 'Fri, 09-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225446/Live/Italy-Serie-A-2017-2018-Roma-Torino',
#   'result': '3 : 0'},
#  '1225448': {'away_team_id': 86,
#   'half_time_result': '1 : 0',
#   'home_team_id': 87,
#   'jc_full_odds': '1.16,5.40,13.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.57,2.55,10.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124520',
#   'match_datetime': 'Sun, 11-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225448/Live/Italy-Serie-A-2017-2018-Juventus-Udinese',
#   'result': '2 : 0'},
#  '1225450': {'away_team_id': 300,
#   'half_time_result': '0 : 2',
#   'home_team_id': 76,
#   'jc_full_odds': '7.00,4.25,1.34',
#   'jc_full_win': True,
#   'jc_half_odds': '6.75,2.40,1.77',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124820',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225450/Live/Italy-Serie-A-2017-2018-Verona-Atalanta',
#   'result': '0 : 5'},
#  '1225452': {'away_team_id': 71,
#   'half_time_result': '1 : 1',
#   'home_team_id': 77,
#   'jc_full_odds': '1.25,4.80,8.70',
#   'jc_full_win': True,
#   'jc_half_odds': '1.70,2.48,7.25',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124846',
#   'match_datetime': 'Sun, 18-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225452/Live/Italy-Serie-A-2017-2018-Lazio-Bologna',
#   'result': '1 : 1'},
#  '1225454': {'away_team_id': 78,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1503,
#   'jc_full_odds': '2.23,3.15,2.80',
#   'jc_full_win': False,
#   'jc_half_odds': '2.90,2.05,3.40',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124819',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225454/Live/Italy-Serie-A-2017-2018-Benevento-Cagliari',
#   'result': '1 : 2'},
#  '1225456': {'away_team_id': 267,
#   'half_time_result': '1 : 2',
#   'home_team_id': 80,
#   'jc_full_odds': '1.28,4.45,8.50',
#   'jc_full_win': True,
#   'jc_half_odds': '1.78,2.35,7.20',
#   'jc_half_win': False,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124816',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225456/Live/Italy-Serie-A-2017-2018-AC-Milan-Chievo',
#   'result': '3 : 2'},
#  '1225458': {'away_team_id': 73,
#   'half_time_result': '0 : 0',
#   'home_team_id': 72,
#   'jc_full_odds': '2.45,3.15,2.52',
#   'jc_full_win': False,
#   'jc_half_odds': '3.10,2.03,3.20',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124818',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225458/Live/Italy-Serie-A-2017-2018-Torino-Fiorentina',
#   'result': '1 : 2'},
#  '1225460': {'away_team_id': 278,
#   'half_time_result': '0 : 0',
#   'home_team_id': 276,
#   'jc_full_odds': '1.14,5.80,14.00',
#   'jc_full_win': True,
#   'jc_half_odds': '1.54,2.65,10.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124845',
#   'match_datetime': 'Sun, 18-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225460/Live/Italy-Serie-A-2017-2018-Napoli-Genoa',
#   'result': '1 : 0'},
#  '1225462': {'away_team_id': 75,
#   'half_time_result': '0 : 4',
#   'home_team_id': 271,
#   'jc_full_odds': '3.50,3.30,1.88',
#   'jc_full_win': True,
#   'jc_half_odds': '3.90,2.15,2.45',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124805',
#   'match_datetime': 'Sun, 18-Mar-18, 11:30',
#   'match_link': 'https://www.whoscored.com/Matches/1225462/Live/Italy-Serie-A-2017-2018-Sampdoria-Inter',
#   'result': '0 : 5'},
#  '1225464': {'away_team_id': 87,
#   'half_time_result': '0 : 0',
#   'home_team_id': 1502,
#   'jc_full_odds': '9.75,4.40,1.26',
#   'jc_full_win': True,
#   'jc_half_odds': '9.50,2.25,1.73',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124774',
#   'match_datetime': 'Sat, 17-Mar-18, 19:45',
#   'match_link': 'https://www.whoscored.com/Matches/1225464/Live/Italy-Serie-A-2017-2018-SPAL-2013-Juventus',
#   'result': '0 : 0'},
#  '1225466': {'away_team_id': 84,
#   'half_time_result': '0 : 1',
#   'home_team_id': 779,
#   'jc_full_odds': '5.10,3.90,1.49',
#   'jc_full_win': True,
#   'jc_half_odds': '5.20,2.30,2.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124817',
#   'match_datetime': 'Sun, 18-Mar-18, 14:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225466/Live/Italy-Serie-A-2017-2018-Crotone-Roma',
#   'result': '0 : 2'},
#  '1225468': {'away_team_id': 2889,
#   'half_time_result': '1 : 1',
#   'home_team_id': 86,
#   'jc_full_odds': '1.95,3.20,3.35',
#   'jc_full_win': False,
#   'jc_half_odds': '2.60,2.03,4.00',
#   'jc_half_win': True,
#   'jc_odds_link': 'http://bet.hkjc.com/football/results/last_odds.aspx?lang=EN&id=124750',
#   'match_datetime': 'Sat, 17-Mar-18, 17:00',
#   'match_link': 'https://www.whoscored.com/Matches/1225468/Live/Italy-Serie-A-2017-2018-Udinese-Sassuolo',
#   'result': '1 : 2'}}
