# %% [markdown]
# # Crawl match instances and performance instances

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
import time

driver = webdriver.Chrome()
#driver = webdriver.Safari()
start_url = "https://www.whoscored.com/Regions/108/Tournaments/5/Seasons/6461/Stages/14014/Fixtures/Italy-Serie-A-2016-2017"
driver.get(start_url)

# %%
# Find the link of each match
match_table = {}

prev_month_button = driver.find_element_by_xpath("//*[@id=\"date-controller\"]/a[1]")
prev_button_status = prev_month_button.get_attribute("title")
previous_month = ""
current_month = driver.find_element_by_xpath("//*[@id=\"date-config-toggle-button\"]/span[1]").text

while (prev_button_status == "View previous month"):
    while (current_month == previous_month):
        prev_month_button.click()
        time.sleep(1)
        current_month = driver.find_element_by_xpath("//*[@id=\"date-config-toggle-button\"]/span[1]").text
        prev_button_status = prev_month_button.get_attribute("title")

    while True:
        try:
            # match_table = {}
            trs = driver.find_elements_by_xpath("//*[@id=\"tournament-fixture\"]/tbody/tr")

            for tr in trs:
                tds = tr.find_elements_by_xpath("td")
                if(len(tds)):
                    match_id = tr.get_attribute("data-id")
                    match_table[match_id] = {}
                for i, td in enumerate(tds):
                    if(i == 4):
                        match_table[match_id]["match_link"] = td.find_element_by_tag_name("a").get_attribute("href")
            break
        except:
            print("wait")
            time.sleep(0.5)

    previous_month = current_month

# %%
# Crawl data of each match details
print("Total number of matches:{}.".format(len(match_table)))
cnt = 1
subdriver = webdriver.Chrome()
for match_id, match_details in match_table.items():
    match_link = match_details["match_link"]
    # Change into the match page
    print(">>> {}: Crawling {}...".format(cnt, match_id))
    cnt += 1
    
    subdriver.get(match_link)
    time.sleep(1)
    web_match_trs = subdriver.find_elements_by_xpath("//*[@id=\"match-header\"]/table/tbody/tr")

    # Crawl basic match information
    web_match_tr = web_match_trs[0]
    web_match_tds = web_match_tr.find_elements_by_tag_name("td")
    home_team_id = int(re.findall(r'\d+', web_match_tds[0].find_element_by_tag_name("a").get_attribute("href"))[0])
    away_team_id = int(re.findall(r'\d+', web_match_tds[2].find_element_by_tag_name("a").get_attribute("href"))[0])

    web_match_tr = web_match_trs[1]
    web_match_tds = web_match_tr.find_elements_by_tag_name("td")
    web_match_divs = web_match_tds[1].find_elements_by_tag_name("div")
    match_datetime = web_match_divs[2].find_element_by_xpath("dl/dd[2]").text + ", " + web_match_divs[2].find_element_by_xpath("dl/dd[1]").text
    half_time_result = web_match_divs[1].find_element_by_xpath("dl/dd[1]").text
    result = web_match_divs[1].find_element_by_xpath("dl/dd[2]").text
    
    match_table[match_id]["match_datetime"] = match_datetime
    match_table[match_id]["home_team_id"] = home_team_id
    match_table[match_id]["away_team_id"] = away_team_id
    match_table[match_id]["half_time_result"] = half_time_result
    match_table[match_id]["result"] = result
print(">>> finished.")
driver.close()
subdriver.close()
# Out:
# Total number of matches:380.
# >>> 1: Crawling 1115280...
# >>> 2: Crawling 1115216...
# >>> 3: Crawling 1115389...
# >>> 4: Crawling 1115500...
# >>> 5: Crawling 1115205...
# >>> 6: Crawling 1115298...
# >>> 7: Crawling 1115445...
# >>> 8: Crawling 1115170...
# >>> 366: Crawling 1115284...
# >>> 367: Crawling 1115242...
# >>> 368: Crawling 1115157...
# >>> 369: Crawling 1115467...
# >>> 370: Crawling 1115221...
# >>> 371: Crawling 1115267...
# >>> 372: Crawling 1115376...
# >>> 373: Crawling 1115391...
# >>> 374: Crawling 1115371...
# >>> 375: Crawling 1115418...
# >>> 376: Crawling 1115299...
# >>> 377: Crawling 1115248...
# >>> 378: Crawling 1115290...
# >>> 379: Crawling 1115174...
# >>> 380: Crawling 1115308...

# %%
import json

with open('match_instances_table.json', 'w') as fp:
    json.dump(match_table, fp, indent=4)

# %% [markdown]
# ### Example for reading JSON as Dataframe

# %%
import pandas as pd
tmp = pd.read_json('match_instances_table.json', orient='index')

# %% [markdown]
# # Crawl team instances

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
import time

driver = webdriver.Chrome()
start_url = "https://www.whoscored.com/Regions/108/Tournaments/5/Seasons/6461/Stages/14014/TeamStatistics/Italy-Serie-A-2016-2017"
driver.get(start_url)

# %%
team_table = {}

trs = driver.find_elements_by_xpath("//*[@id=\"top-team-stats-summary-content\"]/tr")

for tr in trs:
    team_link = tr.find_element_by_class_name("team-link").get_attribute("href")
    team_id = int(re.findall(r'\d+',team_link)[0])
    team_table[team_id] = {}
    team_table[team_id]["team_link"] = team_link

# %%
# Crawl data of each team
print("Total number of teams:{}.".format(len(team_table)))
cnt = 1
subdriver = webdriver.Chrome()
for team_id, team_details in team_table.items():
    team_link = team_details['team_link']
    # Change into the team page
    print(">>> {}: Crawling {}...".format(cnt, team_id))
    
    while True:
        try:
            subdriver.get(team_link)
            time.sleep(1)

            web_team_img_link = subdriver.find_element_by_xpath("//*[@id=\"layout-content-wrapper\"]/div[2]/div[1]/h2/img").get_attribute("src")
            web_team_name = subdriver.find_element_by_xpath("//*[@id=\"layout-content-wrapper\"]/div[2]/div[1]/h2/span").text
            break
        except:
            time.sleep(1)
    
    team_table[team_id]["team_img_link"] = web_team_img_link
    team_table[team_id]["team_name"] = web_team_name
    
    cnt += 1
    
print(">>> finished.")
driver.close()
subdriver.close()
# Out:
# Total number of teams:20.
# >>> 1: Crawling 272...
# >>> 2: Crawling 267...
# >>> 3: Crawling 779...
# >>> 4: Crawling 278...
# >>> 5: Crawling 71...
# >>> 6: Crawling 72...
# >>> 7: Crawling 73...
# >>> 8: Crawling 277...
# >>> 9: Crawling 75...
# >>> 10: Crawling 300...
# >>> 11: Crawling 77...
# >>> 12: Crawling 2889...
# >>> 13: Crawling 271...
# >>> 14: Crawling 80...
# >>> 15: Crawling 276...
# >>> 16: Crawling 78...
# >>> 17: Crawling 86...
# >>> 18: Crawling 87...
# >>> 19: Crawling 84...
# >>> 20: Crawling 1285...

# %%
import json

with open('team_instances_table.json', 'w') as fp:
    json.dump(team_table, fp, indent=4)

# %% [markdown]
# ### Example for reading JSON as Dataframe

# %%
import pandas as pd
tmp = pd.read_json('team_instances_table.json', orient='index')

# %% [markdown]
# # Crawl player instances

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
import time

driver = webdriver.Chrome()
start_url = "https://www.whoscored.com/Regions/108/Tournaments/5/Seasons/6461/Stages/14014/PlayerStatistics/Italy-Serie-A-2016-2017"
driver.get(start_url)

ALL_PLAYER = True

# %%
player_table = {}

if ALL_PLAYER:
    all_players_button = driver.find_element_by_xpath("//*[@id=\"apps\"]/dd[2]/a")
    all_players_button.click()

time.sleep(1)

# %%
next_button = driver.find_element_by_xpath("//*[@id=\"next\"]")
next_button_status = next_button.get_attribute("class")

player_cnt = 0
player_id_list = []
cnt = 1

while next_button_status != "option  disabled ":
    print(">>> Crawling page {}...".format(cnt))
    while True:
        try:
            player_statistic_tbody = driver.find_element_by_xpath("//*[@id=\"player-table-statistics-body\"]")
            player_trs = player_statistic_tbody.find_elements_by_xpath("tr")
            for tr in player_trs:
                pn = tr.find_element_by_class_name("pn")
                player_link = pn.find_element_by_class_name("player-link").get_attribute("href")
                player_id = int(re.findall(r'\d+', player_link)[0])

                player_table[player_id] = {}
                player_table[player_id]["player_link"] = player_link

                player_id_list.append(player_id)
            break
        except:
            time.sleep(1)
    
    while True:
        try:
            next_button.click()
            break
        except:
            time.sleep(1)
            next_button = driver.find_element_by_xpath("//*[@id=\"next\"]")
    cnt += 1
    next_button = driver.find_element_by_xpath("//*[@id=\"next\"]")
    next_button_status = next_button.get_attribute("class")

print(">>> finished.")
# Out:
# >>> Crawling page 1...
# >>> Crawling page 2...
# >>> Crawling page 3...
# >>> Crawling page 4...
# >>> Crawling page 5...
# >>> Crawling page 6...
# >>> Crawling page 7...
# >>> Crawling page 8...
# >>> Crawling page 9...
# >>> Crawling page 10...
# >>> Crawling page 11...
# >>> Crawling page 12...
# >>> Crawling page 13...
# >>> Crawling page 14...
# >>> Crawling page 15...
# >>> Crawling page 16...
# >>> Crawling page 17...
# >>> Crawling page 18...
# >>> Crawling page 19...
# >>> Crawling page 20...
# >>> Crawling page 21...
# >>> Crawling page 22...
# >>> Crawling page 23...
# >>> Crawling page 24...
# >>> Crawling page 25...
# >>> Crawling page 26...
# >>> Crawling page 27...
# >>> Crawling page 28...
# >>> Crawling page 29...
# >>> Crawling page 30...
# >>> Crawling page 31...
# >>> Crawling page 32...
# >>> Crawling page 33...
# >>> Crawling page 34...
# >>> Crawling page 35...
# >>> Crawling page 36...
# >>> Crawling page 37...
# >>> Crawling page 38...
# >>> Crawling page 39...
# >>> Crawling page 40...
# >>> Crawling page 41...
# >>> Crawling page 42...
# >>> Crawling page 43...
# >>> Crawling page 44...
# >>> Crawling page 45...
# >>> Crawling page 46...
# >>> Crawling page 47...
# >>> Crawling page 48...
# >>> Crawling page 49...
# >>> Crawling page 50...
# >>> Crawling page 51...
# >>> Crawling page 52...
# >>> Crawling page 53...
# >>> Crawling page 54...
# >>> Crawling page 55...
# >>> Crawling page 56...
# >>> Crawling page 57...
# >>> Crawling page 58...
# >>> Crawling page 59...
# >>> finished.

# %%
# Crawl data of each player
print("Total number of players:{}.".format(len(player_table)))
cnt = 1
subdriver = webdriver.Chrome()
for player_id, player_details in player_table.items():
    player_link = player_details['player_link']
    # Change into the player page
    print(">>> {}: Crawling {}...".format(cnt, player_id))

    #while True:
        #try:
    subdriver.get(player_link)
    time.sleep(1)

    web_player_name = subdriver.find_element_by_xpath("//*[@id=\"player-profile\"]/div/div/div[1]/dl[1]/dd").text
    web_player_img_link = subdriver.find_element_by_xpath("//*[@id=\"player-profile\"]/img").get_attribute("src")
    web_player_birthday = subdriver.find_element_by_xpath("//*[@id=\"player-profile\"]/div/div/div[2]/dl[1]/dd/i").text        
    web_player_height = int(re.findall(r'\d+', subdriver.find_element_by_xpath("//*[@id=\"player-profile\"]/div/div/div[2]/dl[2]/dd").text)[0])
    web_player_weight = int(re.findall(r'\d+', subdriver.find_element_by_xpath("//*[@id=\"player-profile\"]/div/div/div[2]/dl[3]/dd").text)[0])
    team_id = int(re.findall(r'\d+', subdriver.find_element_by_xpath("//*[@id=\"player-profile\"]/div/div/div[1]/dl[2]/dd/a").get_attribute("href"))[0])
    last_dl = subdriver.find_elements_by_xpath("//*[@id=\"player-profile\"]/div/div/div[1]/dl")
    web_player_position_items = last_dl[-1].find_elements_by_xpath("/dd/ul/li")
    web_player_position = [item.text for item in web_player_position_items]
        #    break
        #except:
        #    time.sleep(1)
        //*[@id="player-profile"]/div/div/div[1]/dl[4]/dd/ul
    player_table[player_id]["player_name"] = web_player_name   
    player_table[player_id]["player_img_link"] = web_player_img_link
    player_table[player_id]["player_birthday"] = web_player_birthday
    player_table[player_id]["player_height"] = web_player_height
    player_table[player_id]["player_weight"] = web_player_weight
    player_table[player_id]["team_id"] = team_id
    player_table[player_id]["player_position"] = web_player_position

    cnt += 1

print(">>> finished")
driver.close()
subdriver.close()
# Out:
# Total number of players:558.
# >>> 1: Crawling 141312...
# >>> 2: Crawling 6145...
# >>> 3: Crawling 68613...
# >>> 4: Crawling 40966...
# >>> 5: Crawling 131079...
# >>> 6: Crawling 141320...
# >>> 7: Crawling 249865...
# >>> 8: Crawling 98317...
# >>> 9: Crawling 23567...
# >>> 10: Crawling 118801...
# >>> 11: Crawling 22546...
# >>> 12: Crawling 70675...
# >>> 13: Crawling 90132...
# >>> 14: Crawling 6166...
# >>> 15: Crawling 82967...
# >>> 16: Crawling 106522...
# >>> 17: Crawling 90287...
# >>> 18: Crawling 24605...
# >>> 19: Crawling 135198...
# >>> 20: Crawling 78880...
# >>> 21: Crawling 13348...
# >>> 22: Crawling 82438...
# >>> 23: Crawling 67261...
# >>> 24: Crawling 84008...
# >>> 25: Crawling 53975...
# >>> 26: Crawling 33834...
# >>> 27: Crawling 71687...
# >>> 28: Crawling 78892...
# >>> 29: Crawling 15407...
# >>> 30: Crawling 89137...
# >>> 31: Crawling 82994...
# >>> 32: Crawling 19676...
# >>> 33: Crawling 128053...
# >>> 34: Crawling 44087...
# >>> 35: Crawling 44089...
# >>> 36: Crawling 149563...
# >>> 37: Crawling 12348...
# >>> 38: Crawling 101437...
# >>> 39: Crawling 336959...
# >>> 40: Crawling 96321...
# >>> 41: Crawling 148546...
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-21-a8f2d95c85d6> in <module>()
#      13     time.sleep(1)
#      14
# ---> 15     web_player_name = subdriver.find_element_by_xpath("//*[@id=\"player-profile\"]/div/div/div[1]/dl[1]/dd").text
#      16     web_player_img_link = subdriver.find_element_by_xpath("//*[@id=\"player-profile\"]/img").get_attribute("src")
#      17     web_player_birthday = subdriver.find_element_by_xpath("//*[@id=\"player-profile\"]/div/div/div[2]/dl[1]/dd/i").text
#
# ~\AppData\Local\Continuum\Anaconda2\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     366             driver.find_element_by_xpath('//div/td[1]')
#     367         """
# --> 368         return self.find_element(by=By.XPATH, value=xpath)
#     369
#     370     def find_elements_by_xpath(self, xpath):
#
# ~\AppData\Local\Continuum\Anaconda2\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     856         return self.execute(Command.FIND_ELEMENT, {
#     857             'using': by,
# --> 858             'value': value})['value']
#     859
#     860     def find_elements(self, by=By.ID, value=None):
#
# ~\AppData\Local\Continuum\Anaconda2\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     309         response = self.command_executor.execute(driver_command, params)
#     310         if response:
# --> 311             self.error_handler.check_response(response)
#     312             response['value'] = self._unwrap_value(
#     313                 response.get('value', None))
#
# ~\AppData\Local\Continuum\Anaconda2\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     235         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     236             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 237         raise exception_class(message, screen, stacktrace)
#     238
#     239     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="player-profile"]/div/div/div[1]/dl[1]/dd"}
#   (Session info: chrome=63.0.3239.132)
#   (Driver info: chromedriver=2.34.522940 (1a76f96f66e3ca7b8e57d503b4dd3bccfba87af1),platform=Windows NT 6.1.7601 SP1 x86_64)

# %%
import json

with open('player_instances_table.json', 'w') as fp:
    json.dump(player_table, fp, indent=4)

# %%
len(last_dl)
# Out:
# 5

# %%
player_table
# Out:
# {183: {'player_birthday': '27-09-1976',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/183.jpg',
#   'player_link': 'https://www.whoscored.com/Players/183/Show/Francesco-Totti',
#   'player_name': 'Francesco Totti',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 0},
#  538: {'player_birthday': '26-06-1981',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/538.jpg',
#   'player_link': 'https://www.whoscored.com/Players/538/Show/Paolo-Cannavaro',
#   'player_name': 'Paolo Cannavaro',
#   'player_position': [],
#   'player_weight': 83,
#   'team_id': 2889},
#  661: {'player_link': 'https://www.whoscored.com/Players/661/Show/Alessandro-Gamberini'},
#  668: {'player_link': 'https://www.whoscored.com/Players/668/Show/Alberto-Gilardino'},
#  715: {'player_link': 'https://www.whoscored.com/Players/715/Show/Dario-Dainelli'},
#  2877: {'player_link': 'https://www.whoscored.com/Players/2877/Show/Emiliano-Moretti'},
#  2943: {'player_birthday': '11-02-1982',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/2943.jpg',
#   'player_link': 'https://www.whoscored.com/Players/2943/Show/Christian-Maggio',
#   'player_name': 'Christian Maggio',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 276},
#  2987: {'player_link': 'https://www.whoscored.com/Players/2987/Show/Jos%C3%A9-Reina'},
#  3328: {'player_birthday': '28-01-1978',
#   'player_height': 192,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/3328.jpg',
#   'player_link': 'https://www.whoscored.com/Players/3328/Show/Gianluigi-Buffon',
#   'player_name': 'Gianluigi Buffon',
#   'player_position': [],
#   'player_weight': 92,
#   'team_id': 87},
#  3853: {'player_link': 'https://www.whoscored.com/Players/3853/Show/Massimo-Maccarone'},
#  4368: {'player_birthday': '12-04-1979',
#   'player_height': 175,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/4368.jpg',
#   'player_link': 'https://www.whoscored.com/Players/4368/Show/Sergio-Pellissier',
#   'player_name': 'Sergio Pellissier',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 267},
#  4444: {'player_birthday': '09-11-1977',
#   'player_height': 193,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/4444.jpg',
#   'player_link': 'https://www.whoscored.com/Players/4444/Show/Albano-Bizzarri',
#   'player_name': 'Albano Bizzarri',
#   'player_position': [],
#   'player_weight': 89,
#   'team_id': 86},
#  4644: {'player_birthday': '18-06-1982',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/4644.jpg',
#   'player_link': 'https://www.whoscored.com/Players/4644/Show/Marco-Borriello',
#   'player_name': 'Marco Borriello',
#   'player_position': [],
#   'player_weight': 73,
#   'team_id': 1502},
#  5070: {'player_link': 'https://www.whoscored.com/Players/5070/Show/Hugo-Campagnaro'},
#  5202: {'player_birthday': '24-07-1983',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/5202.jpg',
#   'player_link': 'https://www.whoscored.com/Players/5202/Show/Daniele-De-Rossi',
#   'player_name': 'Daniele De Rossi',
#   'player_position': [],
#   'player_weight': 83,
#   'team_id': 84},
#  5734: {'player_birthday': '04-02-1984',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/5734.jpg',
#   'player_link': 'https://www.whoscored.com/Players/5734/Show/Mauricio-Pinilla',
#   'player_name': 'Mauricio Pinilla',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 2365},
#  5780: {'player_link': 'https://www.whoscored.com/Players/5780/Show/Dani-Alves'},
#  6075: {'player_link': 'https://www.whoscored.com/Players/6075/Show/Andrea-Barzagli'},
#  6077: {'player_link': 'https://www.whoscored.com/Players/6077/Show/Antonio-Floro-Flores'},
#  6093: {'player_link': 'https://www.whoscored.com/Players/6093/Show/Goran-Pandev'},
#  6134: {'player_link': 'https://www.whoscored.com/Players/6134/Show/Cesare-Bovo'},
#  6145: {'player_birthday': '25-09-1981',
#   'player_height': 177,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/6145.jpg',
#   'player_link': 'https://www.whoscored.com/Players/6145/Show/Angelo-Palombo',
#   'player_name': 'Angelo Palombo',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 0},
#  6166: {'player_birthday': '27-08-1984',
#   'player_height': 179,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/6166.jpg',
#   'player_link': 'https://www.whoscored.com/Players/6166/Show/Sulley-Muntari',
#   'player_name': 'Sulley Muntari',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 59},
#  6410: {'player_birthday': '15-05-1981',
#   'player_height': 174,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/6410.jpg',
#   'player_link': 'https://www.whoscored.com/Players/6410/Show/Patrice-Evra',
#   'player_name': 'Patrice Evra',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 29},
#  7323: {'player_birthday': '29-06-1984',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/7323.jpg',
#   'player_link': 'https://www.whoscored.com/Players/7323/Show/Emil-Hallfredsson',
#   'player_name': 'Emil Hallfredsson',
#   'player_position': [],
#   'player_weight': 83,
#   'team_id': 86},
#  8786: {'player_birthday': '19-04-1987',
#   'player_height': 196,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/8786.jpg',
#   'player_link': 'https://www.whoscored.com/Players/8786/Show/Joe-Hart',
#   'player_name': 'Joe Hart',
#   'player_position': [],
#   'player_weight': 91,
#   'team_id': 29},
#  9578: {'player_birthday': '10-04-1984',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/9578.jpg',
#   'player_link': 'https://www.whoscored.com/Players/9578/Show/Gonzalo-Rodr%C3%ADguez',
#   'player_name': 'Gonzalo Rodríguez',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 906},
#  9730: {'player_birthday': '31-01-1983',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/9730.jpg',
#   'player_link': 'https://www.whoscored.com/Players/9730/Show/Fabio-Quagliarella',
#   'player_name': 'Fabio Quagliarella',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 271},
#  9894: {'player_birthday': '30-08-1983',
#   'player_height': 178,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/9894.jpg',
#   'player_link': 'https://www.whoscored.com/Players/9894/Show/Simone-Pepe',
#   'player_name': 'Simone Pepe',
#   'player_position': [],
#   'player_weight': 73,
#   'team_id': 0},
#  9926: {'player_link': 'https://www.whoscored.com/Players/9926/Show/Massimo-Gobbi'},
#  9943: {'player_link': 'https://www.whoscored.com/Players/9943/Show/Cristian-Raimondi'},
#  9956: {'player_birthday': '07-01-1977',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/9956.jpg',
#   'player_link': 'https://www.whoscored.com/Players/9956/Show/Marco-Storari',
#   'player_name': 'Marco Storari',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 80},
#  9972: {'player_link': 'https://www.whoscored.com/Players/9972/Show/Samir-Handanovic'},
#  9973: {'player_link': 'https://www.whoscored.com/Players/9973/Show/Felipe'},
#  9974: {'player_link': 'https://www.whoscored.com/Players/9974/Show/Riccardo-Montolivo'},
#  9989: {'player_link': 'https://www.whoscored.com/Players/9989/Show/Alberto-Aquilani'},
#  9991: {'player_link': 'https://www.whoscored.com/Players/9991/Show/Giorgio-Chiellini'},
#  10015: {'player_link': 'https://www.whoscored.com/Players/10015/Show/Djamel-Mesbah'},
#  10209: {'player_link': 'https://www.whoscored.com/Players/10209/Show/Thomas-Vermaelen'},
#  10333: {'player_birthday': '12-04-1981',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/10333.jpg',
#   'player_link': 'https://www.whoscored.com/Players/10333/Show/Nicolas-Burdisso',
#   'player_name': 'Nicolas Burdisso',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 72},
#  10334: {'player_birthday': '23-03-1984',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/10334.jpg',
#   'player_link': 'https://www.whoscored.com/Players/10334/Show/Francesco-Lodi',
#   'player_name': 'Francesco Lodi',
#   'player_position': [],
#   'player_weight': 70,
#   'team_id': 0},
#  10372: {'player_birthday': '25-10-1985',
#   'player_height': 191,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/10372.jpg',
#   'player_link': 'https://www.whoscored.com/Players/10372/Show/Daniele-Padelli',
#   'player_name': 'Daniele Padelli',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 75},
#  10468: {'player_birthday': '17-04-1984',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/10468.jpg',
#   'player_link': 'https://www.whoscored.com/Players/10468/Show/Raffaele-Palladino',
#   'player_name': 'Raffaele Palladino',
#   'player_position': [],
#   'player_weight': 74,
#   'team_id': 1501},
#  10705: {'player_birthday': '15-07-1984',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/10705.jpg',
#   'player_link': 'https://www.whoscored.com/Players/10705/Show/Edgar-Barreto',
#   'player_name': 'Edgar Barreto',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 271},
#  10760: {'player_birthday': '22-08-1985',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/10760.jpg',
#   'player_link': 'https://www.whoscored.com/Players/10760/Show/Marco-Zambelli',
#   'player_name': 'Marco Zambelli',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 2214},
#  10864: {'player_link': 'https://www.whoscored.com/Players/10864/Show/Roberto-Vitiello'},
#  10928: {'player_link': 'https://www.whoscored.com/Players/10928/Show/Gianni-Munari'},
#  10930: {'player_link': 'https://www.whoscored.com/Players/10930/Show/Giulio-Migliaccio'},
#  10974: {'player_link': 'https://www.whoscored.com/Players/10974/Show/Bostjan-Cesar'},
#  11118: {'player_link': 'https://www.whoscored.com/Players/11118/Show/Abdoulay-Konko'},
#  11624: {'player_birthday': '11-07-1985',
#   'player_height': 189,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/11624.jpg',
#   'player_link': 'https://www.whoscored.com/Players/11624/Show/Orestis-Karnezis',
#   'player_name': 'Orestis Karnezis',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 27},
#  11845: {'player_birthday': '28-01-1983',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/11845.jpg',
#   'player_link': 'https://www.whoscored.com/Players/11845/Show/Alessandro-Gazzi',
#   'player_name': 'Alessandro Gazzi',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 0},
#  12032: {'player_link': 'https://www.whoscored.com/Players/12032/Show/Valter-Birsa'},
#  12052: {'player_link': 'https://www.whoscored.com/Players/12052/Show/Stefano-Sorrentino'},
#  12348: {'player_birthday': '25-06-1983',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/12348.jpg',
#   'player_link': 'https://www.whoscored.com/Players/12348/Show/Daniele-Gastaldello',
#   'player_name': 'Daniele Gastaldello',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 144},
#  12575: {'player_birthday': '04-09-1985',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/12575.jpg',
#   'player_link': 'https://www.whoscored.com/Players/12575/Show/Ra%C3%BAl-Albiol',
#   'player_name': 'Raúl Albiol',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 276},
#  12732: {'player_birthday': '07-12-1984',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/12732.jpg',
#   'player_link': 'https://www.whoscored.com/Players/12732/Show/Luca-Rigoni',
#   'player_name': 'Luca Rigoni',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 278},
#  13154: {'player_link': 'https://www.whoscored.com/Players/13154/Show/Cyril-Th%C3%A9r%C3%A9au'},
#  13348: {'player_birthday': '23-05-1986',
#   'player_height': 191,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/13348.jpg',
#   'player_link': 'https://www.whoscored.com/Players/13348/Show/Simone-Missiroli',
#   'player_name': 'Simone Missiroli',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 2889},
#  13475: {'player_birthday': '27-07-1987',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/13475.jpg',
#   'player_link': 'https://www.whoscored.com/Players/13475/Show/Marek-Hamsik',
#   'player_name': 'Marek Hamsik',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 276},
#  13551: {'player_birthday': '26-06-1983',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/13551.jpg',
#   'player_link': 'https://www.whoscored.com/Players/13551/Show/Felipe-Melo',
#   'player_name': 'Felipe Melo',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 1234},
#  13554: {'player_birthday': '03-04-1984',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/13554.jpg',
#   'player_link': 'https://www.whoscored.com/Players/13554/Show/Maxi-L%C3%B3pez',
#   'player_name': 'Maxi López',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 86},
#  13764: {'player_link': 'https://www.whoscored.com/Players/13764/Show/Sami-Khedira'},
#  13802: {'player_birthday': '01-02-1987',
#   'player_height': 173,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/13802.jpg',
#   'player_link': 'https://www.whoscored.com/Players/13802/Show/Giuseppe-Rossi',
#   'player_name': 'Giuseppe Rossi',
#   'player_position': [],
#   'player_weight': 72,
#   'team_id': 278},
#  14039: {'player_link': 'https://www.whoscored.com/Players/14039/Show/Manuel-Pasqual'},
#  14040: {'player_link': 'https://www.whoscored.com/Players/14040/Show/Luca-Antonelli'},
#  14063: {'player_birthday': '30-09-1986',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/14063.jpg',
#   'player_link': 'https://www.whoscored.com/Players/14063/Show/Cristian-Zapata',
#   'player_name': 'Cristian Zapata',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 80},
#  14066: {'player_birthday': '25-04-1985',
#   'player_height': 188,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/14066.jpg',
#   'player_link': 'https://www.whoscored.com/Players/14066/Show/Andrea-Coda',
#   'player_name': 'Andrea Coda',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 277},
#  14070: {'player_link': 'https://www.whoscored.com/Players/14070/Show/Davide-Biondini'},
#  14105: {'player_link': 'https://www.whoscored.com/Players/14105/Show/Luiz-Adriano'},
#  14126: {'player_link': 'https://www.whoscored.com/Players/14126/Show/Luca-Cigarini'},
#  14127: {'player_link': 'https://www.whoscored.com/Players/14127/Show/Daniele-Dessena'},
#  14131: {'player_link': 'https://www.whoscored.com/Players/14131/Show/Giovanni-Marchese'},
#  14137: {'player_link': 'https://www.whoscored.com/Players/14137/Show/Guglielmo-Stendardo'},
#  14152: {'player_link': 'https://www.whoscored.com/Players/14152/Show/Sergio-Floccari'},
#  14157: {'player_link': 'https://www.whoscored.com/Players/14157/Show/Andrea-Masiello'},
#  14254: {'player_link': 'https://www.whoscored.com/Players/14254/Show/Aleandro-Rosi'},
#  14482: {'player_birthday': '09-09-1982',
#   'player_height': 172,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/14482.jpg',
#   'player_link': 'https://www.whoscored.com/Players/14482/Show/Daniele-Croce',
#   'player_name': 'Daniele Croce',
#   'player_position': [],
#   'player_weight': 68,
#   'team_id': 2731},
#  14524: {'player_birthday': '18-03-1987',
#   'player_height': 176,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/14524.jpg',
#   'player_link': 'https://www.whoscored.com/Players/14524/Show/Mauro-Z%C3%A1rate',
#   'player_name': 'Mauro Zárate',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 895},
#  14636: {'player_link': 'https://www.whoscored.com/Players/14636/Show/Nicol%C3%A1s-Spolli'},
#  14751: {'player_birthday': '18-08-1984',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/14751.jpg',
#   'player_link': 'https://www.whoscored.com/Players/14751/Show/Dusan-Basta',
#   'player_name': 'Dusan Basta',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 77},
#  14831: {'player_link': 'https://www.whoscored.com/Players/14831/Show/Blerim-Dzemaili'},
#  14871: {'player_birthday': '05-02-1982',
#   'player_height': 176,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/14871.jpg',
#   'player_link': 'https://www.whoscored.com/Players/14871/Show/Rodrigo-Palacio',
#   'player_name': 'Rodrigo Palacio',
#   'player_position': [],
#   'player_weight': 70,
#   'team_id': 71},
#  15119: {'player_birthday': '08-05-1979',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/15119.jpg',
#   'player_link': 'https://www.whoscored.com/Players/15119/Show/Gennaro-Sardo',
#   'player_name': 'Gennaro Sardo',
#   'player_position': [],
#   'player_weight': 87,
#   'team_id': 0},
#  15121: {'player_link': 'https://www.whoscored.com/Players/15121/Show/Santiago-Gentiletti'},
#  15302: {'player_link': 'https://www.whoscored.com/Players/15302/Show/Stephan-Lichtsteiner'},
#  15407: {'player_birthday': '30-07-1983',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/15407.jpg',
#   'player_link': 'https://www.whoscored.com/Players/15407/Show/Cristian-Molinaro',
#   'player_name': 'Cristian Molinaro',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 72},
#  16367: {'player_link': 'https://www.whoscored.com/Players/16367/Show/Domenico-Maietta'},
#  17108: {'player_link': 'https://www.whoscored.com/Players/17108/Show/Hernanes'},
#  17949: {'player_birthday': '08-07-1983',
#   'player_height': 193,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/17949.jpg',
#   'player_link': 'https://www.whoscored.com/Players/17949/Show/Antonio-Mirante',
#   'player_name': 'Antonio Mirante',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 71},
#  18139: {'player_link': 'https://www.whoscored.com/Players/18139/Show/Leandro-Cast%C3%A1n'},
#  18590: {'player_birthday': '27-11-1981',
#   'player_height': 189,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/18590.jpg',
#   'player_link': 'https://www.whoscored.com/Players/18590/Show/Bruno-Alves',
#   'player_name': 'Bruno Alves',
#   'player_position': [],
#   'player_weight': 83,
#   'team_id': 306},
#  18723: {'player_birthday': '20-01-1984',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/18723.jpg',
#   'player_link': 'https://www.whoscored.com/Players/18723/Show/Federico-Peluso',
#   'player_name': 'Federico Peluso',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 2889},
#  18727: {'player_birthday': '10-05-1984',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/18727.jpg',
#   'player_link': 'https://www.whoscored.com/Players/18727/Show/Danilo',
#   'player_name': 'Danilo',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 86},
#  18916: {'player_birthday': '19-06-1985',
#   'player_height': 179,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/18916.jpg',
#   'player_link': 'https://www.whoscored.com/Players/18916/Show/Jos%C3%A9-Sosa',
#   'player_name': 'José Sosa',
#   'player_position': [],
#   'player_weight': 72,
#   'team_id': 226},
#  19087: {'player_link': 'https://www.whoscored.com/Players/19087/Show/Jonathan-de-Guzm%C3%A1n'},
#  19112: {'player_link': 'https://www.whoscored.com/Players/19112/Show/Borja-Valero'},
#  19530: {'player_birthday': '07-05-1987',
#   'player_height': 177,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/19530.jpg',
#   'player_link': 'https://www.whoscored.com/Players/19530/Show/Serge-Gakp%C3%A9',
#   'player_name': 'Serge Gakpé',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 151},
#  19580: {'player_birthday': '23-05-1988',
#   'player_height': 186,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/19580.jpg',
#   'player_link': 'https://www.whoscored.com/Players/19580/Show/Lorenzo-De-Silvestri',
#   'player_name': 'Lorenzo De Silvestri',
#   'player_position': [],
#   'player_weight': 84,
#   'team_id': 72},
#  19676: {'player_birthday': '06-05-1984',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/19676.jpg',
#   'player_link': 'https://www.whoscored.com/Players/19676/Show/Juan-Pablo-Carrizo',
#   'player_name': 'Juan Pablo Carrizo',
#   'player_position': [],
#   'player_weight': 87,
#   'team_id': 1452},
#  19679: {'player_birthday': '25-09-1984',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/19679.jpg',
#   'player_link': 'https://www.whoscored.com/Players/19679/Show/Mat%C3%ADas-Silvestre',
#   'player_name': 'Matías Silvestre',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 271},
#  19729: {'player_birthday': '10-12-1987',
#   'player_height': 186,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/19729.jpg',
#   'player_link': 'https://www.whoscored.com/Players/19729/Show/Gonzalo-Higua%C3%ADn',
#   'player_name': 'Gonzalo Higuaín',
#   'player_position': [],
#   'player_weight': 89,
#   'team_id': 87},
#  20211: {'player_link': 'https://www.whoscored.com/Players/20211/Show/Claudio-Marchisio'},
#  20540: {'player_birthday': '06-03-1984',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/20540.jpg',
#   'player_link': 'https://www.whoscored.com/Players/20540/Show/Nicolas-Frey',
#   'player_name': 'Nicolas Frey',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 85},
#  20664: {'player_birthday': '01-05-1987',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/20664.jpg',
#   'player_link': 'https://www.whoscored.com/Players/20664/Show/Leonardo-Bonucci',
#   'player_name': 'Leonardo Bonucci',
#   'player_position': [],
#   'player_weight': 85,
#   'team_id': 80},
#  20765: {'player_birthday': '01-02-1986',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/20765.jpg',
#   'player_link': 'https://www.whoscored.com/Players/20765/Show/Andrea-Costa',
#   'player_name': 'Andrea Costa',
#   'player_position': [],
#   'player_weight': 73,
#   'team_id': 1503},
#  21234: {'player_link': 'https://www.whoscored.com/Players/21234/Show/Stefan-Radu'},
#  22182: {'player_link': 'https://www.whoscored.com/Players/22182/Show/Miguel-Veloso'},
#  22205: {'player_link': 'https://www.whoscored.com/Players/22205/Show/Lucas-Biglia'},
#  22321: {'player_link': 'https://www.whoscored.com/Players/22321/Show/Mariano-Izco'},
#  22377: {'player_link': 'https://www.whoscored.com/Players/22377/Show/%C3%89der'},
#  22406: {'player_link': 'https://www.whoscored.com/Players/22406/Show/Perparim-Hetemaj'},
#  22486: {'player_birthday': '22-07-1985',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/22486.jpg',
#   'player_link': 'https://www.whoscored.com/Players/22486/Show/Boukary-Dram%C3%A9',
#   'player_name': 'Boukary Dramé',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 1502},
#  22504: {'player_link': 'https://www.whoscored.com/Players/22504/Show/Miranda'},
#  22546: {'player_birthday': '15-02-1988',
#   'player_height': 165,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/22546.jpg',
#   'player_link': 'https://www.whoscored.com/Players/22546/Show/Alejandro-Gomez',
#   'player_name': 'Alejandro Gomez',
#   'player_position': [],
#   'player_weight': 68,
#   'team_id': 300},
#  22605: {'player_birthday': '15-02-1986',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/22605.jpg',
#   'player_link': 'https://www.whoscored.com/Players/22605/Show/Gabriel-Paletta',
#   'player_name': 'Gabriel Paletta',
#   'player_position': [],
#   'player_weight': 88,
#   'team_id': 7125},
#  22784: {'player_birthday': '14-07-1980',
#   'player_height': 178,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/22784.jpg',
#   'player_link': 'https://www.whoscored.com/Players/22784/Show/Giuseppe-Vives',
#   'player_name': 'Giuseppe Vives',
#   'player_position': [],
#   'player_weight': 70,
#   'team_id': 8179},
#  23001: {'player_birthday': '20-09-1986',
#   'player_height': 181,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/23001.jpg',
#   'player_link': 'https://www.whoscored.com/Players/23001/Show/Cristian-Ansaldi',
#   'player_name': 'Cristian Ansaldi',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 72},
#  23043: {'player_link': 'https://www.whoscored.com/Players/23043/Show/Simone-Padoin'},
#  23083: {'player_birthday': '26-07-1987',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/23083.jpg',
#   'player_link': 'https://www.whoscored.com/Players/23083/Show/Panagiotis-Kone',
#   'player_name': 'Panagiotis Kone',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 842},
#  23100: {'player_birthday': '06-05-1987',
#   'player_height': 169,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/23100.jpg',
#   'player_link': 'https://www.whoscored.com/Players/23100/Show/Dries-Mertens',
#   'player_name': 'Dries Mertens',
#   'player_position': [],
#   'player_weight': 61,
#   'team_id': 276},
#  23206: {'player_link': 'https://www.whoscored.com/Players/23206/Show/Ignazio-Abate'},
#  23314: {'player_link': 'https://www.whoscored.com/Players/23314/Show/Federico-Melchiorri'},
#  23413: {'player_link': 'https://www.whoscored.com/Players/23413/Show/Mat%C3%ADas-Fern%C3%A1ndez'},
#  23545: {'player_link': 'https://www.whoscored.com/Players/23545/Show/Vincenzo-Fiorillo'},
#  23567: {'player_birthday': '10-06-1985',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/23567.jpg',
#   'player_link': 'https://www.whoscored.com/Players/23567/Show/Vasilis-Torosidis',
#   'player_name': 'Vasilis Torosidis',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 71},
#  24088: {'player_birthday': '21-05-1986',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/24088.jpg',
#   'player_link': 'https://www.whoscored.com/Players/24088/Show/Mario-Mandzukic',
#   'player_name': 'Mario Mandzukic',
#   'player_position': [],
#   'player_weight': 85,
#   'team_id': 87},
#  24151: {'player_birthday': '17-01-1981',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/24151.jpg',
#   'player_link': 'https://www.whoscored.com/Players/24151/Show/Christian-Puggioni',
#   'player_name': 'Christian Puggioni',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 1503},
#  24419: {'player_link': 'https://www.whoscored.com/Players/24419/Show/Pablo-Armero'},
#  24605: {'player_birthday': '13-06-1986',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/24605.jpg',
#   'player_link': 'https://www.whoscored.com/Players/24605/Show/Keisuke-Honda',
#   'player_name': 'Keisuke Honda',
#   'player_position': [],
#   'player_weight': 74,
#   'team_id': 1449},
#  24642: {'player_birthday': '24-05-1989',
#   'player_height': 178,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/24642.jpg',
#   'player_link': 'https://www.whoscored.com/Players/24642/Show/Adel-Taarabt',
#   'player_name': 'Adel Taarabt',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 278},
#  24845: {'player_birthday': '17-03-1986',
#   'player_height': 193,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/24845.jpg',
#   'player_link': 'https://www.whoscored.com/Players/24845/Show/Edin-Dzeko',
#   'player_name': 'Edin Dzeko',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 84},
#  25079: {'player_link': 'https://www.whoscored.com/Players/25079/Show/Alessandro-Matri'},
#  25091: {'player_birthday': '05-01-1988',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/25091.jpg',
#   'player_link': 'https://www.whoscored.com/Players/25091/Show/Nikola-Kalinic',
#   'player_name': 'Nikola Kalinic',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 80},
#  25484: {'player_link': 'https://www.whoscored.com/Players/25484/Show/Mirko-Eramo'},
#  25820: {'player_birthday': '04-09-1985',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/25820.jpg',
#   'player_link': 'https://www.whoscored.com/Players/25820/Show/Riccardo-Meggiorini',
#   'player_name': 'Riccardo Meggiorini',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 267},
#  26168: {'player_birthday': '18-01-1986',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/26168.jpg',
#   'player_link': 'https://www.whoscored.com/Players/26168/Show/Senad-Lulic',
#   'player_name': 'Senad Lulic',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 77},
#  26587: {'player_link': 'https://www.whoscored.com/Players/26587/Show/Marco-Parolo'},
#  26720: {'player_birthday': '06-02-1986',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/26720.jpg',
#   'player_link': 'https://www.whoscored.com/Players/26720/Show/Carlos-S%C3%A1nchez',
#   'player_name': 'Carlos Sánchez',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 70},
#  26875: {'player_birthday': '26-02-1988',
#   'player_height': 176,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/26875.jpg',
#   'player_link': 'https://www.whoscored.com/Players/26875/Show/Sven-Kums',
#   'player_name': 'Sven Kums',
#   'player_position': [],
#   'player_weight': 63,
#   'team_id': 240},
#  27039: {'player_birthday': '21-08-1989',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/27039.jpg',
#   'player_link': 'https://www.whoscored.com/Players/27039/Show/Giuseppe-Bellusci',
#   'player_name': 'Giuseppe Bellusci',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 1285},
#  27227: {'player_birthday': '12-11-1984',
#   'player_height': 181,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/27227.jpg',
#   'player_link': 'https://www.whoscored.com/Players/27227/Show/Francesco-Magnanelli',
#   'player_name': 'Francesco Magnanelli',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 2889},
#  27421: {'player_link': 'https://www.whoscored.com/Players/27421/Show/Andrea-Ranocchia'},
#  27738: {'player_birthday': '16-06-1988',
#   'player_height': 181,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/27738.jpg',
#   'player_link': 'https://www.whoscored.com/Players/27738/Show/Davide-Di-Gennaro',
#   'player_name': 'Davide Di Gennaro',
#   'player_position': [],
#   'player_weight': 72,
#   'team_id': 77},
#  27991: {'player_birthday': '14-04-1987',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/27991.jpg',
#   'player_link': 'https://www.whoscored.com/Players/27991/Show/Emanuele-Terranova',
#   'player_name': 'Emanuele Terranova',
#   'player_position': [],
#   'player_weight': 86,
#   'team_id': 2732},
#  27999: {'player_birthday': '03-12-1987',
#   'player_height': 169,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/27999.jpg',
#   'player_link': 'https://www.whoscored.com/Players/27999/Show/Marco-Sau',
#   'player_name': 'Marco Sau',
#   'player_position': [],
#   'player_weight': 65,
#   'team_id': 78},
#  28963: {'player_birthday': '27-09-1987',
#   'player_height': 175,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/28963.jpg',
#   'player_link': 'https://www.whoscored.com/Players/28963/Show/Anthony-Mounier',
#   'player_name': 'Anthony Mounier',
#   'player_position': [],
#   'player_weight': 65,
#   'team_id': 685},
#  29072: {'player_birthday': '02-11-1989',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/29072.jpg',
#   'player_link': 'https://www.whoscored.com/Players/29072/Show/Stevan-Jovetic',
#   'player_name': 'Stevan Jovetic',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 248},
#  29244: {'player_birthday': '25-05-1988',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/29244.jpg',
#   'player_link': 'https://www.whoscored.com/Players/29244/Show/Mato-Jajalo',
#   'player_name': 'Mato Jajalo',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 1285},
#  29390: {'player_link': 'https://www.whoscored.com/Players/29390/Show/Gary-Medel'},
#  29655: {'player_link': 'https://www.whoscored.com/Players/29655/Show/Leonel-Vangioni'},
#  29888: {'player_birthday': '17-04-1987',
#   'player_height': 189,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/29888.jpg',
#   'player_link': 'https://www.whoscored.com/Players/29888/Show/Medhi-Benatia',
#   'player_name': 'Medhi Benatia',
#   'player_position': [],
#   'player_weight': 94,
#   'team_id': 87},
#  29908: {'player_birthday': '17-03-1987',
#   'player_height': 195,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/29908.jpg',
#   'player_link': 'https://www.whoscored.com/Players/29908/Show/Federico-Fazio',
#   'player_name': 'Federico Fazio',
#   'player_position': [],
#   'player_weight': 85,
#   'team_id': 84},
#  30226: {'player_birthday': '02-04-1990',
#   'player_height': 178,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/30226.jpg',
#   'player_link': 'https://www.whoscored.com/Players/30226/Show/Miralem-Pjanic',
#   'player_name': 'Miralem Pjanic',
#   'player_position': [],
#   'player_weight': 72,
#   'team_id': 87},
#  30310: {'player_link': 'https://www.whoscored.com/Players/30310/Show/Alessandro-Diamanti'},
#  30589: {'player_link': 'https://www.whoscored.com/Players/30589/Show/Marcello-Gazzola'},
#  31006: {'player_birthday': '17-05-1989',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/31006.jpg',
#   'player_link': 'https://www.whoscored.com/Players/31006/Show/Michel-Morganella',
#   'player_name': 'Michel Morganella',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 1285},
#  31302: {'player_birthday': '09-05-1985',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/31302.jpg',
#   'player_link': 'https://www.whoscored.com/Players/31302/Show/Luca-Rossettini',
#   'player_name': 'Luca Rossettini',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 278},
#  31355: {'player_link': 'https://www.whoscored.com/Players/31355/Show/Andrea-Poli'},
#  31388: {'player_link': 'https://www.whoscored.com/Players/31388/Show/Diego-Perotti'},
#  31654: {'player_link': 'https://www.whoscored.com/Players/31654/Show/Pietro-De-Giorgio'},
#  31991: {'player_birthday': '13-01-1988',
#   'player_height': 177,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/31991.jpg',
#   'player_link': 'https://www.whoscored.com/Players/31991/Show/Tom%C3%A1s-Rinc%C3%B3n',
#   'player_name': 'Tomás Rincón',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 72},
#  32380: {'player_link': 'https://www.whoscored.com/Players/32380/Show/Levan-Mchedlidze'},
#  32514: {'player_link': 'https://www.whoscored.com/Players/32514/Show/Juraj-Kucka'},
#  32676: {'player_link': 'https://www.whoscored.com/Players/32676/Show/Ciprian-Tatarusanu'},
#  32939: {'player_birthday': '12-11-1990',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/32939.jpg',
#   'player_link': 'https://www.whoscored.com/Players/32939/Show/Nicola-Rigoni',
#   'player_name': 'Nicola Rigoni',
#   'player_position': [],
#   'player_weight': 84,
#   'team_id': 267},
#  33071: {'player_birthday': '03-02-1989',
#   'player_height': 191,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/33071.jpg',
#   'player_link': 'https://www.whoscored.com/Players/33071/Show/Slobodan-Rajkovic',
#   'player_name': 'Slobodan Rajkovic',
#   'player_position': [],
#   'player_weight': 88,
#   'team_id': 1285},
#  33399: {'player_birthday': '28-09-1987',
#   'player_height': 186,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/33399.jpg',
#   'player_link': 'https://www.whoscored.com/Players/33399/Show/Filip-Djordjevic',
#   'player_name': 'Filip Djordjevic',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 0},
#  33724: {'player_link': 'https://www.whoscored.com/Players/33724/Show/%C3%89ver-Banega'},
#  33834: {'player_birthday': '04-01-1990',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/33834.jpg',
#   'player_link': 'https://www.whoscored.com/Players/33834/Show/Alberto-Paloschi',
#   'player_name': 'Alberto Paloschi',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 1502},
#  33870: {'player_birthday': '08-10-1986',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/33870.jpg',
#   'player_link': 'https://www.whoscored.com/Players/33870/Show/Fabrizio-Cacciatore',
#   'player_name': 'Fabrizio Cacciatore',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 267},
#  33875: {'player_birthday': '25-10-1991',
#   'player_height': 181,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/33875.jpg',
#   'player_link': 'https://www.whoscored.com/Players/33875/Show/Davide-Faraoni',
#   'player_name': 'Davide Faraoni',
#   'player_position': [],
#   'player_weight': 73,
#   'team_id': 779},
#  33878: {'player_birthday': '12-06-1988',
#   'player_height': 176,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/33878.jpg',
#   'player_link': 'https://www.whoscored.com/Players/33878/Show/Mauricio-Isla',
#   'player_name': 'Mauricio Isla',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 223},
#  34112: {'player_birthday': '28-02-1987',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/34112.jpg',
#   'player_link': 'https://www.whoscored.com/Players/34112/Show/Antonio-Candreva',
#   'player_name': 'Antonio Candreva',
#   'player_position': [],
#   'player_weight': 70,
#   'team_id': 75},
#  35177: {'player_link': 'https://www.whoscored.com/Players/35177/Show/Panagiotis-Tachtsidis'},
#  35549: {'player_link': 'https://www.whoscored.com/Players/35549/Show/Kwadwo-Asamoah'},
#  35640: {'player_link': 'https://www.whoscored.com/Players/35640/Show/Ivan-Radovanovic'},
#  35954: {'player_birthday': '13-02-1990',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/35954.jpg',
#   'player_link': 'https://www.whoscored.com/Players/35954/Show/Kevin-Strootman',
#   'player_name': 'Kevin Strootman',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 84},
#  37188: {'player_birthday': '12-09-1986',
#   'player_height': 170,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/37188.jpg',
#   'player_link': 'https://www.whoscored.com/Players/37188/Show/Yuto-Nagatomo',
#   'player_name': 'Yuto Nagatomo',
#   'player_position': [],
#   'player_weight': 68,
#   'team_id': 294},
#  37351: {'player_birthday': '10-05-1989',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/37351.jpg',
#   'player_link': 'https://www.whoscored.com/Players/37351/Show/Hrvoje-Milic',
#   'player_name': 'Hrvoje Milic',
#   'player_position': [],
#   'player_weight': 74,
#   'team_id': 843},
#  38442: {'player_birthday': '15-09-1990',
#   'player_height': 181,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/38442.jpg',
#   'player_link': 'https://www.whoscored.com/Players/38442/Show/Darko-Lazovic',
#   'player_name': 'Darko Lazovic',
#   'player_position': [],
#   'player_weight': 66,
#   'team_id': 278},
#  40384: {'player_birthday': '22-08-1989',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/40384.jpg',
#   'player_link': 'https://www.whoscored.com/Players/40384/Show/Giacomo-Bonaventura',
#   'player_name': 'Giacomo Bonaventura',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 80},
#  40966: {'player_birthday': '17-07-1987',
#   'player_height': 186,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/40966.jpg',
#   'player_link': 'https://www.whoscored.com/Players/40966/Show/Ivan-Strinic',
#   'player_name': 'Ivan Strinic',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 271},
#  41073: {'player_birthday': '01-04-1991',
#   'player_height': 186,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/41073.jpg',
#   'player_link': 'https://www.whoscored.com/Players/41073/Show/Duv%C3%A1n-Zapata',
#   'player_name': 'Duván Zapata',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 271},
#  41237: {'player_birthday': '28-04-1988',
#   'player_height': 177,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/41237.jpg',
#   'player_link': 'https://www.whoscored.com/Players/41237/Show/Jonathan-Biabiany',
#   'player_name': 'Jonathan Biabiany',
#   'player_position': [],
#   'player_weight': 73,
#   'team_id': 354},
#  41367: {'player_birthday': '29-09-1988',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/41367.jpg',
#   'player_link': 'https://www.whoscored.com/Players/41367/Show/Andrea-Rispoli',
#   'player_name': 'Andrea Rispoli',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 1285},
#  41489: {'player_birthday': '12-04-1988',
#   'player_height': 188,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/41489.jpg',
#   'player_link': 'https://www.whoscored.com/Players/41489/Show/Ricardo-%C3%81lvarez',
#   'player_name': 'Ricardo Álvarez',
#   'player_position': [],
#   'player_weight': 84,
#   'team_id': 271},
#  42124: {'player_birthday': '13-02-1986',
#   'player_height': 186,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/42124.jpg',
#   'player_link': 'https://www.whoscored.com/Players/42124/Show/Sinisa-Andjelkovic',
#   'player_name': 'Sinisa Andjelkovic',
#   'player_position': [],
#   'player_weight': 82,
#   'team_id': 85},
#  42435: {'player_birthday': '25-02-1989',
#   'player_height': 186,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/42435.jpg',
#   'player_link': 'https://www.whoscored.com/Players/42435/Show/Milan-Badelj',
#   'player_name': 'Milan Badelj',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 73},
#  42540: {'player_birthday': '15-12-1988',
#   'player_height': 194,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/42540.jpg',
#   'player_link': 'https://www.whoscored.com/Players/42540/Show/Toni-Sunjic',
#   'player_name': 'Toni Sunjic',
#   'player_position': [],
#   'player_weight': 93,
#   'team_id': 846},
#  42860: {'player_link': 'https://www.whoscored.com/Players/42860/Show/Nenad-Tomovic'},
#  42878: {'player_link': 'https://www.whoscored.com/Players/42878/Show/Emiliano-Viviano'},
#  42879: {'player_link': 'https://www.whoscored.com/Players/42879/Show/Andrea-Consigli'},
#  42950: {'player_link': 'https://www.whoscored.com/Players/42950/Show/Carlao'},
#  43194: {'player_birthday': '29-01-1988',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/43194.jpg',
#   'player_link': 'https://www.whoscored.com/Players/43194/Show/Josip-Ilicic',
#   'player_name': 'Josip Ilicic',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 300},
#  44087: {'player_birthday': '24-08-1975',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/44087.jpg',
#   'player_link': 'https://www.whoscored.com/Players/44087/Show/Roberto-Colombo',
#   'player_name': 'Roberto Colombo',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 0},
#  44089: {'player_birthday': '07-02-1983',
#   'player_height': 188,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/44089.jpg',
#   'player_link': 'https://www.whoscored.com/Players/44089/Show/Federico-Marchetti',
#   'player_name': 'Federico Marchetti',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 0},
#  44304: {'player_birthday': '10-03-1989',
#   'player_height': 191,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/44304.jpg',
#   'player_link': 'https://www.whoscored.com/Players/44304/Show/Etrit-Berisha',
#   'player_name': 'Etrit Berisha',
#   'player_position': [],
#   'player_weight': 92,
#   'team_id': 300},
#  44473: {'player_birthday': '21-04-1986',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/44473.jpg',
#   'player_link': 'https://www.whoscored.com/Players/44473/Show/Thiago-Cionek',
#   'player_name': 'Thiago Cionek',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 1502},
#  44642: {'player_birthday': '02-01-1991',
#   'player_height': 187,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/44642.jpg',
#   'player_link': 'https://www.whoscored.com/Players/44642/Show/Davide-Santon',
#   'player_name': 'Davide Santon',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 75},
#  44643: {'player_birthday': '07-01-1987',
#   'player_height': 188,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/44643.jpg',
#   'player_link': 'https://www.whoscored.com/Players/44643/Show/Davide-Astori',
#   'player_name': 'Davide Astori',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 73},
#  44868: {'player_link': 'https://www.whoscored.com/Players/44868/Show/Juan-Cuadrado'},
#  52380: {'player_link': 'https://www.whoscored.com/Players/52380/Show/Radja-Nainggolan'},
#  53975: {'player_birthday': '05-03-1987',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/53975.jpg',
#   'player_link': 'https://www.whoscored.com/Players/53975/Show/Sebastien-De-Maio',
#   'player_name': 'Sebastien De Maio',
#   'player_position': [],
#   'player_weight': 90,
#   'team_id': 71},
#  54968: {'player_link': 'https://www.whoscored.com/Players/54968/Show/Francesco-Acerbi'},
#  56224: {'player_birthday': '25-03-1981',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/56224.jpg',
#   'player_link': 'https://www.whoscored.com/Players/56224/Show/Gianluca-Pegolo',
#   'player_name': 'Gianluca Pegolo',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 2889},
#  58761: {'player_birthday': '19-12-1994',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/58761.jpg',
#   'player_link': 'https://www.whoscored.com/Players/58761/Show/M-Baye-Niang',
#   'player_name': "M'Baye Niang",
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 72},
#  59214: {'player_link': 'https://www.whoscored.com/Players/59214/Show/Rafael'},
#  61083: {'player_link': 'https://www.whoscored.com/Players/61083/Show/Ervin-Zukanovic'},
#  62575: {'player_birthday': '08-02-1988',
#   'player_height': 191,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/62575.jpg',
#   'player_link': 'https://www.whoscored.com/Players/62575/Show/Giancarlo-Gonz%C3%A1lez',
#   'player_name': 'Giancarlo González',
#   'player_position': [],
#   'player_weight': 84,
#   'team_id': 71},
#  64075: {'player_birthday': '10-10-1990',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/64075.jpg',
#   'player_link': 'https://www.whoscored.com/Players/64075/Show/Rafael-Tol%C3%B3i',
#   'player_name': 'Rafael Tolói',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 300},
# ...
#   'player_link': 'https://www.whoscored.com/Players/262515/Show/Gianluigi-Donnarumma',
#   'player_name': 'Gianluigi Donnarumma',
#   'player_position': [],
#   'player_weight': 90,
#   'team_id': 80},
#  273539: {'player_birthday': '08-01-1998',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/273539.jpg',
#   'player_link': 'https://www.whoscored.com/Players/273539/Show/Manuel-Locatelli',
#   'player_name': 'Manuel Locatelli',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 80},
#  275831: {'player_birthday': '30-01-1998',
#   'player_height': 176,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/275831.jpg',
#   'player_link': 'https://www.whoscored.com/Players/275831/Show/Grigoris-Kastanos',
#   'player_name': 'Grigoris Kastanos',
#   'player_position': [],
#   'player_weight': 71,
#   'team_id': 2164},
#  277269: {'player_link': 'https://www.whoscored.com/Players/277269/Show/Franck-Kessi%C3%A9'},
#  279541: {'player_link': 'https://www.whoscored.com/Players/279541/Show/Matheus-Pereira'},
#  281272: {'player_birthday': '22-10-1998',
#   'player_height': 178,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/281272.jpg',
#   'player_link': 'https://www.whoscored.com/Players/281272/Show/Ianis-Hagi',
#   'player_name': 'Ianis Hagi',
#   'player_position': [],
#   'player_weight': 68,
#   'team_id': 9425},
#  285375: {'player_link': 'https://www.whoscored.com/Players/285375/Show/Andrej-Kotnik'},
#  287088: {'player_birthday': '11-10-1994',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/287088.jpg',
#   'player_link': 'https://www.whoscored.com/Players/287088/Show/Andrea-Beghetto',
#   'player_name': 'Andrea Beghetto',
#   'player_position': [],
#   'player_weight': 74,
#   'team_id': 2732},
#  288766: {'player_link': 'https://www.whoscored.com/Players/288766/Show/Andr%C3%A9s-Tello'},
#  288767: {'player_link': 'https://www.whoscored.com/Players/288767/Show/Sergej-Milinkovic-Savic'},
#  289303: {'player_birthday': '06-06-1992',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/289303.jpg',
#   'player_link': 'https://www.whoscored.com/Players/289303/Show/Marco-Festa',
#   'player_name': 'Marco Festa',
#   'player_position': [],
#   'player_weight': 85,
#   'team_id': 779},
#  294044: {'player_birthday': '17-07-1997',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/294044.jpg',
#   'player_link': 'https://www.whoscored.com/Players/294044/Show/Amadou-Diawara',
#   'player_name': 'Amadou Diawara',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 276},
#  294136: {'player_birthday': '24-02-1997',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/294136.jpg',
#   'player_link': 'https://www.whoscored.com/Players/294136/Show/Rey-Manaj',
#   'player_name': 'Rey Manaj',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 925},
#  294137: {'player_birthday': '02-03-1994',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/294137.jpg',
#   'player_link': 'https://www.whoscored.com/Players/294137/Show/Andrea-Conti',
#   'player_name': 'Andrea Conti',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 80},
#  294148: {'player_birthday': '07-02-1992',
#   'player_height': 168,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/294148.jpg',
#   'player_link': 'https://www.whoscored.com/Players/294148/Show/Ahmad-Benali',
#   'player_name': 'Ahmad Benali',
#   'player_position': [],
#   'player_weight': 66,
#   'team_id': 779},
#  294149: {'player_birthday': '09-02-1996',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/294149.jpg',
#   'player_link': 'https://www.whoscored.com/Players/294149/Show/Olivier-Ntcham',
#   'player_name': 'Olivier Ntcham',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 103},
#  294163: {'player_birthday': '07-10-1993',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/294163.jpg',
#   'player_link': 'https://www.whoscored.com/Players/294163/Show/Rade-Krunic',
#   'player_name': 'Rade Krunic',
#   'player_position': [],
#   'player_weight': 74,
#   'team_id': 272},
#  294164: {'player_birthday': '22-01-1998',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/294164.jpg',
#   'player_link': 'https://www.whoscored.com/Players/294164/Show/Pedro-Pereira',
#   'player_name': 'Pedro Pereira',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 278},
#  295248: {'player_birthday': '31-07-1991',
#   'player_height': 181,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/295248.jpg',
#   'player_link': 'https://www.whoscored.com/Players/295248/Show/Haitam-Aleesami',
#   'player_name': 'Haitam Aleesami',
#   'player_position': [],
#   'player_weight': 73,
#   'team_id': 1285},
#  295362: {'player_birthday': '17-06-1995',
#   'player_height': 178,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/295362.jpg',
#   'player_link': 'https://www.whoscored.com/Players/295362/Show/%C3%81d%C3%A1m-Nagy',
#   'player_name': 'Ádám Nagy',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 71},
#  297395: {'player_birthday': '13-08-1996',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/297395.jpg',
#   'player_link': 'https://www.whoscored.com/Players/297395/Show/Sasa-Lukic',
#   'player_name': 'Sasa Lukic',
#   'player_position': [],
#   'player_weight': 74,
#   'team_id': 832},
#  297546: {'player_link': 'https://www.whoscored.com/Players/297546/Show/Sadiq-Umar'},
#  298053: {'player_birthday': '12-03-1990',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/298053.jpg',
#   'player_link': 'https://www.whoscored.com/Players/298053/Show/Ilija-Nestorovski',
#   'player_name': 'Ilija Nestorovski',
#   'player_position': [],
#   'player_weight': 74,
#   'team_id': 1285},
#  298515: {'player_birthday': '29-11-1997',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/298515.jpg',
#   'player_link': 'https://www.whoscored.com/Players/298515/Show/Giuseppe-Pezzella',
#   'player_name': 'Giuseppe Pezzella',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 86},
#  300438: {'player_birthday': '31-05-1997',
#   'player_height': 185,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/300438.jpg',
#   'player_link': 'https://www.whoscored.com/Players/300438/Show/Adalberto-Pe%C3%B1aranda',
#   'player_name': 'Adalberto Peñaranda',
#   'player_position': [],
#   'player_weight': 83,
#   'team_id': 69},
#  300737: {'player_link': 'https://www.whoscored.com/Players/300737/Show/Federico-Serra'},
#  302485: {'player_birthday': '21-02-1996',
#   'player_height': 197,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/302485.jpg',
#   'player_link': 'https://www.whoscored.com/Players/302485/Show/Norbert-Balogh',
#   'player_name': 'Norbert Balogh',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 1285},
#  302691: {'player_birthday': '15-04-1992',
#   'player_height': 181,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/302691.jpg',
#   'player_link': 'https://www.whoscored.com/Players/302691/Show/Remo-Freuler',
#   'player_name': 'Remo Freuler',
#   'player_position': [],
#   'player_weight': 77,
#   'team_id': 300},
#  302893: {'player_link': 'https://www.whoscored.com/Players/302893/Show/Fabio-Depaoli'},
#  302918: {'player_link': 'https://www.whoscored.com/Players/302918/Show/Milan-Skriniar'},
#  302968: {'player_link': 'https://www.whoscored.com/Players/302968/Show/Claud-Adjapong'},
#  303021: {'player_link': 'https://www.whoscored.com/Players/303021/Show/Andrija-Balic'},
#  303023: {'player_link': 'https://www.whoscored.com/Players/303023/Show/Riccardo-Fiamozzi'},
#  303656: {'player_birthday': '11-05-1996',
#   'player_height': 163,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/303656.jpg',
#   'player_link': 'https://www.whoscored.com/Players/303656/Show/Adri%C3%A1n-Cubas',
#   'player_name': 'Adrián Cubas',
#   'player_position': [],
#   'player_weight': 60,
#   'team_id': 6147},
#  303800: {'player_birthday': '28-02-1996',
#   'player_height': 179,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/303800.jpg',
#   'player_link': 'https://www.whoscored.com/Players/303800/Show/Lucas-Boy%C3%A9',
#   'player_name': 'Lucas Boyé',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 62},
#  303814: {'player_birthday': '12-03-1996',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/303814.jpg',
#   'player_link': 'https://www.whoscored.com/Players/303814/Show/Robert-Muric',
#   'player_name': 'Robert Muric',
#   'player_position': [],
#   'player_weight': 76,
#   'team_id': 11667},
#  303856: {'player_birthday': '10-03-1996',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/303856.jpg',
#   'player_link': 'https://www.whoscored.com/Players/303856/Show/Josip-Posavec',
#   'player_name': 'Josip Posavec',
#   'player_position': [],
#   'player_weight': 80,
#   'team_id': 1285},
#  315537: {'player_birthday': '05-02-1997',
#   'player_height': 192,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/315537.jpg',
#   'player_link': 'https://www.whoscored.com/Players/315537/Show/Senna-Miangue',
#   'player_name': 'Senna Miangue',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 78},
#  316537: {'player_birthday': '03-01-1997',
#   'player_height': 184,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/316537.jpg',
#   'player_link': 'https://www.whoscored.com/Players/316537/Show/Alessandro-Rossi',
#   'player_name': 'Alessandro Rossi',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 143},
#  317544: {'player_birthday': '19-05-1999',
#   'player_height': 186,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/317544.jpg',
#   'player_link': 'https://www.whoscored.com/Players/317544/Show/Andrea-Pinamonti',
#   'player_name': 'Andrea Pinamonti',
#   'player_position': [],
#   'player_weight': 72,
#   'team_id': 75},
#  320493: {'player_link': 'https://www.whoscored.com/Players/320493/Show/Stefan-Silva'},
#  320625: {'player_link': 'https://www.whoscored.com/Players/320625/Show/Samuel-Gustafson'},
#  322971: {'player_birthday': '25-10-1997',
#   'player_height': 175,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/322971.jpg',
#   'player_link': 'https://www.whoscored.com/Players/322971/Show/Federico-Chiesa',
#   'player_name': 'Federico Chiesa',
#   'player_position': [],
#   'player_weight': 70,
#   'team_id': 73},
#  323239: {'player_birthday': '18-02-1998',
#   'player_height': 180,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/323239.jpg',
#   'player_link': 'https://www.whoscored.com/Players/323239/Show/Simone-Lo-Faso',
#   'player_name': 'Simone Lo Faso',
#   'player_position': [],
#   'player_weight': 72,
#   'team_id': 73},
#  323240: {'player_link': 'https://www.whoscored.com/Players/323240/Show/Pol-Lirola'},
#  323660: {'player_birthday': '02-02-1998',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/323660.jpg',
#   'player_link': 'https://www.whoscored.com/Players/323660/Show/Giuseppe-Cuomo',
#   'player_name': 'Giuseppe Cuomo',
#   'player_position': [],
#   'player_weight': 79,
#   'team_id': 0},
#  326500: {'player_birthday': '05-03-1992',
#   'player_height': 181,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/326500.jpg',
#   'player_link': 'https://www.whoscored.com/Players/326500/Show/Maximiliano-Olivera',
#   'player_name': 'Maximiliano Olivera',
#   'player_position': [],
#   'player_weight': 72,
#   'team_id': 73},
#  326588: {'player_link': 'https://www.whoscored.com/Players/326588/Show/Noe-Dussenne'},
#  327933: {'player_birthday': '23-02-1998',
#   'player_height': 190,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/327933.jpg',
#   'player_link': 'https://www.whoscored.com/Players/327933/Show/Luca-Crosta',
#   'player_name': 'Luca Crosta',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 78},
#  328990: {'player_link': 'https://www.whoscored.com/Players/328990/Show/Moise-Kean'},
#  329665: {'player_link': 'https://www.whoscored.com/Players/329665/Show/Alessandro-Bastoni'},
#  329681: {'player_link': 'https://www.whoscored.com/Players/329681/Show/Patrick-Cutrone'},
#  330585: {'player_link': 'https://www.whoscored.com/Players/330585/Show/Roberto-Biancu'},
#  330643: {'player_link': 'https://www.whoscored.com/Players/330643/Show/Orji-Okwonkwo'},
#  330645: {'player_link': 'https://www.whoscored.com/Players/330645/Show/Giuseppe-Borello'},
#  330649: {'player_link': 'https://www.whoscored.com/Players/330649/Show/Joshua-P%C3%A9rez'},
#  331043: {'player_birthday': '02-10-1997',
#   'player_height': 182,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/331043.jpg',
#   'player_link': 'https://www.whoscored.com/Players/331043/Show/Sofian-Kiyine',
#   'player_name': 'Sofian Kiyine',
#   'player_position': [],
#   'player_weight': 72,
#   'team_id': 143},
#  332270: {'player_birthday': '17-03-2001',
#   'player_height': 196,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/332270.jpg',
#   'player_link': 'https://www.whoscored.com/Players/332270/Show/Pietro-Pellegri',
#   'player_name': 'Pietro Pellegri',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 248},
#  332553: {'player_link': 'https://www.whoscored.com/Players/332553/Show/Emanuel-Vignato'},
#  332554: {'player_link': 'https://www.whoscored.com/Players/332554/Show/Filippo-Melegoni'},
#  333136: {'player_link': 'https://www.whoscored.com/Players/333136/Show/Paolo-Farag%C3%B2'},
#  333308: {'player_birthday': '23-10-1998',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/333308.jpg',
#   'player_link': 'https://www.whoscored.com/Players/333308/Show/Jan-Mlakar',
#   'player_name': 'Jan Mlakar',
#   'player_position': [],
#   'player_weight': 78,
#   'team_id': 595},
#  334222: {'player_birthday': '10-08-1999',
#   'player_height': 175,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/334222.jpg',
#   'player_link': 'https://www.whoscored.com/Players/334222/Show/Giorgio-Spizzichino',
#   'player_name': 'Giorgio Spizzichino',
#   'player_position': [],
#   'player_weight': 70,
#   'team_id': 0},
#  334824: {'player_birthday': '04-02-2000',
#   'player_height': 179,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/334824.jpg',
#   'player_link': 'https://www.whoscored.com/Players/334824/Show/Gennaro-Ruggiero',
#   'player_name': 'Gennaro Ruggiero',
#   'player_position': [],
#   'player_weight': 74,
#   'team_id': 0},
#  335087: {'player_birthday': '11-09-1998',
#   'player_height': 178,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/335087.jpg',
#   'player_link': 'https://www.whoscored.com/Players/335087/Show/Han-Kwang-Song',
#   'player_name': 'Han Kwang Song',
#   'player_position': [],
#   'player_weight': 70,
#   'team_id': 78},
#  335093: {'player_birthday': '03-02-1999',
#   'player_height': 183,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/335093.jpg',
#   'player_link': 'https://www.whoscored.com/Players/335093/Show/Mamadou-Coulibaly',
#   'player_name': 'Mamadou Coulibaly',
#   'player_position': [],
#   'player_weight': 75,
#   'team_id': 277},
#  336959: {'player_birthday': '29-05-1998',
#   'player_height': 186,
#   'player_img_link': 'https://d2zywfiolv4f83.cloudfront.net/img/players/336959.jpg',
#   'player_link': 'https://www.whoscored.com/Players/336959/Show/Arnel-Jakupovic',
#   'player_name': 'Arnel Jakupovic',
#   'player_position': [],
#   'player_weight': 81,
#   'team_id': 272}}

# %% [markdown]
# # Crawl performance instances

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
import time

driver = webdriver.Chrome()
#driver = webdriver.Safari()
start_url = "https://www.whoscored.com/Regions/108/Tournaments/5/Seasons/6461/Stages/14014/Fixtures/Italy-Serie-A-2016-2017"
driver.get(start_url)

# %%
# Find the link of each match
match_table = {}

prev_month_button = driver.find_element_by_xpath("//*[@id=\"date-controller\"]/a[1]")
prev_button_status = prev_month_button.get_attribute("title")
previous_month = ""
current_month = driver.find_element_by_xpath("//*[@id=\"date-config-toggle-button\"]/span[1]").text

while (prev_button_status == "View previous month"):
    while (current_month == previous_month):
        prev_month_button.click()
        time.sleep(1)
        current_month = driver.find_element_by_xpath("//*[@id=\"date-config-toggle-button\"]/span[1]").text
        prev_button_status = prev_month_button.get_attribute("title")

    while True:
        try:
            # match_table = {}
            trs = driver.find_elements_by_xpath("//*[@id=\"tournament-fixture\"]/tbody/tr")

            for tr in trs:
                tds = tr.find_elements_by_xpath("td")
                if(len(tds)):
                    match_id = tr.get_attribute("data-id")
                    match_table[match_id] = {}
                for i, td in enumerate(tds):
                    if(i == 4):
                        match_table[match_id]["match_link"] = td.find_element_by_tag_name("a").get_attribute("href")
            break
        except:
            print("wait")
            time.sleep(0.5)

    previous_month = current_month

# %%
# Crawl data of each match performance
performance_table = {}

print("Total number of matches:{}.".format(len(match_table)))
cnt = 1
subdriver = webdriver.Chrome()
for match_id, match_details in match_table.items():
    performance_table[match_id] = {}
    match_link = match_details["match_link"]
    # Change into the match page
    print(">>> {}: Crawling {}...".format(cnt, match_id))
    cnt += 1
    
    subdriver.get(match_link)
    # Change into player statistic page
    subdriver.get(subdriver.find_element_by_xpath("//*[@id=\"sub-sub-navigation\"]/ul/li[2]/a").get_attribute("href"))
    time.sleep(1)

    # Click through all player statistic tables such that they can be loaded
    home_offensive_button = subdriver.find_element_by_xpath("//*[@id=\"live-player-home-options\"]/li[2]/a")
    home_offensive_button.click()
    home_defensive_button = subdriver.find_element_by_xpath("//*[@id=\"live-player-home-options\"]/li[3]/a")
    home_defensive_button.click()
    home_passing_button = subdriver.find_element_by_xpath("//*[@id=\"live-player-home-options\"]/li[4]/a")
    home_passing_button.click()
    away_offensive_button = subdriver.find_element_by_xpath("//*[@id=\"live-player-away-options\"]/li[2]/a")
    away_offensive_button.click()
    away_defensive_button = subdriver.find_element_by_xpath("//*[@id=\"live-player-away-options\"]/li[3]/a")
    away_defensive_button.click()
    away_passing_button = subdriver.find_element_by_xpath("//*[@id=\"live-player-away-options\"]/li[4]/a")
    away_passing_button.click()
    # Crawl match performance
    home_offensive_trs = subdriver.find_element_by_xpath("//*[@id=\"statistics-table-home-offensive\"]").find_elements_by_xpath("/[@id=\"player-table-statistics-body\"]/tr")
    home_defensive_trs = subdriver.find_element_by_xpath("//*[@id=\"statistics-table-home-defensive\"]").find_elements_by_xpath("/[@id=\"player-table-statistics-body\"]/tr")
    home_passing_trs = subdriver.find_element_by_xpath("//*[@id=\"statistics-table-home-passing\"]").find_elements_by_xpath("/[@id=\"player-table-statistics-body\"]/tr")
    away_offensive_trs = subdriver.find_element_by_xpath("//*[@id=\"statistics-table-away-offensive\"]").find_elements_by_xpath("/[@id=\"player-table-statistics-body\"]/tr")
    away_defensive_trs = subdriver.find_element_by_xpath("//*[@id=\"statistics-table-away-dfensive\"]").find_elements_by_xpath("/[@id=\"player-table-statistics-body\"]/tr")
    away_passing_trs = subdriver.find_element_by_xpath("//*[@id=\"statistics-table-away-passing\"]").find_elements_by_xpath("/[@id=\"player-table-statistics-body\"]/tr")
    total_offensive_trs = home_offensive_trs + away_offensive_trs
    total_defensive_trs = home_defensive_trs + away_defensive_trs
    total_passing_trs = home_passing_trs + away_passing_trs
                  
    for tr in total_offensive_trs:
        player_id = int(re.findall(r'\d+', tr.find_element_by_class_name("player-link").get_attribute("href"))[0])
        performance_table[match_id][player_id] = {}
        
        total_shots = tr.find_element_by_class_name("ShotsTotal ").text
        ot_shots = tr.find_element_by_class_name("ShotOnTarget ").text
        key_passes = tr.find_element_by_class_name("KeyPassTotal ").text
        dribbles = tr.find_element_by_class_name("DribbleWon ").text
        foul_given = tr.find_element_by_class_name("FoulGiven ").text
        offsides = tr.find_element_by_class_name("OffsideGiven ").text
        disp = tr.find_element_by_class_name("Dispossessed ").text
        uns_touches = tr.find_element_by_class_name("Turnover ").text
        key_events_icons = tr.find_elements_by_class_name("incident-icon")
        key_events = ["{},{},{}".format(icon.get_attribute("data-type"), icon.get_attribute("data-minute"), icon.get_attribute("data-second")) for icon in key_events_icons]
        
        performance_table[match_id][player_id]["total_shots"] = total_shots
        performance_table[match_id][player_id]["ot_shots"] = ot_shots
        performance_table[match_id][player_id]["key_passes"] = key_passes
        performance_table[match_id][player_id]["dribbles"] = dribbles
        performance_table[match_id][player_id]["foul_given"] = foul_given
        performance_table[match_id][player_id]["offsides"] = offsides
        performance_table[match_id][player_id]["disp"] = disp
        performance_table[match_id][player_id]["uns_touches"] = uns_touches
        performance_table[match_id][player_id]["key_events"] = key_events
        
    for tr in total_defensive_trs:
        player_id = int(re.findall(r'\d+', tr.find_element_by_class_name("player-link").get_attribute("href"))[0])
        
        total_tackles = tr.find_element_by_class_name("TackleWonTotal ").text
        interception = tr.find_element_by_class_name("InterceptionAll ").text
        clearances = tr.find_element_by_class_name("ClearanceTotal ").text
        blocked_shots = tr.find_element_by_class_name("ShotBlocked ").text
        fouls_committed = tr.find_element_by_class_name("FoulCommitted ").text
        
        performance_table[match_id][player_id]["total_tackles"] = total_tackles
        performance_table[match_id][player_id]["interception"] = interception
        performance_table[match_id][player_id]["clearances"] = clearances
        performance_table[match_id][player_id]["blocked_shots"] = blocked_shots
        performance_table[match_id][player_id]["fouls_committed"] = fouls_committed
    
    for tr in total_passing_trs:
        player_id = int(re.findall(r'\d+', tr.find_element_by_class_name("player-link").get_attribute("href"))[0])
        
        total_passes = tr.find_element_by_class_name("TotalPasses ").text
        pass_acc = tr.find_element_by_class_name("PassSuccessInMatch ").text
        crosses = tr.find_element_by_class_name("PassCrossTotal ").text
        acc_crosses = tr.find_element_by_class_name("PassCrossAccurate ").text
        total_long_balls = tr.find_element_by_class_name("PassLongBallTotal ").text
        acc_long_balls = tr.find_element_by_class_name("PassLongBallAccurate ").text
        total_through_balls = tr.find_element_by_class_name("PassThroughBallTotal ").text
        acc_through_balls = tr.find_element_by_class_name("PassThroughBallAccurate ").text
        
        performance_table[match_id][player_id]["total_passes"] = total_passes
        performance_table[match_id][player_id]["pass_acc"] = pass_acc
        performance_table[match_id][player_id]["crosses"] = crosses
        performance_table[match_id][player_id]["acc_crosses"] = acc_crosses
        performance_table[match_id][player_id]["total_long_balls"] = total_long_balls
        performance_table[match_id][player_id]["acc_long_balls"] = acc_long_balls
        performance_table[match_id][player_id]["total_through_balls"] = total_through_balls
        performance_table[match_id][player_id]["acc_through_balls"] = acc_through_balls
    
print(">>> finished.")
driver.close()
subdriver.close()
# Out:
#   File "<ipython-input-10-ea1d71a1914a>", line 17
#     time.sleep(1)
#        ^
# SyntaxError: invalid syntax
